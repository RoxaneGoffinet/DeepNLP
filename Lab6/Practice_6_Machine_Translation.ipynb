# %% [markdown]
# # **Deep Natural Language Processing @ PoliTO**
#
#
# ---
# **Teaching Assistant:** Teaching Assistant
#
# **Credits:** Moreno La Quatra
#
# **Practice 6:** Machine Translation

# %% [markdown]
# ## **Machine Translation**
#
# Machine Translation is a sub-field of Natural Language Processing that aims at translating a text from a source language to a target language. In this practice, we will experiment with a Transformer-based model for Machine Translation. Specifically, we will benchmark the performance of a pre-trained MT model on Italian-English and English-Italian translation tasks.
#
# ![](https://www.deepl.com/img/press/desktop_ENIT_2020-01.png)
#
# In this practice we will use a data collection provided by [tatoeba](https://tatoeba.org/). The following cell download a subset of the data collection, containing parallel Italian-English sentences.

# %%
# %%capture
# !wget https://raw.githubusercontent.com/MorenoLaQuatra/DeepNLP/main/practices/P6/train_it_en.tsv
# !wget https://raw.githubusercontent.com/MorenoLaQuatra/DeepNLP/main/practices/P6/test_it_en.tsv

# %% [markdown]
# ### **Question 1: Parsing data**
#
# The first step is to parse the data collection to generate a list of sentence pairs. The data are provided in `tsv` format, where each line contains a sentence pair in the following format:
#
# `<source_language_sentence>\t<target_language_sentence>\n`
#
# You are provided with a training and a test set. For this question you should parse both data splits and store them in your preferred data structure.
#
# **Note:** store train and test set into separate data objects.

# %%
# your code here

def parse_tsv(file_path):
    sentence_pairs = []
    with open(file_path, 'r', encoding='utf-8') as file:
        for i, line in enumerate(file):
            if i == 0:
                continue
            striped_line = line.strip().split('\t')
            source = striped_line[2]
            target = striped_line[4]
            sentence_pairs.append((source, target))
    
    return sentence_pairs

train_file_path = 'train_it_en.tsv'
test_file_path = 'test_it_en.tsv'

train_data = parse_tsv(train_file_path)
test_data = parse_tsv(test_file_path)

# %%
train_data
# Out:
# [('Li aiuteremo domani.', "We'll help them tomorrow."),
#  ('Tu guardi spesso la TV?', 'Do you watch TV often?'),
#  ('Rovesciò il suo drink sul mio smoking.',
#   'She spilled her drink all over my tuxedo.'),
#  ('Rimanete in contatto con me.', 'Keep in touch with me.'),
#  ('Quale cane è il vostro?', 'Which dog is yours?'),
#  ("C'erano alcuni fiori lì.", 'There were some flowers there.'),
#  ("C'è del traffico pesante su questa strada.",
#   'There is heavy traffic on this street.'),
#  ('Lui ha precisato che il viaggio costerà 300 euro.',
#   'He made it clear that the trip will cost 300 euros.'),
#  ("Io sono un po' arrabbiato con te.", "I'm a little angry with you."),
#  ('Tom passa meno tempo a studiare francese di me.',
#   'Tom spends less time studying French than I do.'),
#  ('Ho visto un ragazzino correre.', 'I saw a little boy running.'),
#  ('È quasi estate.', "It's almost summertime."),
#  ('Tom ama i film sugli zombie e li guarda ogni volta che può.',
#   'Tom loves zombie movies and watches them whenever he can.'),
#  ('Tom ha detto a Mary di aiutare John.', 'Tom told Mary to help John.'),
#  ('La fermammo.', 'We stopped it.'),
#  ("L'ho incontrato mentre studiava.", 'I met him while he was studying.'),
#  ('Lo incontrerai.', "You'll meet him."),
#  ('Dovrà farlo da qualche altra parte.', "You'll have to do that elsewhere."),
#  ('Può essere pericoloso.', 'It can be dangerous.'),
#  ('Assomiglia a suo fratello.', 'He looks like his brother.'),
#  ('Tom ritornò in Australia per essere con me.',
#   'Tom returned to Australia to be with me.'),
#  ('Ha smesso di correre.', 'He quit running.'),
#  ('Loro cosa stanno nascondendo?', 'What are they hiding?'),
#  ('Tom sta chiedendo il permesso,', 'Tom is asking permission.'),
#  ('Posso venire?', 'Can I come?'),
#  ('La catturarono.', 'They captured her.'),
#  ('Tom e Mary saranno di nuovo in ritardo.',
#   'Tom and Mary are going to be late again.'),
#  ('Lui stava lavorando in ufficio ieri sera.',
#   'He was working at the office yesterday evening.'),
#  ('Che succede la settimana prossima?', "What's happening next week?"),
#  ('Molti contadini sono morti durante la siccità.',
#   'Many peasants died during the drought.'),
#  ('Stai entrando?', 'Are you coming in?'),
#  ('Qual è la cosa migliore che hai mai ricevuto per Natale?',
#   "What's the best thing you've ever gotten for Christmas?"),
#  ('Tom è piuttosto occupato in questo momento.',
#   "Tom's rather busy just now."),
#  ('Ha detto che era infelice.', 'She said that she was unhappy.'),
#  ('Sarà impegnativo resistere alla tentazione.',
#   'It will be difficult to resist the temptation.'),
#  ('Non prendo ordini da lei.', "I don't take orders from you."),
#  ("Tom si fece male al ginocchio sinistro durante l'allenamento, così John dovette giocare al posto suo.",
#   'Tom hurt his left knee during practice, so John had to play the game in his place.'),
#  ('Io mi chiamo Lin Feng.', 'I am called Lin Feng.'),
#  ('Dormii a lungo?', 'Did I sleep long?'),
#  ('Disegnami una pecora!', 'Draw me a sheep!'),
#  ("Tom sta cercando una via d'uscita.", 'Tom is searching for a way out.'),
#  ('Tom non è associato a Disneyland.',
#   'Tom is not affiliated with Disneyland.'),
#  ("Vengono dall'Italia.", 'They are from Italy.'),
#  ('Tom prese su il telefono.', 'Tom picked up the phone.'),
#  ('Lui non uscirebbe.', 'He would not go out.'),
#  ('Le macchine stanno diventando costose.', 'Cars are getting expensive.'),
#  ('È spaventoso.', "It's scary."),
#  ('Tom è svenuto.', "Tom's fainted."),
#  ('Dovrei essere davvero preoccupata?', 'Should I really be worried?'),
#  ('Sei dalla mia parte, vero?', "You're on my side, aren't you?"),
#  ('Gli dissi che eri impegnata.', 'I told him you were busy.'),
#  ('Tom non ha lavorato lunedì notte.', "Tom didn't work on Monday night."),
#  ('Ho fatto una bella chiacchierata con Tom.', 'I had a nice chat with Tom.'),
#  ('Non mi piace parlare con la gente che non conosco.',
#   "I don't like talking to people I don't know."),
#  ('Dovrebbero esserci più frasi in lingue minoritarie su Tatoeba.',
#   'There should be more sentences in minority languages in Tatoeba.'),
#  ('Per via della tempesta, lui non è arrivato.',
#   "Due to the storm, he didn't arrive."),
#  ("Yanni legge dei libri riguardo all'Islam.",
#   'Yanni reads books about Islam.'),
#  ('Non ha ragione di essere gelosa.', 'She has no reason to be jealous.'),
#  ('Ditemi come posso aiutarvi.', 'Tell me how I can help you.'),
#  ('Mi disse che ci credeva.', 'She told me she believed that.'),
#  ("Io ho vissuto all'estero per dieci anni.", 'I lived abroad for ten years.'),
#  ('Sembra che lei stia bene adesso.', 'She seems OK now.'),
#  ('Dice che non era qui.', "He says he wasn't here."),
#  ('Spero che Tom e Mary siano a scuola.',
#   'I hope that Tom and Mary are at school.'),
#  ('Ovviamente sta mentendo.', 'Obviously, he is lying.'),
#  ('Ha detto che è cautamente ottimista.',
#   "She said she's cautiously optimistic."),
#  ('Mi disse che era veramente occupata.', 'She told me she was really busy.'),
#  ('Le persone sono davvero stupide a volte.',
#   'People are really stupid sometimes.'),
#  ('Potrei avere un giornale giapponese, per piacere?',
#   'Could I get a Japanese newspaper, please?'),
#  ('Per favore, abbia pazienza.', 'Please have patience.'),
#  ('Sono impegnata, Tom.', "I'm busy, Tom."),
#  ('Per favore, chiamatemi Philip.', 'Please call me Philip.'),
#  ('Tom è uno scrittore di discorsi.', 'Tom is a speechwriter.'),
#  ('Tom ha detto che eri bravo.', 'Tom said that you were good.'),
#  ('A lui non piace la pizza.', "He doesn't like pizza."),
#  ('Non lo dimenticherò mai.', "I'll never forget him."),
#  ('È stata provata.', "It's been tried."),
#  ("Dorma un po' adesso.", 'Get some sleep now.'),
#  ('Tom e Mary vogliono farlo?', 'Do Tom and Mary want to do that?'),
#  ('È il nuovo medico interno.', "He's the new intern."),
#  ('Prendete la scatola.', 'Get the box.'),
#  ('È tutta la mattina che scrivo lettere. Ho scritto dieci lettere e non ho ancora finito.',
#   "I've been writing letters all morning. I've written ten and still haven't finished."),
#  ('Nessuno è troppo vecchio per imparare.', "You're never too old to learn."),
#  ('Non ho provato a fermarle.', "I didn't try to stop them."),
#  ('Vorrei prendere questo vestito più che quello.',
#   'I would take this dress before that one.'),
#  ('Pagammo un prezzo equo per esso.', 'We paid a fair price for it.'),
#  ("Tom ha portato a casa un po' di cibo.", 'Tom took some food home.'),
#  ("C'era cibo sufficiente per quaranta giorni.",
#   'There was enough food for forty days.'),
#  ('Lo hanno rilasciato.', 'They released him.'),
#  ('Se devo scegliere, prendo questo.', "For choice, I'll take this one."),
#  ('Chiuda la porta, per piacere.', 'Shut the door, please.'),
#  ('Ha ricevuto un regalo da lui.', 'She got a present from him.'),
#  ('Annoterò il tuo nome e il tuo indirizzo.',
#   'I will write down your name and address.'),
#  ('Era esausta.', 'You were worn out.'),
#  ("Guardi quell'edificio. È un tempio?",
#   'Look at that building. Is it a temple?'),
#  ('Il mio gatto sembra triste.', 'My cat looks sad.'),
#  ("Conosci l'imam di questa moschea?", 'Do you know the imam of this mosque?'),
#  ('Solitamente ottengo quello che voglio.', 'I usually get what I want.'),
#  ('È praticamente nuova!', "It's almost new!"),
#  ('Io non posso vederlo.', "I can't see him."),
#  ("L'ha aspettata all'aeroporto.", 'She waited for her at the airport.'),
#  ('Parlate troppo di loro.', 'You talk about them too much.'),
#  ('Tom è uno sciatore molto bravo, vero?',
#   "Tom is a very good skier, isn't he?"),
#  ("Tom mi chiese se volevo un po' di ketchup nel mio hamburger.",
#   'Tom asked me if I wanted some ketchup on my hamburger.'),
#  ("Lo sai cos'è?", 'Do you know what it is?'),
#  ('Perbacco!', 'Gosh!'),
#  ('Io sto andando in macchina.', "I'm going by car."),
#  ("Gennaio è il primo mese dell'anno, aprile è il quarto, novembre è l'undicesimo, dicembre è il dodicesimo.",
#   'January is the first month of the year, April is the fourth, November is the eleventh, December is the twelfth.'),
#  ('Tom comprò un nuovo pickup.', 'Tom bought a new pickup.'),
#  ('Sto provando a fissarla.', "I'm trying to fix it."),
#  ('Non posso capire Tom.', "I can't understand Tom."),
#  ('Siete nei guai con la legge?', 'Are you in trouble with the law?'),
#  ('Io ho bisogno di ghiaccio.', 'I need ice.'),
#  ('Avete una penna a fontana?', 'Do you have a fountain pen?'),
#  ('Quando vi trasferite nella casa nuova?',
#   'When are you moving into your new house?'),
#  ('Comprò delle calze.', 'He bought socks.'),
#  ('Ha conosciuto Tom mentre lavorava part-time al ranch.',
#   'She met Tom while working part-time on the ranch.'),
#  ('Lo volevo fermare.', 'I wanted to stop him.'),
#  ('Tom vive a Boston.', 'Tom is living in Boston.'),
#  ('Non sapevamo che fare.', "We didn't know what to do."),
#  ("Tu l'hai già chiamato?", 'Did you call him yet?'),
#  ('Non avete paura delle altezze, vero?',
#   "You're not afraid of heights, are you?"),
#  ('Perché me lo sta chiedendo?', 'Why are you asking me?'),
#  ('Tu hai qualcosa di più forte da bere?',
#   'Do you have something stronger to drink?'),
#  ('Smettila di imprecare.', 'Stop swearing.'),
#  ('Ha detto che era depresso.', 'He said that he was depressed.'),
#  ('Hai fino a mezzanotte.', 'You have until midnight.'),
#  ('Volevo solamente vederla.', 'I just wanted to see her.'),
#  ('È una vita da cani.', "It's a dog's life."),
#  ('A te non piace neppure il pesce.', "You don't even like fish."),
#  ('Questo è un televisore.', 'This is a television.'),
#  ('Abbiamo dieci vacche.', 'We have ten cows.'),
#  ('Non so nemmeno da dove cominciare.', "I don't even know where to start."),
#  ('Mi scambiò per il mio fratello gemello.',
#   'He mistook me for my twin brother.'),
#  ('Assassinarono Tom.', 'They murdered Tom.'),
#  ('Tom dice che era affamato.', 'Tom says he was hungry.'),
#  ('Dove li hai umiliati?', 'Where did you humiliate them?'),
#  ('Grazie per il meraviglioso regalo.', 'Thank you for the wonderful gift.'),
#  ('Pensate mai a Tom?', 'Do you ever think about Tom?'),
#  ('Pure Tom mentì.', 'Even Tom lied.'),
#  ('Mi chiedo perché Tom sembri così depresso.',
#   'I wonder why Tom looks so depressed.'),
#  ("Voi lo sapete che cos'è?", 'Do you know what it is?'),
#  ('Tengono pulite le loro automobili.', 'They keep their cars clean.'),
#  ('Posso prenotare un volo per Chicago?',
#   'Can I reserve a flight to Chicago?'),
#  ('Ne avevo davvero bisogno.', 'I really needed it.'),
#  ('Hai detto loro che sei qui?', "Have you told them you're here?"),
#  ('Io cosa posso mangiare?', 'What can I eat?'),
#  ('Tom ha agito in modo irrazionale.', 'Tom acted irrationally.'),
#  ('Tom non vuole che i suoi genitori sappiano che lui si è ubriacato.',
#   "Tom doesn't want his parents to know he got drunk."),
#  ('Sei stato a Londra?', 'Have you been to London?'),
#  ('Questo è il libro di Tony.', "This is Tony's book."),
#  ('Diversi giardinieri curano le azalee nel parco.',
#   'Several gardeners look after the azaleas in the park.'),
#  ('Devi studiare sodo per raggiungere la tua classe.',
#   'You have to study hard to catch up with your class.'),
#  ('Sei libero di andare o rimanere.', 'You are free to go or stay.'),
#  ('Io mi sento onorato.', 'I feel honored.'),
#  ('Il negozio è aperto?', 'Is the store open?'),
#  ('Le sue labbra erano morbide.', 'His lips were soft.'),
#  ('Tu pensi davvero che Tom sia preoccupato?',
#   'Do you really think Tom is worried?'),
#  ('Tom sa che non è il benvenuto qua.', "Tom knows he isn't welcome here."),
#  ('Confessò il fatto.', 'He confessed the fact.'),
#  ('Le persone qui sono esigenti riguardo a quello che mangiano, quindi anche se un ristorante è poco costoso, chiuderà presto i battenti se il cibo non ha un buon sapore.',
#   "The people here are particular about what they eat, so even if a restaurant is inexpensive, it'll soon go out of business if the food doesn't taste good."),
#  ('È piuttosto testardo, vero?', "He's quite stubborn, isn't he?"),
#  ('Tom è fedele con tutte le sue amiche.', 'Tom is loyal to all his friends.'),
#  ('Noi siamo influenzati dal nostro ambiente.',
#   "We're influenced by our environment."),
#  ("Non l'ha quasi riconosciuto.", "She almost didn't recognize him."),
#  ('Sami è cresciuto qui nel ranch.', 'Sami grew up here on the ranch.'),
#  ('Tom è romantico.', 'Tom is romantic.'),
#  ("Lui ha fallito l'esame perché non ha studiato.",
#   "He failed the exam because he didn't study."),
#  ("Quell'albergo era molto vicino al lago.",
#   'That hotel was very near the lake.'),
#  ("Dov'è il tuo altro orecchino?", "Where's your other earring?"),
#  ("Odia studiare il berbero perché odia l'insegnante.",
#   'He hates studying Berber because he hates the teacher.'),
#  ('Non la vedo molto.', "I don't see much of her."),
#  ('Non lasci che i bambini escano dopo il tramonto.',
#   "Don't let the children go out after dark."),
#  ('Qual è la capitale della Grecia?', 'What is the capital of Greece?'),
#  ('Tutti sanno che Jessie ha una cotta per te.',
#   'Everyone knows that Jessie has a thing for you.'),
#  ('Voi avete fatto un errore.', 'You made an error.'),
#  ('Perché ha detto una cosa così stupida?',
#   'Why did you say such a stupid thing?'),
#  ('Tom ha tirato la fune.', 'Tom pulled the rope.'),
#  ('Solamente le vostre opinioni contano.', 'Only your opinions matter.'),
#  ('Esprimi le tue idee.', 'Express your ideas.'),
#  ('Vuole un massaggio?', 'Do you want a massage?'),
#  ('Deve restare in ospedale per una settimana.',
#   'He must stay in the hospital for a week.'),
#  ('Come prendi il caffè, con o senza zucchero?',
#   'How do you take your coffee, with or without sugar?'),
#  ('Cominciai a imparare il berbero alle medie.',
#   'I started to learn Berber in middle school.'),
#  ('Dove siamo su questa cartina?', 'Where are we on this map?'),
#  ('Lui lo uccise.', 'He killed him.'),
#  ('Ho ancora molti ricordi chiari dei miei giorni di scuola.',
#   'I still have many clear memories of my school days.'),
#  ('Ha detto di essere andata a casa a piedi.',
#   'She said that she walked home.'),
#  ('È aggraziata.', 'She is graceful.'),
#  ('Crebbi.', 'I grew up.'),
#  ('Lui ha fatto tutto quello che poteva per proteggere suo figlio.',
#   'He did all he could to protect his son.'),
#  ('Non parliamo di lavoro, OK?', "Let's not talk shop, OK?"),
#  ('Sono senza parole.', 'I am at a loss for words.'),
#  ('Io parlo inglese, esperanto, francese e giapponese.',
#   'I speak English, Esperanto, French and Japanese.'),
#  ('Questo semplice test può prevedere la tua longevità.',
#   'This simple test can predict your longevity.'),
#  ('Ho un vecchio conto in sospeso con Tom.',
#   'I have an old score to settle with Tom.'),
#  ('Il campanello suonò durante il pasto.',
#   'The doorbell rang during the meal.'),
#  ('Io mi sono adattato rapidamente alla mia nuova scuola.',
#   'I quickly adapted myself to my new school.'),
#  ('Siete veramete felici?', 'Are you really happy?'),
#  ('Questo posto è davvero carino.', 'This place is really nice.'),
#  ('Avrete fame.', 'You will be hungry.'),
#  ('È la loro unica figlia.', "She's their only daughter."),
#  ('Ne ho avuto abbastanza delle vostre lezioni.',
#   "I've had enough of your lectures."),
#  ('La caviglia è rotta.', 'The ankle is broken.'),
#  ('Chi me la diede?', 'Who gave it to me?'),
#  ('Io penso che funzionerà.', "I think it'll work."),
#  ('Abbiamo discusso su cosa fare e dove andare.',
#   'We discussed what to do and where to go.'),
#  ('Ha detto a tutti che era al sicuro.', 'He told everybody he was safe.'),
#  ('Può incassare questo assegno per me?', 'Can you cash this check for me?'),
#  ('Io non avevo intenzione di urlare.', "I didn't mean to yell."),
#  ('Tom è un mio amico dalle superiori.',
#   'Tom is a friend of mine from high school.'),
#  ('Anche io lo penso.', 'I think so, too.'),
#  ('Perché hai bisogno del mio aiuto?', 'Why do you need my help?'),
#  ('Dalla tutta a loro.', 'Give them all of it.'),
#  ('Il Venice Film Festival è il festival cinematografico più vecchio del mondo.',
#   'The Venice Film Festival is the oldest film festival in the world.'),
#  ('Uno degli apostoli di Gesù si chiamava Paolo.',
#   "One of Jesus' disciples was named Paul."),
#  ('Tom e Mary hanno detto che non hanno visto nulla.',
#   'Tom and Mary said they saw nothing.'),
#  ('Mi darete la vostra radio per la mia bicicletta?',
#   'Will you give me your radio for my bicycle?'),
#  ('Guarda sempre verso il futuro.', 'He is always looking to the future.'),
#  ('Ha abbandonato sua moglie e i suoi figli.',
#   'He abandoned his wife and children.'),
#  ('Chi è la respondabile di questa sezione?',
#   "Who's in charge of this section?"),
#  ('Per piacere, non la faccia.', "Please don't do it."),
#  ('Vorresti andare a nuotare con noi.',
#   'Would you like to go swimming with us?'),
#  ('Mary ti crede.', 'Mary believes you.'),
#  ('Io gli ho detto che avevo dei piani.', 'I told him I had plans.'),
#  ("Oggi è l'anniversario di matrimonio dei miei genitori.",
#   "Today is my parents' wedding anniversary."),
#  ('Sono ucraino.', "I'm Ukrainian."),
#  ('Io ho il doppio della vostra età.', "I'm twice your age."),
#  ('Che storia emozionante!', 'What a touching story!'),
#  ('Se non ha nulla da fare, può contribuire a Tatoeba.',
#   "If you don't have anything to do, you can contribute to Tatoeba."),
#  ("Tom mi ha dato un bell'ombrello, però l'ho perso.",
#   'Tom gave me a nice umbrella, but I lost it.'),
#  ('Fece irruzione nella stanza.', 'She burst into the room.'),
#  ("Puoi permetterti di prendere le ferie quest'estate?",
#   'Can you afford to take a holiday this summer?'),
#  ('Non li lascerò entrare.', "I won't let them come in."),
#  ('Assecondi Tom.', 'Humor Tom.'),
#  ('Sami si fece un bagno.', 'Sami had a bath.'),
#  ('Non ho intenzione di ripetermi.', "I don't intend to repeat myself."),
#  ('Avete sempre avuto quel taglio di capelli?',
#   'Have you always had that hairstyle?'),
#  ("L'ho deluso.", "I've let him down."),
#  ('Tom ha cercato di non tossire.', 'Tom tried not to cough.'),
#  ('La città fu danneggiata durante la guerra.',
#   'The city was damaged during the war.'),
#  ('Tom non ha fatto niente per aiutare Mary.',
#   'Tom did nothing to help Mary.'),
#  ("Tom ha bevuto un po' d'acqua.", 'Tom drank some water.'),
#  ('Ha mai assaggiato una zuppa così buona?',
#   'Have you ever tasted such a good soup?'),
#  ('Il tornado ha toccato terra a due chilometri dalla mia scuola.',
#   'The tornado touched down two kilometers from my school.'),
#  ('Abbiamo tre ore.', "We've got three hours."),
#  ('È veramente triste.', "That's really sad."),
#  ('Non ci vorrà molto tempo prima che stia meglio.',
#   'It will not be long before he gets better.'),
#  ('Grazie per avere guardato.', 'Thank you for watching.'),
#  ("Scegliete uno o l'altro.", 'Choose either one or the other.'),
#  ('Mandai via Tom.', 'I sent Tom away.'),
#  ('Ha detto che vuole più dettagli.', 'He said he wants more details.'),
#  ('Io penso che Tom sia antipatico.', 'I think Tom is unlikeable.'),
#  ('Speriamo per il meglio.', "Let's hope for the best."),
#  ('Sono curioso riguardo a qualcosa.', "I'm curious about something."),
#  ('Il mio cuore sanguina per te.', 'My heart bleeds for you.'),
#  ('Posso portarti a casa?', 'Can I take you home?'),
#  ('Mary vive in un appartamento con sua madre e due fratelli minori.',
#   'Mary lives in an apartment with her mother and two younger brothers.'),
#  ('Tom diede il suo gatto a Mary.', 'Tom gave his cat to Mary.'),
#  ('Io voglio qualcosa di fresco da bere.', 'I want something cold to drink.'),
#  ('Vuoi studiare il francese?', 'Do you want to study French?'),
#  ('Tom non ne parlò mai.', 'Tom never talked about it.'),
#  ('Chiamate vostro fratello.', 'Call your brother.'),
#  ('Ero emozionata.', 'I was excited.'),
#  ('Portami una forchetta, Tom.', 'Bring me a fork, Tom.'),
#  ('Voleva comprare un libro.', 'He wanted to buy a book.'),
#  ('A me piace camminare sotto la pioggia.', 'I like to walk in the rain.'),
#  ('Non importa quanto lei possa essere stanca, deve farlo.',
#   'No matter how tired you might be, you have to do it.'),
#  ('Lei sta vincendo.', "You're winning."),
#  ('Garantirò per lui.', "I'll vouch for him."),
#  ('Non può scappare.', "He can't escape."),
#  ('Sua sorella non va negli Stati Uniti.',
#   'His sister does not go to the United States.'),
#  ('Conosco Tom da molto tempo.', "I've known Tom for a long time."),
#  ('Non sono in servizio adesso.', "I'm off duty now."),
#  ('Semplicemente non abbiamo scelta.', 'We simply have no choice.'),
#  ("Lei non vuole provare nient'altro.",
#   "She doesn't want to try anything else."),
#  ('Perché si sta comportando in maniera così infantile?',
#   'Why are you acting so childish?'),
#  ('Si suicidò.', 'He committed suicide.'),
#  ('Hanno fatto una breccia nel muro.', 'They made a breach in the wall.'),
#  ('Ha detto che stava bene.', 'She said that she was well.'),
#  ("Dov'è la corsia delle vitamine?", "Where's the aisle for vitamins?"),
#  ('Tom non mi ha ancora perdonata.', "Tom still hasn't forgiven me."),
#  ('Devi studiare molto più duramente.', 'You must study much harder.'),
#  ('Guardi la donna laggiù!', 'Look at the woman over there!'),
#  ('Tom non ci vide.', "Tom didn't see us."),
#  ('È sicuro che passerà il prossimo esame.',
#   "He's sure that he'll pass the next exam."),
#  ('Mi sono imbattuto nel signor Yoshiyuki alla stazione di Shibuya.',
#   'I ran into Mr. Yoshiyuki at Shibuya station.'),
#  ('La casa in cui sto abitando non è molto carne.',
#   "The house I'm living in isn't very large."),
#  ("Tom mi ha promesso che l'avrebbe fatta.", "Tom promised me he'd do it."),
#  ("L'hai incontrato di recente?", 'Did you meet him recently?'),
#  ('Io non conoscevo alcuna canzone.', "I didn't know any of the songs."),
#  ('Prendo delle vitamine.', 'I take vitamins.'),
#  ('Loro abbandonarono i loro figli nel bosco.',
#   'They abandoned their children in the forest.'),
#  ('Io ho fatto un calcolo rapido.', 'I calculated hastily.'),
#  ('Non nuoti nel fiume.', "Don't swim in the river."),
#  ('Lei è mancata a tutte noi.', 'We all have missed you.'),
#  ('Io non riesco a crederti.', "I can't believe you."),
#  ('Lei sembra perfetto per il lavoro.', 'You seem perfect for the job.'),
#  ('Riesce ad aspettare fino a domani.', 'He can wait until tomorrow.'),
#  ('Torna adesso.', 'Come back now.'),
#  ("Non sa dov'è nata.", "She doesn't know where she was born."),
#  ('Lascia che ti richiami.', 'Let me call you back.'),
#  ('Questa è la giornata giusta.', 'This is the right day.'),
#  ('Noi avremo una discussione riguardante la prognosi.',
#   'We will have a discussion concerning the prognosis.'),
#  ('Capiamo tutti.', 'We all understand.'),
#  ('Questo hotel non è molto buono.', "This hotel isn't very good."),
#  ('Tu vuoi vedere un film francese, giusto?',
#   'You want to see a French movie, right?'),
#  ('Chi ha aspettato?', 'Who waited?'),
#  ('Mi è veramente piaciuto il film.', 'I really enjoyed the movie.'),
#  ('Abbassate quella musica!', 'Turn that music down!'),
#  ('Mia nonna si lamenta sempre del freddo.',
#   'My grandmother is always complaining of the cold.'),
#  ("L'ha suggerita da sola.", 'You suggested it yourself.'),
#  ('È piuttosto avventuroso, vero?', "He's pretty adventurous, isn't he?"),
#  ('Io non sono più ispirata.', "I'm not inspired anymore."),
#  ('Come si chiama?', "What's that called?"),
#  ('Non voglio perdere Mary.', "I don't want to lose Mary."),
#  ('Pensavo ci odiasse.', 'I thought you hated us.'),
#  ('Non mi lascerete, vero?', "You won't leave me, will you?"),
#  ("L'avidità è buona.", 'Greed is good.'),
#  ('Ora, mi aiuterai?', 'Now, will you help me?'),
#  ('Tom voleva che Mary imparasse il francese.',
#   'Tom wanted Mary to learn French.'),
#  ('Perché era un segreto?', 'Why was that a secret?'),
#  ('Li dobbiamo trovare.', 'We must find them.'),
#  ('Io ho preparato dello stufato.', "I've made stew."),
#  ("Tom è un po' più alto di lei.", 'Tom is a little taller than you are.'),
#  ('Ma di colpo gli incominciò a girare la testa e si risedette sulla sua vecchia sedia.',
#   'But he suddenly felt dizzy and he sat down again in his old chair.'),
#  ('Potresti indicarmi la direzione giusta?',
#   'Could you point me in the right direction?'),
#  ('Ha spesso torto, vero?', "He's often wrong, isn't he?"),
#  ('Non si è presentato.', "He didn't introduce himself."),
#  ('Lei è la mia sorella maggiore.', 'She is my older sister.'),
#  ('Io sono un esperto di programmazione.', "I'm an expert at programming."),
#  ('Tom portò dei fiori a Mary.', 'Tom brought Mary flowers.'),
#  ('Tom parla sempre in francese.', 'Tom always speaks in French.'),
#  ('Vorrei essere stato gentile con lei allora.',
#   'I wish I had been kind to her then.'),
#  ('"Gerusalemme si chiama ""Yerushalayim"" in ebraico."',
#   '"Jerusalem is called ""Yerushalayim"" in Hebrew."'),
#  ('Sentitevi libere di dire di no.', 'Feel free to say no.'),
#  ('Voleva restare con sua madre.', 'He wanted to stay with his mother.'),
#  ('Non importa.', 'Never mind.'),
#  ('Lui ha comprato un casco di banane.', 'He has bought a banana case.'),
#  ('Che ne dici di pesce per cena?', 'What about having fish for dinner?'),
#  ('Indovina chi viene a cena.', "Guess who's coming for dinner."),
#  ('Ha realizzato che doveva farlo.', 'She realized she had to do that.'),
#  ('Credo che voi conosciate Tom.', 'I believe you know Tom.'),
#  ('Tom non aspetterà a lungo.', "Tom won't wait long."),
#  ('Il ragazzo ha la maggiore quantità di frutta.',
#   'The boy has the greatest amount of fruit.'),
#  ('Pensa di potere salvare il mondo.', 'He thinks he can save the world.'),
#  ('Pagai da bere.', 'I paid for the drinks.'),
#  ('Io sto andando a fare shopping.', 'I am going shopping.'),
#  ('Io sto liberando Tom.', "I'm setting Tom free."),
#  ("Tom fotografò questi edifici per l'esposizione.",
#   'Tom photographed these buildings for the exhibit.'),
#  ('Sono sicura che Tom avrebbe acconsentito.',
#   "I'm sure Tom would've agreed."),
#  ('Dicono di essere sue amiche.', "They say they're friends of yours."),
#  ('Vale la pena investigare.', "It's worth investigating."),
#  ('Lei non è andata lontano.', "She didn't go far."),
#  ('Tom è inaffidabile.', "Tom isn't reliable."),
#  ('Tom è grassottello.', 'Tom is pudgy.'),
#  ('Lui non aveva niente da dire.', 'He had nothing to tell.'),
#  ('Le piace cacciare, vero?', "You like to hunt, don't you?"),
#  ('Ho preso la decisione giusta.', 'I made the right decision.'),
#  ('Tom si spazzolò i capelli.', 'Tom brushed his hair.'),
#  ('Ci sono abituata ad alzarmi presto.',
#   "I'm accustomed to getting up early."),
#  ('Perché non mi avete chiamato la scorsa notte?',
#   "Why didn't you call me last night?"),
#  ('Tom ha cambiato il suo avatar.', 'Tom changed his avatar.'),
#  ('Mi dissero che erano disperate.', 'They told me that they were desperate.'),
#  ('Scegline una e scrivi una lettera.', 'Choose one and write a letter.'),
#  ("Io ho riempito il secchio d'acqua.", 'I filled the bucket with water.'),
#  ('Ha detto che non lo avrebbe fatto.', "She said she wouldn't do it."),
#  ('Non credo che ci sia alcuna giustificazione per il suo comportamento. Allo stesso tempo, dobbiamo ascoltare quello che ha da dire.',
#   "I don't think there is any excuse for his behavior. At the same time, we should listen to what he has to say."),
#  ('È disperata ora, vero?', "She's desperate now, isn't she?"),
#  ('Tu sei ferita.', "You're wounded."),
#  ('Ha detto che pensava che fossi morto.',
#   'He said that he thought I was dead.'),
#  ('Il tempo passa molto velocemente.', 'Time goes very swiftly.'),
#  ('Non interferite con me.', "Don't interfere with me."),
#  ('È veramente ubriaca, vero?', "She's really drunk, isn't she?"),
#  ('Li incontreremo.', "We'll meet them."),
#  ("L'insegnante era preoccupato per le frequenti assenze di Tom.",
#   "The teacher was worried by Tom's frequent absence from class."),
#  ('Non potete guardarlo.', "You can't look at that."),
#  ('Quindi cosa state dicendo?', "So what're you saying?"),
#  ('Ha detto che avrebbe chiamato domani.', 'He said he would call tomorrow.'),
#  ('Vediamo sempre Tom quando andiamo a Boston.',
#   'We always see Tom when we go to Boston.'),
#  ("Ditegli che non l'ho letto.", "Tell him I didn't read it."),
#  ('Vuoi una mia foto?', 'You want my picture?'),
#  ('Io penso che Tom sia acuto.', 'I think Tom is sharp.'),
#  ('Tom nuota come nuota un cane.', 'Tom swims like a dog.'),
#  ('Tom invitò Mary a cena.', 'Tom invited Mary to dinner.'),
#  ("Questa è un'enorme perdita di tempo.", 'This is a huge waste of time.'),
#  ('Noi vogliamo la verità, Tom.', 'We want the truth, Tom.'),
#  ('Ha detto che è irritato.', "He said he's irritated."),
#  ('Io ho iniziato a usare il berbero.', 'I started using Berber.'),
#  ('Rimanga con noi.', 'Stay with us.'),
#  ('Nessuno è stato dentro.', "Nobody's been inside."),
#  ('"Quante zucche vuoi? ""Tre, per favore."""',
#   '"How many pumpkins do you want? ""Three, please."""'),
#  ('Non posso trovare un lavoro che mi piace.', "I can't find a job I like."),
#  ("Tom si sta un po' stancando di questo.",
#   'Tom is getting a little tired of this.'),
#  ('Io non condivido la vostra opinione.', "I don't share your opinion."),
#  ("Ce l'ha in verde?", 'Do you have it in green?'),
#  ('Sta invecchiando.', 'She is getting older.'),
#  ('Come osi dirmi una cosa del genere?',
#   'How dare you say such a thing to me?'),
#  ('Tom provò ad evitare la domanda.', 'Tom tried to avoid the question.'),
#  ('Quelle studentesse sono coreane.', 'Those students are Korean.'),
#  ('Devo andare a chiedere a Tom.', 'I have to go ask Tom.'),
#  ('Ho chiesto a Tom.', 'I asked Tom.'),
#  ('Si comporta in modo molto naturale.', 'He behaves very naturally.'),
#  ('Siete sicure che Tom non si ricorderà niente?',
#   "Are you sure Tom won't remember anything?"),
#  ('Lei non è un dio.', "You're not a god."),
#  ('Perché non ce ne parlate?', "Why don't you tell us about it?"),
#  ('È arrivato alla moschea.', 'He arrived at the mosque.'),
#  ('La mia opinione è completamente diversa dalla sua.',
#   'My opinion is entirely different from yours.'),
#  ('Non voglio che vada in prigione.', "I don't want her to go to jail."),
#  ('Sembra che siamo intrappolate.', 'We seem to be trapped.'),
#  ('Quello che state dicendo è molto importante.',
#   'What you are saying is very important.'),
#  ('Non sfrecci.', "Don't rush."),
#  ('Odio i litigi.', 'I hate arguments.'),
#  ('Sta ancora lavorando con loro?', 'Are you still working with them?'),
#  ("Non l'ha trovata divertente.", 'He did not find it funny.'),
#  ('Sono gli affari.', "It's business."),
#  ('Inizierò io.', "I'll start."),
#  ('Voi siete utili.', "You're helpful."),
#  ('Le piaceva questa partita.', 'She liked this game.'),
#  ('Il diario è orribile.', 'The diary is horrible.'),
#  ('Puoi dirmi quando sarà di ritorno Tom?',
#   "Can you tell me when Tom'll be back?"),
#  ("Ci mostri dove l'ha trovato.", 'Show us where you found him.'),
#  ('Studio spagnolo.', 'I study Spanish.'),
#  ('Restò in bilico tra la vita e la morte.',
#   'He hovered between life and death.'),
#  ('Tom ha provato ad aiutarmi.', 'Tom tried to help me.'),
#  ('Trovò la scatola sotto il tavolo.', 'He found the box under the table.'),
#  ('Non la prenderei mai.', "I'd never take it."),
#  ("Dov'era?", 'Where was he?'),
#  ('Ha avuto una vita difficile.', "She's had a hard life."),
#  ('Posso chiederti un favore?', 'May I ask a favor of you?'),
#  ('Lo faccio tutte le volte.', 'I do it all the time.'),
#  ("Io studierò all'estero quando avrò finito la scuola.",
#   'I will study abroad when I have finished school.'),
#  ('Porti qui quegli uomini.', 'Bring those men here.'),
#  ('Ogni lingua vede il mondo in modo diverso.',
#   'Every language sees the world in a different way.'),
#  ('I soldati potrebbero vederlo adesso.', 'The soldiers could see him now.'),
#  ('Abitate ancora con Tom?', 'Do you still live with Tom?'),
#  ('Tom ha paura di danzare in pubblico.',
#   'Tom is afraid of dancing in public.'),
#  ('Dicono che sono impegnati.', "They say that they're busy."),
#  ('Tom si stava prendendo gioco di Mary.', 'Tom was making fun of Mary.'),
#  ('Passatemi la valigetta.', 'Hand me the briefcase.'),
#  ('Non era malato.', "He wasn't sick."),
#  ('Lo so come funziona il sistema.', 'I know how the system works.'),
#  ('Tu hai pranzato?', 'Have you eaten lunch?'),
#  ('Io sono sicura di poter trovare Tom.', "I'm sure I can find Tom."),
#  ('È stato segnalato che un pullman si è scontrato con un SUV in autostrada la scorsa settimana.',
#   'It was reported that a coach collided with an SUV on the motorway last week.'),
#  ('Non mi sentivo particolarmente nervoso.',
#   "I didn't feel particularly nervous."),
#  ('Tom mi ha fatto suo assistente.', 'Tom made me his assistant.'),
#  ('A Tom ovviamente piace Mary.', 'Tom obviously likes Mary.'),
#  ('Sono pronta per una vacanza.', "I'm ready for a vacation."),
#  ('Siete sicuri di volere lavorare con me?',
#   'Are you sure that you want to work with me?'),
#  ('Decifrò un messaggio.', 'She deciphered a message.'),
#  ('È venuta a trovarmi dal Canada.', 'She came from Canada to see me.'),
#  ('Io mi stavo divertendo.', 'I was having fun.'),
#  ('Noi ci siamo divertiti alla festa.', 'We had fun at the party.'),
#  ('La vita non è altro che un sogno assurdo.', 'Life is but an absurd dream.'),
#  ('Ma le risposte erano tutte sbagliate.', 'But the answers were all wrong.'),
#  ('Si rifiuta di prendre ordini da lei.',
#   'He refuses to take orders from her.'),
#  ('Tom non voleva leggere un libro.', "Tom didn't want to read a book."),
#  ('Tu sai di cosa sto parlando.', "You know what I'm talking about."),
#  ('Io voglio soltanto tenerle la mano.', 'I just want to hold her hand.'),
#  ('Disse che voleva sposarmi.', 'He said that he wanted to marry me.'),
#  ('Io non posso essere suo amico.', "I can't be friends with him."),
#  ('Tom sta solo sprecando tempo, vero?',
#   "Tom is just wasting time, isn't he?"),
#  ('Mary non uccise suo marito.', "Mary didn't kill her husband."),
#  ('Perché quella luce sta lampeggiando?', 'Why is that light flashing?'),
#  ('Lei pensa che Tom sia sdraiato?', 'Do you think Tom is lying?'),
#  ('I linguaggi cambiano nel corso del tempo.', 'Languages change over time.'),
#  ('Mi ha detto che era pronto a farlo.',
#   'He told me he was ready to do that.'),
#  ('Te ne compro uno nuovo.', "I'll buy you a new one."),
#  ('San Pietroburgo è una città russa.', 'St. Petersburg is a Russian city.'),
#  ('Sapete cosa sono questi?', 'Do you know what these are?'),
#  ('Disse che sapeva come mi sentivo.', 'He said he knew how I felt.'),
#  ('Io avrei potuto fare di meglio.', "I could've done better."),
#  ('Ha divorato il suo pasto.', 'He devoured his meal.'),
#  ('Dove avete messo le mie chiavi?', 'Where did you put my keys?'),
#  ('Ne comprerò una.', "I'll buy one."),
#  ('"Ha capito? ""Sì, tutto."""', '"Did you understand? ""Yes, everything."""'),
#  ('La porta è aperta. Andrò a chiuderla.',
#   "The door is open. I'll go and shut it."),
#  ('Mio padre era ancora a casa quando me ne andai.',
#   'My father was still at home when I left.'),
#  ('Loro sanno tutto.', 'They know everything.'),
#  ('Io ho visto veramente un fantasma.', 'I actually saw a ghost.'),
#  ('Forse era lei?', 'Maybe it was her?'),
#  ('Per piacere, mi lasci parlare.', 'Please let me speak.'),
#  ('Devi prenotare in anticipo.', 'You have to book in advance.'),
#  ('Perché non prendiamo un taxi?', "Why don't we take a taxi?"),
#  ('Voi avete paura di loro?', 'Are you afraid of them?'),
#  ('Voi non siete perfetti.', "You aren't perfect."),
#  ('Il segretario del dottor Georges è giapponese.',
#   "Dr. Georges's secretary is Japanese."),
#  ('Non menzioni la guerra!', "Don't mention the war!"),
#  ("Ritagliai l'articolo dalla rivista.",
#   'I cut the article out of the magazine.'),
#  ('Ho analizzato la registrazione.', "I've analyzed the recording."),
#  ('Puoi aprirmi la porta?', 'Can you open the door for me?'),
#  ('Noi non possiamo lavorare in queste condizioni.',
#   "We can't work under these conditions."),
#  ('Tom ha detto a Mary che ero pronto.', 'Tom told Mary that I was ready.'),
#  ('Perché non puoi aiutarmi?', "Why can't you help me?"),
#  ('Hai intenzione di spendere tutti questi soldi?',
#   'Are you going to spend all of this money?'),
#  ('Ti sto mandando una copia della mia lettera.',
#   'I am sending a copy of my letter to you.'),
#  ('Ci infastidisce molto.', 'That bothers us a lot.'),
#  ('Mikey ha tredici anni.', 'Mikey is thirteen.'),
#  ('Apparteneva a mio padre.', 'It belonged to my father.'),
#  ('Non posso vedervi oggi perché mi sento malata.',
#   "I can't see you today because I feel ill."),
#  ('La mia ragazza pianse.', 'My girlfriend cried.'),
#  ('Dove li avete uccisi?', 'Where did you kill them?'),
#  ('Tom si infuriosì.', 'Tom became furious.'),
#  ('Lei è andata a vedere Tom?', 'Did you go to see Tom?'),
#  ('Io spero che nevichi tutta la sera.', 'I hope it snows all night.'),
#  ('Loro sono nemici.', "They're enemies."),
#  ('Perché devi partire oggi?', 'Why do you have to leave today?'),
#  ('Io sono incinta di quattro mesi.', 'I am four months pregnant.'),
#  ('Non compro o vendo niente!', "I don't buy or sell anything!"),
#  ('Dille che sono impegnato.', "Tell her I'm busy."),
#  ('È stata alzata tutta la notte?', 'Have you been up all night?'),
#  ('Per favore, scriva con una penna.', 'Please write with a pen.'),
#  ('È sempre amichevole, vero?', "He's always friendly, isn't he?"),
#  ('Questa è la mia materia preferita.', 'This is my favourite subject.'),
#  ('Sta cercando suo figlio.', "She's looking for her son."),
#  ('Trascorro sempre il giorno di Natale con i miei genitori.',
#   'I always spend Christmas Day with my parents.'),
#  ("Tom l'ha fatto per molti anni.", 'Tom has done that for many years.'),
#  ("Tom canta spesso quand'è sotto la doccia.",
#   "Tom often sings when he's in the shower."),
#  ('Ha guidato la sua macchina sportiva a tutta velocità.',
#   'He drove his sports car at full speed.'),
#  ("Lui non è qualificato per l'impiego.", 'He is not qualified for the job.'),
#  ('Tom ha detto che non era felice qua in Australia.',
#   "Tom said that he wasn't happy here in Australia."),
#  ('Loro si sono rilassate.', 'They relaxed.'),
#  ('Io sono persa.', "I'm lost."),
#  ('Sai dove ha comprato la sua macchina fotografica?',
#   'Do you know where he bought his camera?'),
#  ('Tom è in cucina ad aiutare Mary a cucinare la cena.',
#   'Tom is in the kitchen helping Mary cook dinner.'),
#  ("Lui l'ha spiegato in dettaglio.", 'He explained it in detail.'),
#  ('Lei è stata invitata alla sua festa di compleanno?',
#   'Were you invited to her birthday party?'),
#  ('Avete un problema con me?', 'Do you have a problem with me?'),
#  ('Le mostrò il suo tatuaggio.', 'He showed her his tattoo.'),
#  ('Ha smesso di parlare.', 'You stopped to talk.'),
#  ('Non ho alcuna amica.', 'I have no friends.'),
#  ('Ha preparato il caffè stamattina?', 'Did you make coffee this morning?'),
#  ('Riescono a capirmi.', 'They can understand me.'),
#  ('Lei è troppo modesto.', "You're too modest."),
#  ('Gioca a pallacanestro?', 'Do you play basketball?'),
#  ('Di quanti soldi avrete bisogno?', 'How much money will you need?'),
#  ('Grazie per i vostri affari.', 'Thanks for your business.'),
#  ('Sapete chi ha vinto la gara?', 'Do you know who won the race?'),
#  ('Io mi farò dare un passaggio da lui.', "I'll catch a ride with him."),
#  ('Questo è il suo ombrello, giusto?', 'This is his umbrella, right?'),
#  ('Questo ti ha sorpreso?', 'Did that surprise you?'),
#  ('Amare è vedere lei anche nei tuoi sogni.',
#   'Love is seeing her even in your dreams.'),
#  ('Scommetto che sei molto cambiata. Immagino che bella ragazza sei diventata...',
#   "I guess you have changed a lot. I imagine what kind of beautiful young lady you've become..."),
#  ('Tom ha guardato attraverso il suo microscopio.',
#   'Tom looked through his microscope.'),
#  ('Vi deve piacere Tom.', "You've got to like Tom."),
#  ('È troppo tardi per dire che mi dispiace?',
#   "Is it too late to say I'm sorry?"),
#  ('Stiamo affrontando una violenta crisi.', 'We are facing a violent crisis.'),
#  ('Portatela lontano da qua.', 'Get her away from here.'),
#  ('Tom mi mandò qualche fiore.', 'Tom sent me some flowers.'),
#  ('Noi non potevamo vedere niente.', 'We could see nothing.'),
#  ('Pensiamo anche che sia un bastardo.', "We also think that he's a bastard."),
#  ('Faccio colazione prima del lavoro.', 'I eat breakfast before work.'),
#  ('Tu hai bevuto molto?', 'Did you drink a lot?'),
#  ('Avete già trovato qualcosa?', 'Have you found anything yet?'),
#  ('Vai e sii felice!', 'Go and be happy!'),
#  ('Sei materialistico.', "You're materialistic."),
#  ('Loro sono cristiani.', 'They are Christians.'),
#  ('Vi siete divertite a Boston?', 'Did you have fun in Boston?'),
#  ('Sono bassa.', "I'm short."),
#  ("Il gioco d'azzardo è una maledizione.", 'Gambling is a curse.'),
#  ('Non lo dovranno fare loro stesse.',
#   "They won't have to do that themselves."),
#  ('Questo è il pupazzo di neve più brutto che io abbia mai visto!',
#   "This is the ugliest snowman I've ever seen!"),
#  ('Io volevo farlo.', 'I wanted to do it.'),
#  ('Lei non ha molti amici.', "She doesn't have many friends."),
#  ('Abbiamo giudicato male Tom.', 'We misjudged Tom.'),
#  ('Non sapevo che Tom fosse grasso.', "I didn't know Tom was fat."),
#  ('Ha fatto bene la sua parte.', 'She did her part well.'),
#  ('Perché Fadil è qui?', 'Why is Fadil here?'),
#  ('Disse a tutti che aveva freddo.', 'He told everyone he was cold.'),
#  ('La state turbando.', "You're upsetting her."),
#  ('È probabile che sia quello che ho visto.', 'That is likely what I saw.'),
#  ('Tom si grattò.', 'Tom scratched himself.'),
#  ("È vicina ai sessant'anni.", 'She is close to sixty.'),
#  ('Da dove inizio?', 'Where do I begin?'),
#  ('La lista era infinita.', 'The list was endless.'),
#  ('Gli comprerò una birra.', "I'll buy him a beer."),
#  ('Mi vendettero la loro vecchia automobile.',
#   'They sold their old car to me.'),
#  ('Tom sembrava davvero imbarazzato.', 'Tom looked really embarrassed.'),
#  ('Non riesco a farli rallentare.', "I can't get them to slow down."),
#  ('Io penso che Tom mi ami.', 'I think Tom loves me.'),
#  ('Voi ragazzi non avete niente di meglio da fare?',
#   "Don't you guys have anything better to do?"),
#  ("Non c'è ragione di tenerlo segreto.",
#   "There's no reason to keep it a secret."),
#  ('Mi creda. Sarò un uomo nuovo.', "Believe me. I'll be a new man."),
#  ('Dovrete trovarlo.', 'You have to find him.'),
#  ('Io sto parlando al telefono con Tom.', "I'm talking to Tom on the phone."),
#  ('A Mary piace la neve.', 'Mary likes snow.'),
#  ('Ho imparato a farlo tre anni fa.', 'I learned to do that three years ago.'),
#  ('Cosa ne sarà di lui?', 'What will become of him?'),
#  ('So tutto della festa.', 'I know all about the party.'),
#  ('Tom sta sventolando una bandiera.', 'Tom is waving a flag.'),
#  ('Lei ha paura della morte?', 'Are you afraid of death?'),
#  ('La allerterò.', "I'll alert her."),
#  ('Tom addestrò il suo cane ad abbaiare agli estranei',
#   'Tom conditioned his dog to bark at strangers.'),
#  ('Non litighi con una donna quando è stanca.',
#   "Don't argue with a woman when she's tired."),
#  ('Tutti sono rimasti calmi.', 'Everyone stayed calm.'),
#  ('Come sta tua moglie?', "How's your wife?"),
#  ('Viviamo vicino a una grande biblioteca.', 'We live near a big library.'),
#  ('Non dipendeva più dai suoi genitori.',
#   'He was no longer dependent on his parents.'),
#  ('Hanno detto che non sono esperte.', "They said that they're no expert."),
#  ('Perché Tom si è scusato?', 'Why did Tom apologize?'),
#  ('Sembra che ci sarà il sole.', "It looks like it's going to be sunny."),
#  ('Sta piangendo?', 'Is he crying?'),
#  ('Chi le ha detto che poteva venire?', 'Who told you you could come?'),
#  ('Lo vedrò di nuovo.', "I'll see him again."),
#  ('Il ponte collega le due città.', 'The bridge connects the two cities.'),
#  ('Vorrei sapere come ha avuto il mio numero.',
#   "I'd like to know how you got my number."),
#  ('Devo pulire la camera?', 'Shall I clean the room?'),
#  ('Vada a sedersi.', 'Go sit down.'),
#  ('Lui viaggiava per lavoro.', 'He traveled on business.'),
#  ('Uscendo dal liceo, andai a Tokyo.',
#   'On leaving high school, I went to Tokyo.'),
#  ('Sia Tom che Mary si sono coperti gli occhi.',
#   'Tom and Mary both covered their eyes.'),
#  ('Ero scioccata.', 'I was shocked.'),
#  ('I cavalli sono degli animali molto sensibili.',
#   'Horses are very sensitive animals.'),
#  ('Voi siete state drogate.', "You've been drugged."),
#  ('Fatta eccezione per alcune nuvole sottilissime, il cielo era limpido e azzurro.',
#   'Except for a few gossamer clouds, the sky was clear and blue.'),
#  ('Tom ci ha detto che amava sciare.', 'Tom told us he loved skiing.'),
#  ('Vi ho detto delle cose così orribili.',
#   'I said such horrible things to you.'),
#  ('Penso che andrò a parlare con Tom.', "I think I'll go talk to Tom."),
#  ('Non sono brava a nuotare.', "I'm not good at swimming."),
#  ('Tom ha promesso di salvare Mary.', 'Tom vowed to rescue Mary.'),
#  ('Noi siamo molto dispiaciuti per la sua perdita.',
#   "We're very sorry for your loss."),
#  ('Non dovresti guidare.', "You shouldn't drive."),
#  ('Mi feci un sandwich al tacchino.', 'I made myself a turkey sandwich.'),
#  ('Dice che non sarà qua domani.', "She says she won't be here tomorrow."),
#  ('Si barricò nella sua stanza.', 'She barricaded herself in his room.'),
#  ('Quando divento grande, mi sposerò con Tom.',
#   "When I grow up, I'm going to get married to Tom."),
#  ('Questo è ciò che ha pitturato.', 'This is what he painted.'),
#  ('Tom e Mary cosa stanno cercando di fare?',
#   'What are Tom and Mary trying to do?'),
#  ('È troppo anziano per me.', "He's too old for me."),
#  ('Tom mi dà davvero sui nervi.', 'Tom really gets on my nerves.'),
#  ('Penso che comprerò questo paio di scarpe.',
#   "I think I'll buy this pair of shoes."),
#  ('Non lo sottovaluti.', "Don't underestimate him."),
#  ('È la rappresentante ufficiale di Tatoeba.',
#   "She's the official spokesperson for Tatoeba."),
#  ("Mary l'ha vista all'aeroporto.", 'Mary saw her at the airport.'),
#  ('Tom ha tutto sotto controllo.', "Tom's got everything under control."),
#  ('Era nella fila.', 'He was in the queue.'),
#  ('Tu non ami nessuno tranne che te stesso.', 'You only love yourself.'),
#  ('Ha mai provato a leccare il sapone?', 'Have you ever tried licking soap?'),
#  ('Hai delle amiche?', 'Do you have any friends?'),
#  ('Sarò di ritorno quando ho finito.', "I'll be back when I'm done."),
#  ('Non rimpiango niente.', "I don't regret anything."),
#  ('Tom si addormentò in classe.', 'Tom fell asleep in class.'),
#  ('Tom e Mary ci hanno sorpresi tutti quando sono andati a Boston.',
#   'Tom and Mary surprised all of us when they went to Boston.'),
#  ('Era dolorosamente ovvia.', 'It was painfully obvious.'),
#  ("Andrò all'aeroporto.", "I'm going to go to the airport."),
#  ('Non è stata una decisione difficile.', "That wasn't a tough decision."),
#  ('Ha detto che lo farebbe per noi.', 'She said she would do that for us.'),
#  ('Combatti!', 'Fight!'),
#  ('Amava le sue nipoti.', 'He loved his grandchildren.'),
#  ('Loro non hanno corso.', "They didn't run."),
#  ("L'ha rapito?", 'Did you kidnap him?'),
#  ('Tu andrai a nuotare?', 'Are you going to go swimming?'),
#  ("Non c'erano problemi veri e propri.", 'There were no real problems.'),
#  ('No, non devi andarci adesso.', 'No, you need not go right now.'),
#  ('Questo ti divertirà.', 'This will amuse you.'),
#  ('Perché la gente si stringe la mano?', 'Why do people shake hands?'),
#  ('Tom ha risposto in francese.', 'Tom replied in French.'),
#  ("L'ho visto nello spettacolo ieri.", 'I saw you in the show yesterday.'),
#  ('Ha detto che non era felice qui.', "She said she wasn't happy here."),
#  ('Disse a tutti che aveva paura.', 'He told everybody he was afraid.'),
#  ("Dov'è l'ufficio di Tom Jackson?", "Where is Tom Jackson's office?"),
#  ('Lo amereste.', "You'd love it."),
#  ('In che stanza è Tom?', 'What room is Tom in?'),
#  ('Vi odio!', 'I hate you!'),
#  ('Ci sono troppe cose che non so.', "There's too much I don't know."),
#  ("Ho un po' di denaro questo mese.", 'I have a little money this month.'),
#  ('Conoscete il segreto di Tom?', "Do you know Tom's secret?"),
#  ('Posso sedermi dietro di voi?', 'May I sit behind you?'),
#  ('Il costo del libro è di 4 dollari.', 'The cost of the book is 4 dollars.'),
#  ("L'ho lasciata sul tavolo.", 'I left it on the table.'),
#  ('Perché lei è in chiesa?', 'Why are you in the church?'),
#  ('Sami non lascerà mai Layla.', 'Sami will never leave Layla.'),
#  ('Si perse in città.', 'He got lost in the city.'),
#  ('La porta della stanza di Tom era chiusa.',
#   "The door to Tom's room was closed."),
# ...
#  ('Qual è il suo scioglilingua preferito?',
#   "What's your favorite tongue twister?"),
#  ('Sembri impegnato.', 'You seem busy.'),
#  ('Ho comprato una seconda racchetta da badminton per me stessa, però ho scordato di comprare un volano.',
#   'I bought a second badminton racket for myself, but I forgot to buy a shuttlecock.'),
#  ('Sei dopo di lui.', "You're after him."),
#  ("Qual è l'idea?", "What's the idea?"),
#  ('Perché non volete farlo?', 'Why do you not want to do that?'),
#  ('Non siete già annoiati?', "Aren't you bored yet?"),
#  ('A metà della mia classe piacciono i cani.', 'Half of my class like dogs.'),
#  ('Tom non stava traslocando.', "Tom wasn't moving."),
#  ('Lo so qual è il suo problema.', 'I know what your problem is.'),
#  ('È la mia ispirazione.', "You're my inspiration."),
#  ('Non posso immaginarlo.', "I can't imagine it."),
#  ('Dite loro perché.', 'Tell them why.'),
#  ('Loro vi pagano bene.', 'They pay you well.'),
#  ('Tom pensava che a Mary sarebbe piaciuta la cucina indonesiana.',
#   'Tom thought that Mary would like Indonesian food.'),
#  ("Non posso essere d'accordo con loro.", "I can't agree with them."),
#  ('Spinse via il suo piatto.', 'He pushed away his plate.'),
#  ('Perché non ti calmi?', "Why don't you calm down?"),
#  ("Tom è arrivato all'albergo.", 'Tom arrived at the hotel.'),
#  ('Non li potete licenziare.', "You can't fire them."),
#  ('Tom ha trascorso molto tempo con Mary recentemente.',
#   'Tom has been spending a lot of time with Mary recently.'),
#  ('Si chiuse fuori dalla sua casa.', 'He locked himself out of his house.'),
#  ('Noi abbiamo solo delle informazioni di seconda mano sul colpo di Stato.',
#   'We only have secondhand information of the coup.'),
#  ('Non ti preoccupare per quello.', "Don't worry about that."),
#  ('Non parliamo la stessa lingua.', "We don't speak the same language."),
#  ('Tom non ha intenzione di essere lì.', "Tom doesn't plan to be there."),
#  ('Dammela.', 'Give it to me.'),
#  ('Tom mi disse che odiava il Natale.',
#   'Tom told me that he hated Christmas.'),
#  ('Spero non si sia rotto niente.', "I hope nothing's been broken."),
#  ('Sta parlando con me?', 'Are you talking to me?'),
#  ('Tom voleva avere molti figli.', 'Tom wanted to have a lot of children.'),
#  ('Assicuratevi di essere qui in orario.', "Make sure you're here on time."),
#  ('Nessuno si aspettava che vincessero.', 'No one expected them to win.'),
#  ('Ha detto che non è arrabbiato.', "He said that he isn't angry."),
#  ('Voi non dovete aiutarmi.', "You don't have to help me."),
#  ("Io non ho un'assicurazione.", 'I have no insurance.'),
#  ('Per piacere, ricordati di svegliarmi alle sette domattina.',
#   'Please remember to wake me up at seven tomorrow morning.'),
#  ('Ci fidavamo di lei.', 'We trusted her.'),
#  ("È caduto all'indietro.", 'He fell backward.'),
#  ('Ci divertiremo così tanto!', "We're going to have so much fun!"),
#  ('Perderai il tuo lavoro.', "You're going to lose your job."),
#  ('Lasciami dormire per altri dieci minuti.',
#   'Let me sleep for another ten minutes.'),
#  ('Non siamo qui da molto tempo. Siamo qui solo da dieci minuti. Siamo arrivati alle 10:40.',
#   "We haven't been here for long. We've only been here for ten minutes. We got here at 10:40."),
#  ('Resto a casa.', 'I am staying home.'),
#  ('È calmo qui di notte.', 'It is quiet here at night.'),
#  ('Come le aiuterete?', 'How are you going to help them?'),
#  ('Tom sembra aver visto un fantasma.', "Tom looks like he's seen a ghost."),
#  ('Ho sempre voluto conoscere Tom.', "I've always wanted to meet Tom."),
#  ('Mi disse che suo padre era un dottore.',
#   'He told me that his father was a doctor.'),
#  ('Io abito piuttosto vicino a loro.', 'I live pretty close to them.'),
#  ('Tom dice che non voterà.', "Tom says he won't vote."),
#  ('Si è arreso.', 'He gave up.'),
#  ("Io non l'ho mai conosciuto.", 'I never knew him.'),
#  ('Perché siete in Australia ora?', 'Why are you in Australia now?'),
#  ('La collina ha bruciato per tutta la notte.',
#   'The hillside burned all night.'),
#  ('Deve studiare più duramente.', 'You must study harder.'),
#  ('Non ti appartiene.', "It doesn't belong to you."),
#  ('Tom fu colto di sorpresa.', 'Tom was caught by surprise.'),
#  ('Tutto ciò che potete fare è aspettare.', 'All you can do is wait.'),
#  ('Tutti volevano farlo.', 'Everybody wanted to do that.'),
#  ('È in ufficio.', 'He is at the office.'),
#  ('Loro non sono pronti per nulla.', "They aren't ready for anything."),
#  ('Piace veramente a tutti.', 'Everyone really likes it.'),
#  ('Noi perdemmo la scommessa.', 'We lost the bet.'),
#  ("Io sono allergica all'aspirina, alla penicillina e ai sulfanilamidi.",
#   'I am allergic to aspirin, penicillin, and sulfa drugs.'),
#  ('Salutate vostra sorella da parte mia.', 'Say hello to your sister for me.'),
#  ('Ha detto che gli piace la pizza.', 'He said he likes pizza.'),
#  ('Verranno forniti i materiali.', 'Materials will be provided.'),
#  ('Sei splendida e ti amo molto.', "You're gorgeous and I love you bunches."),
#  ('Per piacere, mi dia il libro.', 'Please give me the book.'),
#  ("Sono in sciopero dall'8 al 12 dicembre.",
#   "I'm striking from December 8th through the 12th."),
#  ('Ha preso una giornata libera.', "You've taken a day off."),
#  ('Conoscete la famiglia?', 'Do you know the family?'),
#  ('Non mi aspettavo di vedervi in un posto come questo.',
#   "I didn't expect to see you at a place like this."),
#  ('Fareste meglio ad alzarvi presto.', "You'd better get up early."),
#  ('"Dio ti benedica. ""Io sono ateo."""',
#   '"God bless you. ""I\'m an atheist."""'),
#  ('Seguiamola.', "Let's follow her."),
#  ('Lasciatele riposare.', 'Let them rest.'),
#  ('Tom morirà, vero?', "Tom is going to die, isn't he?"),
#  ('Tom chiamò suo figlio John.', 'Tom named his son John.'),
#  ('Tom non è giusto.', "Tom isn't fair."),
#  ('Tom si è sposato troppo giovane.', 'Tom married too young.'),
#  ('Sono grande.', "I'm big."),
#  ("Io ve l'ho detto che Tom era pronto.", 'I told you Tom was ready.'),
#  ('Date a Tom e Mary le loro chiavi.', 'Give Tom and Mary their keys.'),
#  ('Si stanno addestrando.', "They're training."),
#  ('Mi aiuterete con i miei compiti?', 'Will you help me with my homework?'),
#  ('Tom era troppo stanco per studiare.', 'Tom was too tired to study.'),
#  ('Tutta questa roba è mia.', 'All this stuff is mine.'),
#  ('Noi ce ne assicurammo.', 'We made sure of it.'),
#  ('Io le ho dato la mia metà.', 'I gave my half to her.'),
#  ('Sami aveva un alibi ben documentato.', 'Sami had a well documented alibi.'),
#  ('Fingetelo e basta.', 'Just fake it.'),
#  ('Tom diede una mela a Mary.', 'Tom gave Mary an apple.'),
#  ('Hai capito tutto?', 'Did you understand everything?'),
#  ('Si mise le sue scarpe nuove.', 'She put on her new shoes.'),
#  ('Che cibi evita di mangiare?', 'What foods do you avoid eating?'),
#  ("L'hai spaventato.", 'You scared him.'),
#  ('Non ero contento.', 'I was not pleased.'),
#  ("In Tatoeba c'è un eccellente insegnante di Toki Pona di nome Tepan.",
#   'At Tatoeba there is a great Toki Pona teacher named Tepan.'),
#  ('Sono astigmatico.', 'I am astigmatic.'),
#  ('Grazie per le sue parole gentili.', 'Thank you for your kind words.'),
#  ("Non c'erano taxi, quindi sono dovuto andare a casa a piedi.",
#   'There was no taxi, so I had to walk home.'),
#  ('Io non riesco a proteggere Tom.', "I can't protect Tom."),
#  ('Sono scosso.', "I'm shaken."),
#  ('Mio nonno ha i capelli bianchi come la neve.',
#   'My grandfather has snowy white hair.'),
#  ('Lui aveva qualcosa in mano.', 'He had something in his hand.'),
#  ('Dice che le manca molto la sua famiglia.',
#   'She says she misses her family a lot.'),
#  ('Ci ha chiesto di aiutarla.', 'She asked us to help her.'),
#  ('Ma perché il francese è così difficile?',
#   'But why is French so difficult?'),
#  ('Ha dormito molto la scorsa notte?', 'Did you sleep much last night?'),
#  ('A Mary piace fare quasi tutto da sola.',
#   'Mary likes to do almost everything by herself.'),
#  ('Lui guida molto veloce.', 'He drives very fast.'),
#  ('Sono così imbarazzata.', "I'm so embarrassed."),
#  ('Dammi la tua opinione, per favore.', 'Give me your opinion, please.'),
#  ('Tom è certo.', 'Tom is certain.'),
#  ('Tom ha detto che non doveva più preoccuparsi per Mary.',
#   "Tom said he didn't have to worry about Mary anymore."),
#  ('Ho vinto.', 'I have won.'),
#  ('Amo il suo cappello.', 'I love your hat.'),
#  ('Vado a lavorare in bici.', 'I ride a bike to work.'),
#  ('Mi sono rotto il braccio.', 'I fractured my arm.'),
#  ('Io leggerò un libro.', "I'm going to read a book."),
#  ('Sai chi vive qua?', 'Do you know who lives here?'),
#  ('Tom non è così ottuso.', "Tom isn't that dumb."),
#  ('Imparò la poesia a memoria.', 'He learned the poem by heart.'),
#  ('Tu eri ammalata.', 'You were sick.'),
#  ('Mi sposerà?', 'Will you marry me?'),
#  ('Andateglielo a dire.', 'Go and tell him.'),
#  ('La stanno inseguendo tutte.', "They're all chasing her."),
#  ('Tom non ha fatto nulla finora.', "Tom hasn't done anything so far."),
#  ('Non sono sicuro di poterlo fare.', "I'm not sure I can do that."),
#  ('Io non penso che Tom sia pronto.', "I don't think Tom is ready."),
#  ('Questo richiede che io abbia delle amiche?',
#   'Does this require me to have friends?'),
#  ('La aiuto quasi ogni giorno.', 'I help her almost every day.'),
#  ('Vai a vederla.', 'Go see her.'),
#  ('Faccia ciò che è giusto.', 'Do that which is right.'),
#  ('Mi dispiace di essere così in ritardo.', "I'm sorry to be so late."),
#  ('Voglio stringerle.', 'I want to hold them.'),
#  ('Le avete detto qualcosa?', 'Have you said anything to her?'),
#  ('Se non conosci il significato di una parola, cercala in un dizionario.',
#   "If you don't know the meaning of a word, look it up in a dictionary."),
#  ('Problema risolto!', 'Problem solved!'),
#  ('Ha detto che sarebbe venuto domani.', "He said that he'd come tomorrow."),
#  ('Nessuno sa il suo nome.', 'No one knows his name.'),
#  ('Fadil non era a casa.', "Fadil wasn't home."),
#  ('Tom è sposato con un insegnante delle superiori.',
#   'Tom is married to a high school teacher.'),
#  ('Tu devi tenerti le mani pulite.', 'You must keep your hands clean.'),
#  ('"Ha rotto con te? ""Sì, e ora il mio cuore è pesante come il piombo."""',
#   '"Has he broken up with you? ""Yes, and now my heart is heavy as lead""."'),
#  ('Sta andando allo Chiba Stadium.', 'She is going to Chiba Stadium.'),
#  ('Porti a casa tutte le truppe.', 'Bring home all the troops.'),
#  ('Non mi odi.', "Don't hate me."),
#  ('Voi siete più intelligenti di Tom.', "You're smarter than Tom is."),
#  ('Mi promise che avrebbe vinto.', "He promised me he'd win."),
#  ("Lei è in ritardo con l'affitto.", 'She is behind in her rent.'),
#  ('Tom e Mary dissero a John perché volevano farlo.',
#   'Tom and Mary told John why they wanted to do that.'),
#  ("C'è un ostello della gioventù da queste parti?",
#   'Is there a youth hostel around here?'),
#  ('Mi hanno fuorviata.', 'They misled me.'),
#  ('Non sanno che sono giapponese.', "They don't know that I'm Japanese."),
#  ('Era esausta.', 'You were exhausted.'),
#  ("Dopo aver passato l'esame di guida ha comprato una macchina.",
#   'After she had passed her driving test, she bought a car.'),
#  ('Pensavo foste arrabbiate con lui.', 'I thought you were mad at him.'),
#  ("Perché vivevate a Boston l'anno scorso?",
#   'Why were you living in Boston last year?'),
#  ("Cos'è importante per lei?", 'What is important for you?'),
#  ('Anche io volevo vederli.', 'I wanted to see them, too.'),
#  ('Chi stiamo aspettando?', 'Who are we waiting for?'),
#  ('Lui portò la sua famiglia allo zoo.', 'He took his family to the zoo.'),
#  ('Mi dispiace di contraddirla.', "I'm sorry to contradict you."),
#  ('Tom è sveglio?', 'Is Tom awake?'),
#  ('Voi siete famosi.', "You're famous."),
#  ('Tom non ha mai giocato a golf.', 'Tom has never played golf.'),
#  ('È mai scivolata su una buccia di banana?',
#   'Have you ever slipped on a banana peel?'),
#  ('Sono venuta qui per parlare con loro.', 'I came here to talk to them.'),
#  ('Mi puoi aiutare a ottenere un rimborso?', 'Can you help me get a refund?'),
#  ("Dove vuole che vada? Su un'isola deserta?",
#   'Where do you want me to go? To a desert island?'),
#  ('Abitate da queste parti?', 'Do you live around here?'),
#  ('È arrivato là prima di noi.', 'He arrived there before us.'),
#  ('Mi disse che era occupato in quel momento.',
#   'He told me that he was busy then.'),
#  ('Sono convinto della vostra innocenza.',
#   'I am convinced of your innocence.'),
#  ('È semplicemente stupida.', "It's just stupid."),
#  ('Abitavo qua.', 'I lived here.'),
#  ('Io incontro persone nuove ogni giorno.', 'I meet new people every day.'),
#  ('Che brutto cane!', 'What an ugly dog!'),
#  ('Qual era il segreto di Tom?', "What was Tom's secret?"),
#  ('Era sua abitudine alzarsi presto.', 'It was his habit to rise early.'),
#  ('Tom ha un appuntamento alle 2:30.', 'Tom has an appointment at 2:30.'),
#  ('Sono troppo stanca per farlo adesso.', "I'm too tired to do that now."),
#  ('Perché sono arrabbiati?', 'Why are they angry?'),
#  ('Dove erano tutti?', 'Where was everyone?'),
#  ('Voi avete mai mangiato del cibo turco prima?',
#   'Have you ever eaten Turkish food before?'),
#  ('Non penso sia pericoloso.', "I don't think it's dangerous."),
#  ('Tom deve a tutti tre dollari.', 'Tom owes everyone three dollars.'),
#  ('Tom non è molto alto.', 'Tom is not very tall.'),
#  ('Non provi mai a morire.', 'Never try to die.'),
#  ("Penso che Tom e Mary vengano dall'Australia, ma non sono sicuro.",
#   "I think Tom and Mary are from Australia, but I'm not sure."),
#  ('Mi scuso se vi ho offesi.', 'I apologize if I offended you.'),
#  ('Ha la voce morbida e chiara.', 'She has a soft and clear voice.'),
#  ('Tom sta perdendo interesse.', 'Tom is losing interest.'),
#  ('È così strano.', "It's so strange."),
#  ('Dove compri i tuoi dizionari?', 'Where do you buy your dictionaries?'),
#  ('Si preoccupa troppo per lei.', 'You worry too much about her.'),
#  ('Vi ricordate il suo cognome?', 'Do you remember his last name?'),
#  ('Vuole comprare una collana di perle per sua moglie.',
#   'He wants to buy a pearl necklace for his wife.'),
#  ('A me non serve molto altro.', "I don't need much else."),
#  ('Quale altra scelta avevo?', 'What other choice did I have?'),
#  ('Non mi posso sposare con Tom.', "I can't marry Tom."),
#  ('Cosa darà a loro?', "What'll you give them?"),
#  ('Il presidente attualmente è a Miami.',
#   'The president is presently in Miami.'),
#  ('Ho fiducia nelle capacità di Tom.',
#   "I have confidence in Tom's abilities."),
#  ("Perché guarda solo i film dell'orrore?",
#   'Why do you only watch horror movies?'),
#  ('Dove ha imparato a sparare?', 'Where did he learn to shoot?'),
#  ('Farei lo stesso.', 'I would do the same.'),
#  ('Ero lì con lui.', 'I was there with him.'),
#  ("È un po' insipido.", "It's a little bland."),
#  ('Tom ha il singhiozzo.', 'Tom has hiccups.'),
#  ('Le avete detto cosa fare?', 'Have you told her what to do?'),
#  ("Mostrami qualcosa di un po' più grande.",
#   'Show me something a little larger.'),
#  ('È ancora nel carcere, vero?', "She's still in the prison, isn't she?"),
#  ("Abbiamo un'ora per trovarle.", "We've got one hour to find them."),
#  ('Sembrava che Tom e Mary fossero furiosi.',
#   'Tom and Mary looked like they were furious.'),
#  ('Lavoravo per una piccola azienda a Boston.',
#   'I used to work for a small company in Boston.'),
#  ("Noi abbiamo un po' di tempo per rilassarci.",
#   "We've got a little time to relax."),
#  ('Io ho preparato degli spaghetti.', 'I made spaghetti.'),
#  ('Persi il treno delle 7.', 'I missed the 7:00 train.'),
#  ('Lei lo beccò mentre fumava una sigaretta.',
#   'She caught him smoking a cigarette.'),
#  ('Non dovresti bere a stomaco vuoto.',
#   "You shouldn't drink on an empty stomach."),
#  ('Ha detto che non può fidarsi di se stesso.',
#   "He says he can't trust himself."),
#  ('Lo avete chiesto a lei?', 'Did you ask her?'),
#  ('Ma, io non mangio neanche un piccolo pezzo di carne.',
#   "But, I don't eat even a little bit of meat."),
#  ('Parla in berbero.', 'Speak Berber.'),
#  ('Lei è una brava persona.', 'You are a good person.'),
#  ('Il francese è insegnato a scuola?', 'Is French taught at school?'),
#  ...]

# %% [markdown]
# ### **Question 2: Pre-trained MT models**
#
# Pre-trained MT models are released to the public to allow researchers to experiment with them. In this question you will load a pre-trained MT model and use it to translate sentences from Italian to English and vice-versa.
#
# [EasyNMT](https://github.com/UKPLab/EasyNMT) is a Python library that provides an easy-to-use interface to pre-trained MT models. It provides a simple wrapper over HuggingFace transformers library for machine translation. In this question you will use EasyNMT to load a pre-trained MT model and translate sentences from Italian to English and vice-versa:
#
# - Load the pre-trained model for a specific direction (e.g., Italian-English or English-Italian)
# - Translate all the sentences in the test set from the source language to the target language.
#
#
# **Note 1**: the choice for the MT model is up to you.
#
# **Note 2**: store the translated sentences in both directions using the data structure of your choice.

# %%
# your code here
from easynmt import EasyNMT
model = EasyNMT('opus-mt')

# %%
# Italian to English
predictions_en = []
for sentence_pair in train_data[:50]:
    source, target = sentence_pair
    print(f'Input: {source}')
    print(f'Target: {target}')
    print(f'Prediction: {model.translate(source, target_lang="en", source_lang="it")}')
    predictions_en.append(model.translate(source, target_lang="en", source_lang="it"))
print("For FINISHED")

# English to Italian
predictions_it = []
for sentence_pair in train_data[:50]:
    target, source = sentence_pair
    print(f'Input: {target}')
    print(f'Target: {source}')
    print(f'Prediction: {model.translate(target, target_lang="it",source_lang="en")}')
    predictions_it.append(model.translate(target, target_lang="it", source_lang="en"))
# Out:
# Input: Li aiuteremo domani.
# Target: We'll help them tomorrow.
# Prediction: We'll help them tomorrow.
# Input: Tu guardi spesso la TV?
# Target: Do you watch TV often?
# Prediction: Do you watch TV often?
# Input: Rovesciò il suo drink sul mio smoking.
# Target: She spilled her drink all over my tuxedo.
# Prediction: He spilled his drink in my tuxedo.
# Input: Rimanete in contatto con me.
# Target: Keep in touch with me.
# Prediction: Stay in touch with me.
# Input: Quale cane è il vostro?
# Target: Which dog is yours?
# Prediction: Which dog is yours?
# Input: C'erano alcuni fiori lì.
# Target: There were some flowers there.
# Prediction: There were some flowers there.
# Input: C'è del traffico pesante su questa strada.
# Target: There is heavy traffic on this street.
# Prediction: There's heavy traffic on this road.
# Input: Lui ha precisato che il viaggio costerà 300 euro.
# Target: He made it clear that the trip will cost 300 euros.
# Prediction: He pointed out that the trip will cost 300 euros.
# Input: Io sono un po' arrabbiato con te.
# Target: I'm a little angry with you.
# Prediction: I'm a little angry with you.
# Input: Tom passa meno tempo a studiare francese di me.
# Target: Tom spends less time studying French than I do.
# Prediction: Tom spends less time studying French than I do.
# Input: Ho visto un ragazzino correre.
# Target: I saw a little boy running.
# Prediction: I saw a kid run.
# Input: È quasi estate.
# Target: It's almost summertime.
# Prediction: It's almost summer.
# Input: Tom ama i film sugli zombie e li guarda ogni volta che può.
# Target: Tom loves zombie movies and watches them whenever he can.
# Prediction: Tom loves zombie movies and watches them whenever he can.
# Input: Tom ha detto a Mary di aiutare John.
# Target: Tom told Mary to help John.
# Prediction: Tom told Mary to help John.
# Input: La fermammo.
# Target: We stopped it.
# Prediction: We stopped her.
# Input: L'ho incontrato mentre studiava.
# Target: I met him while he was studying.
# Prediction: I met him while he was studying.
# Input: Lo incontrerai.
# Target: You'll meet him.
# Prediction: You'll meet him.
# Input: Dovrà farlo da qualche altra parte.
# Target: You'll have to do that elsewhere.
# Prediction: He's gonna have to do it somewhere else.
# Input: Può essere pericoloso.
# Target: It can be dangerous.
# Prediction: It can be dangerous.
# Input: Assomiglia a suo fratello.
# Target: He looks like his brother.
# Prediction: He looks like his brother.
# Input: Tom ritornò in Australia per essere con me.
# Target: Tom returned to Australia to be with me.
# Prediction: Tom returned to Australia to be with me.
# Input: Ha smesso di correre.
# Target: He quit running.
# Prediction: He stopped running.
# Input: Loro cosa stanno nascondendo?
# Target: What are they hiding?
# Prediction: What are they hiding?
# Input: Tom sta chiedendo il permesso,
# Target: Tom is asking permission.
# Prediction: Tom is asking permission,
# Input: Posso venire?
# Target: Can I come?
# Prediction: Can I come?
# Input: La catturarono.
# Target: They captured her.
# Prediction: They caught her.
# Input: Tom e Mary saranno di nuovo in ritardo.
# Target: Tom and Mary are going to be late again.
# Prediction: Tom and Mary will be late again.
# Input: Lui stava lavorando in ufficio ieri sera.
# Target: He was working at the office yesterday evening.
# Prediction: He was working at the office last night.
# Input: Che succede la settimana prossima?
# Target: What's happening next week?
# Prediction: What's going on next week?
# Input: Molti contadini sono morti durante la siccità.
# Target: Many peasants died during the drought.
# Prediction: Many peasants died during the drought.
# Input: Stai entrando?
# Target: Are you coming in?
# Prediction: Are you coming in?
# Input: Qual è la cosa migliore che hai mai ricevuto per Natale?
# Target: What's the best thing you've ever gotten for Christmas?
# Prediction: What's the best thing you've ever had for Christmas?
# Input: Tom è piuttosto occupato in questo momento.
# Target: Tom's rather busy just now.
# Prediction: Tom is pretty busy right now.
# Input: Ha detto che era infelice.
# Target: She said that she was unhappy.
# Prediction: She said she was unhappy.
# Input: Sarà impegnativo resistere alla tentazione.
# Target: It will be difficult to resist the temptation.
# Prediction: It will be challenging to resist temptation.
# Input: Non prendo ordini da lei.
# Target: I don't take orders from you.
# Prediction: I don't take orders from you.
# Input: Tom si fece male al ginocchio sinistro durante l'allenamento, così John dovette giocare al posto suo.
# Target: Tom hurt his left knee during practice, so John had to play the game in his place.
# Prediction: Tom hurt his left knee during training, so John had to play for him.
# Input: Io mi chiamo Lin Feng.
# Target: I am called Lin Feng.
# Prediction: My name is Lin Feng.
# Input: Dormii a lungo?
# Target: Did I sleep long?
# Prediction: Did I sleep long?
# Input: Disegnami una pecora!
# Target: Draw me a sheep!
# Prediction: Draw me a sheep!
# Input: Tom sta cercando una via d'uscita.
# Target: Tom is searching for a way out.
# Prediction: Tom is looking for a way out.
# Input: Tom non è associato a Disneyland.
# Target: Tom is not affiliated with Disneyland.
# Prediction: Tom isn't associated with Disneyland.
# Input: Vengono dall'Italia.
# Target: They are from Italy.
# Prediction: They're from Italy.
# Input: Tom prese su il telefono.
# Target: Tom picked up the phone.
# Prediction: Tom picked up the phone.
# Input: Lui non uscirebbe.
# Target: He would not go out.
# Prediction: He wouldn't go out.
# Input: Le macchine stanno diventando costose.
# Target: Cars are getting expensive.
# Prediction: Cars are getting expensive.
# Input: È spaventoso.
# Target: It's scary.
# Prediction: It's scary.
# Input: Tom è svenuto.
# Target: Tom's fainted.
# Prediction: Tom fainted.
# Input: Dovrei essere davvero preoccupata?
# Target: Should I really be worried?
# Prediction: Should I be really worried?
# Input: Sei dalla mia parte, vero?
# Target: You're on my side, aren't you?
# Prediction: You're on my side, aren't you?
# For FINISHED
# Input: Li aiuteremo domani.
# Target: We'll help them tomorrow.
# tokenizer_config.json: 100%|██████████| 42.0/42.0 [00:00<00:00, 36.8kB/s]
# source.spm: 100%|██████████| 789k/789k [00:00<00:00, 2.39MB/s]
# target.spm: 100%|██████████| 814k/814k [00:00<00:00, 8.37MB/s]
# vocab.json: 100%|██████████| 2.35M/2.35M [00:00<00:00, 3.94MB/s]
# config.json: 100%|██████████| 1.38k/1.38k [00:00<00:00, 7.15MB/s]
# /Users/roxane/Documents/GitHub/DeepNLP/Lab2/.venv/lib/python3.11/site-packages/transformers/models/marian/tokenization_marian.py:197: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")
# pytorch_model.bin: 100%|██████████| 343M/343M [00:06<00:00, 56.2MB/s]
# generation_config.json: 100%|██████████| 293/293 [00:00<00:00, 891kB/s]
# Prediction: Li aiuteremo domani.
# Input: Tu guardi spesso la TV?
# Target: Do you watch TV often?
# Prediction: Tu guarda spesso la TV?
# Input: Rovesciò il suo drink sul mio smoking.
# Target: She spilled her drink all over my tuxedo.
# Prediction: Rovesciò il suo drink sul mio fumo.
# Input: Rimanete in contatto con me.
# Target: Keep in touch with me.
# Prediction: Rimanete in contatto con me.
# Input: Quale cane è il vostro?
# Target: Which dog is yours?
# Prediction: Qual'è il vostro cane?
# Input: C'erano alcuni fiori lì.
# Target: There were some flowers there.
# Prediction: C'erano alcuni fiori là.
# Input: C'è del traffico pesante su questa strada.
# Target: There is heavy traffic on this street.
# Prediction: C'è del traffico pesante su questa strada.
# Input: Lui ha precisato che il viaggio costerà 300 euro.
# Target: He made it clear that the trip will cost 300 euros.
# Prediction: Lui ha previsto che il viaggio costerà 300 euro.
# Input: Io sono un po' arrabbiato con te.
# Target: I'm a little angry with you.
# Prediction: Io sono un po' arrabbiato con te.
# Input: Tom passa meno tempo a studiare francese di me.
# Target: Tom spends less time studying French than I do.
# Prediction: Tom passa meno tempo a studiare francese di me.
# Input: Ho visto un ragazzino correre.
# Target: I saw a little boy running.
# Prediction: Ho visto un ragazzo correre.
# Input: È quasi estate.
# Target: It's almost summertime.
# Prediction: E' quasi proprieta'.
# Input: Tom ama i film sugli zombie e li guarda ogni volta che può.
# Target: Tom loves zombie movies and watches them whenever he can.
# Prediction: Tom ama i film sugli zombie e li guarda ogni volta che può.
# Input: Tom ha detto a Mary di aiutare John.
# Target: Tom told Mary to help John.
# Prediction: Tom ha detto a Mary di aiutare John.
# Input: La fermammo.
# Target: We stopped it.
# Prediction: La fermammo.
# Input: L'ho incontrato mentre studiava.
# Target: I met him while he was studying.
# Prediction: L'ho incontrato mentre studiava.
# Input: Lo incontrerai.
# Target: You'll meet him.
# Prediction: Lo incontrerai.
# Input: Dovrà farlo da qualche altra parte.
# Target: You'll have to do that elsewhere.
# Prediction: Dovrà fare da qualche altra parte.
# Input: Può essere pericoloso.
# Target: It can be dangerous.
# Prediction: Può essere pericoloso.
# Input: Assomiglia a suo fratello.
# Target: He looks like his brother.
# Prediction: Assomiglia a suo fratello.
# Input: Tom ritornò in Australia per essere con me.
# Target: Tom returned to Australia to be with me.
# Prediction: Tom ritorno in Australia per essere con me.
# Input: Ha smesso di correre.
# Target: He quit running.
# Prediction: Ha smesso di correre.
# Input: Loro cosa stanno nascondendo?
# Target: What are they hiding?
# Prediction: Loro cosa stano nascondendo?
# Input: Tom sta chiedendo il permesso,
# Target: Tom is asking permission.
# Prediction: Tom sta chiedendo il permesso,
# Input: Posso venire?
# Target: Can I come?
# Prediction: Posso venire?
# Input: La catturarono.
# Target: They captured her.
# Prediction: La catturarono.
# Input: Tom e Mary saranno di nuovo in ritardo.
# Target: Tom and Mary are going to be late again.
# Prediction: Tom e Mary saranno di nuovo intardo.
# Input: Lui stava lavorando in ufficio ieri sera.
# Target: He was working at the office yesterday evening.
# Prediction: Lui sta lavorando in ufficio ieri sera.
# Input: Che succede la settimana prossima?
# Target: What's happening next week?
# Prediction: Che succeda la settimana prossima?
# Input: Molti contadini sono morti durante la siccità.
# Target: Many peasants died during the drought.
# Prediction: Molti contatti sono morti durante la sicurezza.
# Input: Stai entrando?
# Target: Are you coming in?
# Prediction: Stai entrando?
# Input: Qual è la cosa migliore che hai mai ricevuto per Natale?
# Target: What's the best thing you've ever gotten for Christmas?
# Prediction: Qual è la cosa migliore che hai mai ricevuto per Natale?
# Input: Tom è piuttosto occupato in questo momento.
# Target: Tom's rather busy just now.
# Prediction: Tom è piuttosto occupato in questo momento.
# Input: Ha detto che era infelice.
# Target: She said that she was unhappy.
# Prediction: Ha detto che era infelice.
# Input: Sarà impegnativo resistere alla tentazione.
# Target: It will be difficult to resist the temptation.
# Prediction: Sara' impegnativo resistere alla tendazione.
# Input: Non prendo ordini da lei.
# Target: I don't take orders from you.
# Prediction: Non prendo ordini da lei.
# Input: Tom si fece male al ginocchio sinistro durante l'allenamento, così John dovette giocare al posto suo.
# Target: Tom hurt his left knee during practice, so John had to play the game in his place.
# Prediction: Tom si feci maschio al ginocchio sinistro durante l'allenamento, così John dovette giocare al posto suo.
# Input: Io mi chiamo Lin Feng.
# Target: I am called Lin Feng.
# Prediction: Io mi chiamo Lin Feng.
# Input: Dormii a lungo?
# Target: Did I sleep long?
# Prediction: Dormii a lungo?
# Input: Disegnami una pecora!
# Target: Draw me a sheep!
# Prediction: Disegnami una pecora!
# Input: Tom sta cercando una via d'uscita.
# Target: Tom is searching for a way out.
# Prediction: Tom sta cercando una via d'uscita.
# Input: Tom non è associato a Disneyland.
# Target: Tom is not affiliated with Disneyland.
# Prediction: Tom non è associato a Disneyland.
# Input: Vengono dall'Italia.
# Target: They are from Italy.
# Prediction: Vengono dall'Italia.
# Input: Tom prese su il telefono.
# Target: Tom picked up the phone.
# Prediction: Tom prese su il telefono.
# Input: Lui non uscirebbe.
# Target: He would not go out.
# Prediction: Lui non uscirebbe.
# Input: Le macchine stanno diventando costose.
# Target: Cars are getting expensive.
# Prediction: Le macchine stanno diventando costose.
# Input: È spaventoso.
# Target: It's scary.
# Prediction: E' spaventoso.
# Input: Tom è svenuto.
# Target: Tom's fainted.
# Prediction: Tom è venduto.
# Input: Dovrei essere davvero preoccupata?
# Target: Should I really be worried?
# Prediction: Dovrei essere davvero preoccupato?
# Input: Sei dalla mia parte, vero?
# Target: You're on my side, aren't you?
# Prediction: Sei dalla mia parte, vero?

# %% [markdown]
# ### **Question 3: BLEU scores**
#
# One of the most common metrics used to evaluate MT models is the BLEU score. The BLEU score is a metric that compares the predicted translation with the reference translation. The higher the BLEU score, the better the translation. In this question you will compute the BLEU score for the translated sentences.
#
# Evaluate the selected MT model using [BLEU evaluation metric](https://github.com/mjpost/sacrebleu). Report scores for both translation directions (`EN->IT`, `IT->EN`).
#
# The following cell install the `saclrebleu` library that can be used to compute the BLEU score.

# %%
# !pip install sacrebleu
from sacrebleu.metrics import BLEU
# Out:
# Collecting sacrebleu
#   Downloading sacrebleu-2.3.3-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 2.9 MB/s eta 0:00:00
# Collecting portalocker (from sacrebleu)
#   Downloading portalocker-2.8.2-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: regex in /Users/roxane/Documents/GitHub/DeepNLP/Lab2/.venv/lib/python3.11/site-packages (from sacrebleu) (2023.10.3)
# Collecting tabulate>=0.8.9 (from sacrebleu)
#   Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Requirement already satisfied: numpy>=1.17 in /Users/roxane/Documents/GitHub/DeepNLP/Lab2/.venv/lib/python3.11/site-packages (from sacrebleu) (1.26.1)
# Collecting colorama (from sacrebleu)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Collecting lxml (from sacrebleu)
#   Downloading lxml-4.9.3-cp311-cp311-macosx_11_0_universal2.whl.metadata (3.8 kB)
# Downloading sacrebleu-2.3.3-py3-none-any.whl (106 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.4/106.4 kB 6.0 MB/s eta 0:00:00
# Downloading lxml-4.9.3-cp311-cp311-macosx_11_0_universal2.whl (8.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 14.8 MB/s eta 0:00:0000:0100:01
# Downloading portalocker-2.8.2-py3-none-any.whl (17 kB)
# Installing collected packages: tabulate, portalocker, lxml, colorama, sacrebleu
# Successfully installed colorama-0.4.6 lxml-4.9.3 portalocker-2.8.2 sacrebleu-2.3.3 tabulate-0.9.0

# %%
italian_sentences = [sentence_pair[0] for sentence_pair in train_data]
english_sentences = [sentence_pair[1] for sentence_pair in train_data]

# %%
# Score Italian to English
bleu = BLEU()
score_it_en = bleu.corpus_score(english_sentences[:50],predictions_en)
print(score_it_en)
# Out:
# BLEU = 0.74 3.7/0.7/0.4/0.3 (BP = 1.000 ratio = 7.364 hyp_len = 81 ref_len = 11)

# %%
# Score English to Italian
score_en_it = bleu.corpus_score(italian_sentences[:50], predictions_it)
print(score_en_it)
# Out:
# BLEU = 0.76 3.7/0.7/0.4/0.3 (BP = 1.000 ratio = 6.750 hyp_len = 81 ref_len = 12)

# %% [markdown]
# ### **Question 4: Fine-tuning Seq2Seq model (IT->EN)**
#
# One of the most common paradigm for modern transformer architectures is to use pre-training to learn a generic representation of the language and then fine-tune the model on a specific task. However, you can also fine-tune a model that is already pre-trained on a specific task to another dataset. In this question you will fine-tune a pre-trained MT model on a tatoeba dataset.
#
# Exploit the [Trainer API](https://huggingface.co/transformers/training.html#fine-tuning-in-pytorch-with-the-trainer-api) to finetune and evaluate a [MarianMT](https://arxiv.org/pdf/1804.00344.pdf) sequence to sequence model for machine translation. The documentation for MarianMT is available [here](https://huggingface.co/transformers/model_doc/marian.html).
#
# You can use the code from the previous practices as a starting point (seq2seq model for abstractive summarization).
#
# **Note 1:** select the pre-trained model according to the input-output pair (it-en)
#
# **Note 2:** for the lab practice, please use a sub-set of the training data (e.g., 10000 sentences for training and 1000 sentences for validation)

# %%
# your code here

# %% [markdown]
# ### **Question 5: Model evaluation**
#
# Using the test set provided at the beginning of the practice, evaluate the fine-tuned model and report the BLEU score. How does the BLEU score compare with the one obtained in the previous question?

# %%
# your code here
