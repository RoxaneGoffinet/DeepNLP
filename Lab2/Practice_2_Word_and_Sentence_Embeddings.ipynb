# %% [markdown]
# #**Deep Natural Language Processing @ PoliTO**
#
# ---
#
#
# **Teaching Assistant:** Lorenzo Vaiani
#
# **Credits:** Moreno La Quatra
#
# **Practice 2:** Word and Sentence Embeddings

# %% [markdown]
# ## Word Embedding
#
# ![](https://qph.fs.quoracdn.net/main-qimg-3e812fd164a08f5e4f195000fecf988f)
#
#
# **Key takeaways** from lessons and in-class practices:
# - Word embeddings are able to map words into a semantic-aware vector space
# - There are multiple architectures for the generation of word embeddings
# - Each architecture has its advantages and disadvantages
# - Word embedding evaluation could be intrinsic (intermediate tasks) or extrinsic (downstream task)
# - It is possible to use pre-trained word embedding models or use large amount of text to train it from scratch
# - The use of pre-trained word embedding models is a common practice in NLP and removes the need of training a word embedding model from scratch (that could be very time consuming and computationally expensive)

# %% [markdown]
# ### **Question 1**
#
# Train a new Word2Vec model using gensim with the text8 corpus available in the python package ([reference](https://radimrehurek.com/gensim/downloader.html)). Compute the training time for the model and store it for subsequent steps.
#
# **Hint:** you can use the following code to load the text8 corpus:
#
# ```python
# import gensim.downloader as api
# from gensim.models import Word2Vec
# import time
# dataset = api.load("text8")
# ```

# %%
! pip install --upgrade gensim
# Out:
# Collecting gensim
#   Downloading gensim-4.3.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (8.3 kB)
# Collecting numpy>=1.18.5 (from gensim)
#   Using cached numpy-1.26.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (115 kB)
# Collecting scipy>=1.7.0 (from gensim)
#   Using cached scipy-1.11.3-cp311-cp311-macosx_12_0_arm64.whl.metadata (165 kB)
# Collecting smart-open>=1.8.1 (from gensim)
#   Downloading smart_open-6.4.0-py3-none-any.whl.metadata (21 kB)
# Downloading gensim-4.3.2-cp311-cp311-macosx_11_0_arm64.whl (24.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.0/24.0 MB 5.7 MB/s eta 0:00:0000:0100:01
# Using cached numpy-1.26.1-cp311-cp311-macosx_11_0_arm64.whl (14.0 MB)
# Using cached scipy-1.11.3-cp311-cp311-macosx_12_0_arm64.whl (29.7 MB)
# Downloading smart_open-6.4.0-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 3.1 MB/s eta 0:00:00
# Installing collected packages: smart-open, numpy, scipy, gensim
# Successfully installed gensim-4.3.2 numpy-1.26.1 scipy-1.11.3 smart-open-6.4.0

# %%
# your code here

import gensim.downloader as api
from gensim.models import Word2Vec
import time
dataset = api.load("text8")


start_time = time.time()
model_W2V = Word2Vec(sentences=dataset, vector_size=100, window=5, min_count=5, workers=4) # Train Word2Vec model
end_time = time.time()

training_time = end_time - start_time
print(f"Word2Vec model trained in {training_time} seconds.")
# Out:
# Word2Vec model trained in 30.35967183113098 seconds.

# %% [markdown]
# ### **Question 2**:
# Perform **intrinsic** evaluation of the model for the task of word analogy by exploiting the data collection available [here](https://raw.githubusercontent.com/MorenoLaQuatra/DeepNLP/main/practices/P2/google_analogies.csv).
#
# 1. read CSV file
# 2. group analogy entries by type (column: `type`)
# 3. for each type entry (**in the lab, just set type="family"** to reduce the required time) use the first 3 word vectors to compute the fourth
#     - Entry: `Athens,Greece,Baghdad,Iraq`
#     - `v(Greece) - v(Athens) + v(Baghdad) = res_v`
#     - Get the most similar vectors to `res_v`
#     - Compute in how many cases the correct word is among the top K (if `v[Iraq]` is among the K most similar words) with `K = 1, 3, 5, 10`
#
# $top(k) = \dfrac{\sum_{i=1}^{N} f(i)}{|E|}$
#
# where $f(i) = 1$ if the target word is among the top k and $f(i) = 0$ otherwise.
#
# $|E|$ is the total number of entries for the considered type.
#
# **Notes:**
# 1. Try with the model trained on `text8`, is there any issue? If yes, how can you solve it?
# 2. Test the model trained on Google News available in gensim.

# %%
# %%capture
! wget https://raw.githubusercontent.com/MorenoLaQuatra/DeepNLP/main/practices/P2/google_analogies.csv
! pip install --upgrade pandas

# %%
# Executing this cell could take ~5 minutes
import gensim.downloader
w2v_google_news_model = gensim.downloader.load('word2vec-google-news-300')
# Out:
# [==================================================] 100.0% 1662.8/1662.8MB downloaded

# %%
# your code here
import pandas as pd
data_analogies = pd.read_csv("google_analogies.csv")

# %%
grouped_analogies = data_analogies.groupby('type')

def calculate_analogy_accuracy(type_group, model, k_values):
    total_entries = len(type_group)
    correct_counts = {k: 0 for k in k_values}

    for _, entry in type_group.iterrows():
        words = entry[['word1', 'word2', 'word3', 'target']].values
        try:
            analogy_vector = model[words[1]] - model[words[0]] + model[words[2]]
            similar_words = model.similar_by_vector(analogy_vector, topn=max(k_values))

            for k in k_values:
                correct_counts[k] += int(words[3] in [word[0] for word in similar_words[:k]])

        except KeyError as e:
            print(f"Skipping entry {words} due to missing word in the vocabulary.")

    accuracy_results = {k: count / total_entries for k, count in correct_counts.items()}
    return accuracy_results



type_group = grouped_analogies.get_group('family')


k_values = [1, 3, 5, 10]
accuracy_results = calculate_analogy_accuracy(type_group, model_W2V.wv, k_values)
accuracy_results_google = calculate_analogy_accuracy(type_group, w2v_google_news_model , k_values)

for k, accuracy in accuracy_results.items():
    print(f"Accuracy for k = {k} and W2V trained on text8: {accuracy * 100:.2f}%")

for k, accuracy in accuracy_results_google.items():
    print(f"Accuracy for k = {k} and W2V pretrainde on google news: {accuracy * 100:.2f}%")
# Out:
# Skipping entry ['boy' 'girl' 'stepbrother' 'stepsister'] due to missing word in the vocabulary.
# Skipping entry ['brother' 'sister' 'stepbrother' 'stepsister'] due to missing word in the vocabulary.
# Skipping entry ['brothers' 'sisters' 'stepbrother' 'stepsister'] due to missing word in the vocabulary.
# Skipping entry ['dad' 'mom' 'stepbrother' 'stepsister'] due to missing word in the vocabulary.
# Skipping entry ['father' 'mother' 'stepbrother' 'stepsister'] due to missing word in the vocabulary.
# Skipping entry ['grandfather' 'grandmother' 'stepbrother' 'stepsister'] due to missing word in the vocabulary.
# Skipping entry ['grandpa' 'grandma' 'stepbrother' 'stepsister'] due to missing word in the vocabulary.
# Skipping entry ['grandson' 'granddaughter' 'stepbrother' 'stepsister'] due to missing word in the vocabulary.
# Skipping entry ['groom' 'bride' 'stepbrother' 'stepsister'] due to missing word in the vocabulary.
# Skipping entry ['he' 'she' 'stepbrother' 'stepsister'] due to missing word in the vocabulary.
# Skipping entry ['his' 'her' 'stepbrother' 'stepsister'] due to missing word in the vocabulary.
# Skipping entry ['husband' 'wife' 'stepbrother' 'stepsister'] due to missing word in the vocabulary.
# Skipping entry ['king' 'queen' 'stepbrother' 'stepsister'] due to missing word in the vocabulary.
# Skipping entry ['man' 'woman' 'stepbrother' 'stepsister'] due to missing word in the vocabulary.
# Skipping entry ['nephew' 'niece' 'stepbrother' 'stepsister'] due to missing word in the vocabulary.
# Skipping entry ['policeman' 'policewoman' 'prince' 'princess'] due to missing word in the vocabulary.
# Skipping entry ['policeman' 'policewoman' 'son' 'daughter'] due to missing word in the vocabulary.
# Skipping entry ['policeman' 'policewoman' 'sons' 'daughters'] due to missing word in the vocabulary.
# Skipping entry ['policeman' 'policewoman' 'stepbrother' 'stepsister'] due to missing word in the vocabulary.
# Skipping entry ['policeman' 'policewoman' 'stepfather' 'stepmother'] due to missing word in the vocabulary.
# Skipping entry ['policeman' 'policewoman' 'stepson' 'stepdaughter'] due to missing word in the vocabulary.
# Skipping entry ['policeman' 'policewoman' 'uncle' 'aunt'] due to missing word in the vocabulary.
# Skipping entry ['policeman' 'policewoman' 'boy' 'girl'] due to missing word in the vocabulary.
# Skipping entry ['policeman' 'policewoman' 'brother' 'sister'] due to missing word in the vocabulary.
# Skipping entry ['policeman' 'policewoman' 'brothers' 'sisters'] due to missing word in the vocabulary.
# Skipping entry ['policeman' 'policewoman' 'dad' 'mom'] due to missing word in the vocabulary.
# Skipping entry ['policeman' 'policewoman' 'father' 'mother'] due to missing word in the vocabulary.
# Skipping entry ['policeman' 'policewoman' 'grandfather' 'grandmother'] due to missing word in the vocabulary.
# Skipping entry ['policeman' 'policewoman' 'grandpa' 'grandma'] due to missing word in the vocabulary.
# Skipping entry ['policeman' 'policewoman' 'grandson' 'granddaughter'] due to missing word in the vocabulary.
# Skipping entry ['policeman' 'policewoman' 'groom' 'bride'] due to missing word in the vocabulary.
# Skipping entry ['policeman' 'policewoman' 'he' 'she'] due to missing word in the vocabulary.
# Skipping entry ['policeman' 'policewoman' 'his' 'her'] due to missing word in the vocabulary.
# Skipping entry ['policeman' 'policewoman' 'husband' 'wife'] due to missing word in the vocabulary.
# Skipping entry ['policeman' 'policewoman' 'king' 'queen'] due to missing word in the vocabulary.
# Skipping entry ['policeman' 'policewoman' 'man' 'woman'] due to missing word in the vocabulary.
# Skipping entry ['policeman' 'policewoman' 'nephew' 'niece'] due to missing word in the vocabulary.
# Skipping entry ['prince' 'princess' 'stepbrother' 'stepsister'] due to missing word in the vocabulary.
# Skipping entry ['son' 'daughter' 'stepbrother' 'stepsister'] due to missing word in the vocabulary.
# Skipping entry ['sons' 'daughters' 'stepbrother' 'stepsister'] due to missing word in the vocabulary.
# Skipping entry ['stepbrother' 'stepsister' 'stepfather' 'stepmother'] due to missing word in the vocabulary.
# Skipping entry ['stepbrother' 'stepsister' 'stepson' 'stepdaughter'] due to missing word in the vocabulary.
# Skipping entry ['stepbrother' 'stepsister' 'uncle' 'aunt'] due to missing word in the vocabulary.
# Skipping entry ['stepbrother' 'stepsister' 'boy' 'girl'] due to missing word in the vocabulary.
# Skipping entry ['stepbrother' 'stepsister' 'brother' 'sister'] due to missing word in the vocabulary.
# Skipping entry ['stepbrother' 'stepsister' 'brothers' 'sisters'] due to missing word in the vocabulary.
# Skipping entry ['stepbrother' 'stepsister' 'dad' 'mom'] due to missing word in the vocabulary.
# Skipping entry ['stepbrother' 'stepsister' 'father' 'mother'] due to missing word in the vocabulary.
# Skipping entry ['stepbrother' 'stepsister' 'grandfather' 'grandmother'] due to missing word in the vocabulary.
# Skipping entry ['stepbrother' 'stepsister' 'grandpa' 'grandma'] due to missing word in the vocabulary.
# Skipping entry ['stepbrother' 'stepsister' 'grandson' 'granddaughter'] due to missing word in the vocabulary.
# Skipping entry ['stepbrother' 'stepsister' 'groom' 'bride'] due to missing word in the vocabulary.
# Skipping entry ['stepbrother' 'stepsister' 'he' 'she'] due to missing word in the vocabulary.
# Skipping entry ['stepbrother' 'stepsister' 'his' 'her'] due to missing word in the vocabulary.
# Skipping entry ['stepbrother' 'stepsister' 'husband' 'wife'] due to missing word in the vocabulary.
# Skipping entry ['stepbrother' 'stepsister' 'king' 'queen'] due to missing word in the vocabulary.
# Skipping entry ['stepbrother' 'stepsister' 'man' 'woman'] due to missing word in the vocabulary.
# Skipping entry ['stepbrother' 'stepsister' 'nephew' 'niece'] due to missing word in the vocabulary.
# Skipping entry ['stepbrother' 'stepsister' 'policeman' 'policewoman'] due to missing word in the vocabulary.
# Skipping entry ['stepbrother' 'stepsister' 'prince' 'princess'] due to missing word in the vocabulary.
# Skipping entry ['stepbrother' 'stepsister' 'son' 'daughter'] due to missing word in the vocabulary.
# Skipping entry ['stepbrother' 'stepsister' 'sons' 'daughters'] due to missing word in the vocabulary.
# Skipping entry ['stepfather' 'stepmother' 'stepbrother' 'stepsister'] due to missing word in the vocabulary.
# Skipping entry ['stepson' 'stepdaughter' 'stepbrother' 'stepsister'] due to missing word in the vocabulary.
# Skipping entry ['uncle' 'aunt' 'stepbrother' 'stepsister'] due to missing word in the vocabulary.
# Accuracy for k = 1 and W2V trained on text8: 5.14%
# Accuracy for k = 3 and W2V trained on text8: 51.98%
# Accuracy for k = 5 and W2V trained on text8: 58.50%
# Accuracy for k = 10 and W2V trained on text8: 62.25%
# Accuracy for k = 1 and W2V pretrainde on google news: 34.98%
# Accuracy for k = 3 and W2V pretrainde on google news: 87.94%
# Accuracy for k = 5 and W2V pretrainde on google news: 93.68%
# Accuracy for k = 10 and W2V pretrainde on google news: 97.23%

# %% [markdown]
# Yes there is issues with the model trainde on text8 because there is missing words in the vocabulary, to go pass this we have to put a try-except clause in the function that calculate the analogy accuracy
# What we can see is that we obtained better performances with the pretrained on goolgle news model and that is no matter k.
#
# Accuracy for k = 1 and W2V trained on text8: 5.14%
# Accuracy for k = 3 and W2V trained on text8: 51.98%
# Accuracy for k = 5 and W2V trained on text8: 58.50%
# Accuracy for k = 10 and W2V trained on text8: 62.25%
# Accuracy for k = 1 and W2V pretrainde on google news: 34.98%
# Accuracy for k = 3 and W2V pretrainde on google news: 87.94%
# Accuracy for k = 5 and W2V pretrainde on google news: 93.68%
# Accuracy for k = 10 and W2V pretrainde on google news: 97.23%

# %% [markdown]
# ### **Question 3:**
#
# Train a new FastText model using gensim with text8 corpus available in the python package ([reference](https://radimrehurek.com/gensim/downloader.html)). Compute the training time for the model and store it for subsequent steps.
#
# - Is there any significant difference in training time if compared with Word2Vec training?

# %%
# your code here
from gensim.models import FastText
start_time = time.time()
model_FastText = FastText(sentences=dataset, vector_size=100, window=5, min_count=5, workers=4) # Train FastText model
end_time = time.time()

training_time = end_time - start_time
print(f"FastText model trained in {training_time} seconds.")
# Out:
# FastText model trained in 131.47197914123535 seconds.

# %% [markdown]
# ### **Question 4:**
# Provide the same evaluation done in Question 2 for the FastText model. In this case, you can use the same type of analogy (family) and the same K values.
#
# **Notes:**
# - Try with the model trained on `text8`, is there any issue? What does it mean?
# - Test the model trained on Wikipedia+News available in gensim.

# %%
# Executing this cell could take ~5 minutes
import gensim.downloader
ft_wiki_news_model = gensim.downloader.load('fasttext-wiki-news-subwords-300')
# Out:
# [==================================================] 100.0% 958.5/958.4MB downloaded

# %%
# your code here
accuracy_results = calculate_analogy_accuracy(type_group, model_FastText.wv , k_values)
accuracy_results_wiki = calculate_analogy_accuracy(type_group, ft_wiki_news_model , k_values)

for k, accuracy in accuracy_results.items():
    print(f"Accuracy for k = {k} and FastText trained on text8: {accuracy * 100:.2f}%")

for k, accuracy in accuracy_results_wiki.items():
    print(f"Accuracy for k = {k} and W2V pretrainde on wikipedial and news: {accuracy * 100:.2f}%")
# Out:
# Accuracy for k = 1 and FastText trained on text8: 2.37%
# Accuracy for k = 3 and FastText trained on text8: 32.41%
# Accuracy for k = 5 and FastText trained on text8: 39.92%
# Accuracy for k = 10 and FastText trained on text8: 47.43%
# Accuracy for k = 1 and W2V pretrainde on wikipedial and news: 22.92%
# Accuracy for k = 3 and W2V pretrainde on wikipedial and news: 89.33%
# Accuracy for k = 5 and W2V pretrainde on wikipedial and news: 95.06%
# Accuracy for k = 10 and W2V pretrainde on wikipedial and news: 97.83%

# %% [markdown]
# There is no issue that means that the word doesn't have to be in the vocabulary for it to work. The model trained on Wikipedia and news is working way better even though it is not entirely satisfying bcause for small k (k =1 or 2) we don't have that much accuracy.

# %% [markdown]
# ### **Question 5** (optional)
#
# Provide a complete evaluation of the best performing models (Word2Vec and FastText) by leveraging the complete dataset of analogy entries. In this case, you should use all the analogy types and all you can use the same K values provided in Question 2.

# %%
# your code here

accuracy_results_W2V = calculate_analogy_accuracy(data_analogies, model_W2V.wv , k_values)
accuracy_results_google = calculate_analogy_accuracy(data_analogies, w2v_google_news_model , k_values)
accuracy_results_FastText = calculate_analogy_accuracy(data_analogies, model_FastText.wv , k_values)
accuracy_results_wiki = calculate_analogy_accuracy(data_analogies, ft_wiki_news_model , k_values)

for k, accuracy in accuracy_results_W2V.items():
    print(f"Accuracy for k = {k} and W2V trained on text8: {accuracy * 100:.2f}%")
for k, accuracy in accuracy_results_google.items():
    print(f"Accuracy for k = {k} and W2V trained on google news: {accuracy * 100:.2f}%")
for k, accuracy in accuracy_results_FastText.items():
    print(f"Accuracy for k = {k} and FastText trained on text8: {accuracy * 100:.2f}%")
for k, accuracy in accuracy_results_wiki.items():
    print(f"Accuracy for k = {k} and W2V pretrainde on wikipedia and news: {accuracy * 100:.2f}%")
# Out:
# Skipping entry ['Athens' 'Greece' 'Baghdad' 'Iraq'] due to missing word in the vocabulary.
# Skipping entry ['Athens' 'Greece' 'Bangkok' 'Thailand'] due to missing word in the vocabulary.
# Skipping entry ['Athens' 'Greece' 'Beijing' 'China'] due to missing word in the vocabulary.
# Skipping entry ['Athens' 'Greece' 'Berlin' 'Germany'] due to missing word in the vocabulary.
# Skipping entry ['Athens' 'Greece' 'Bern' 'Switzerland'] due to missing word in the vocabulary.
# Skipping entry ['Athens' 'Greece' 'Cairo' 'Egypt'] due to missing word in the vocabulary.
# Skipping entry ['Athens' 'Greece' 'Canberra' 'Australia'] due to missing word in the vocabulary.
# Skipping entry ['Athens' 'Greece' 'Hanoi' 'Vietnam'] due to missing word in the vocabulary.
# Skipping entry ['Athens' 'Greece' 'Havana' 'Cuba'] due to missing word in the vocabulary.
# Skipping entry ['Athens' 'Greece' 'Helsinki' 'Finland'] due to missing word in the vocabulary.
# Skipping entry ['Athens' 'Greece' 'Islamabad' 'Pakistan'] due to missing word in the vocabulary.
# Skipping entry ['Athens' 'Greece' 'Kabul' 'Afghanistan'] due to missing word in the vocabulary.
# Skipping entry ['Athens' 'Greece' 'London' 'England'] due to missing word in the vocabulary.
# Skipping entry ['Athens' 'Greece' 'Madrid' 'Spain'] due to missing word in the vocabulary.
# Skipping entry ['Athens' 'Greece' 'Moscow' 'Russia'] due to missing word in the vocabulary.
# Skipping entry ['Athens' 'Greece' 'Oslo' 'Norway'] due to missing word in the vocabulary.
# Skipping entry ['Athens' 'Greece' 'Ottawa' 'Canada'] due to missing word in the vocabulary.
# Skipping entry ['Athens' 'Greece' 'Paris' 'France'] due to missing word in the vocabulary.
# Skipping entry ['Athens' 'Greece' 'Rome' 'Italy'] due to missing word in the vocabulary.
# Skipping entry ['Athens' 'Greece' 'Stockholm' 'Sweden'] due to missing word in the vocabulary.
# Skipping entry ['Athens' 'Greece' 'Tehran' 'Iran'] due to missing word in the vocabulary.
# Skipping entry ['Athens' 'Greece' 'Tokyo' 'Japan'] due to missing word in the vocabulary.
# Skipping entry ['Baghdad' 'Iraq' 'Bangkok' 'Thailand'] due to missing word in the vocabulary.
# Skipping entry ['Baghdad' 'Iraq' 'Beijing' 'China'] due to missing word in the vocabulary.
# Skipping entry ['Baghdad' 'Iraq' 'Berlin' 'Germany'] due to missing word in the vocabulary.
# Skipping entry ['Baghdad' 'Iraq' 'Bern' 'Switzerland'] due to missing word in the vocabulary.
# Skipping entry ['Baghdad' 'Iraq' 'Cairo' 'Egypt'] due to missing word in the vocabulary.
# Skipping entry ['Baghdad' 'Iraq' 'Canberra' 'Australia'] due to missing word in the vocabulary.
# Skipping entry ['Baghdad' 'Iraq' 'Hanoi' 'Vietnam'] due to missing word in the vocabulary.
# Skipping entry ['Baghdad' 'Iraq' 'Havana' 'Cuba'] due to missing word in the vocabulary.
# Skipping entry ['Baghdad' 'Iraq' 'Helsinki' 'Finland'] due to missing word in the vocabulary.
# Skipping entry ['Baghdad' 'Iraq' 'Islamabad' 'Pakistan'] due to missing word in the vocabulary.
# Skipping entry ['Baghdad' 'Iraq' 'Kabul' 'Afghanistan'] due to missing word in the vocabulary.
# Skipping entry ['Baghdad' 'Iraq' 'London' 'England'] due to missing word in the vocabulary.
# Skipping entry ['Baghdad' 'Iraq' 'Madrid' 'Spain'] due to missing word in the vocabulary.
# Skipping entry ['Baghdad' 'Iraq' 'Moscow' 'Russia'] due to missing word in the vocabulary.
# Skipping entry ['Baghdad' 'Iraq' 'Oslo' 'Norway'] due to missing word in the vocabulary.
# Skipping entry ['Baghdad' 'Iraq' 'Ottawa' 'Canada'] due to missing word in the vocabulary.
# Skipping entry ['Baghdad' 'Iraq' 'Paris' 'France'] due to missing word in the vocabulary.
# Skipping entry ['Baghdad' 'Iraq' 'Rome' 'Italy'] due to missing word in the vocabulary.
# Skipping entry ['Baghdad' 'Iraq' 'Stockholm' 'Sweden'] due to missing word in the vocabulary.
# Skipping entry ['Baghdad' 'Iraq' 'Tehran' 'Iran'] due to missing word in the vocabulary.
# Skipping entry ['Baghdad' 'Iraq' 'Tokyo' 'Japan'] due to missing word in the vocabulary.
# Skipping entry ['Baghdad' 'Iraq' 'Athens' 'Greece'] due to missing word in the vocabulary.
# Skipping entry ['Bangkok' 'Thailand' 'Beijing' 'China'] due to missing word in the vocabulary.
# Skipping entry ['Bangkok' 'Thailand' 'Berlin' 'Germany'] due to missing word in the vocabulary.
# Skipping entry ['Bangkok' 'Thailand' 'Bern' 'Switzerland'] due to missing word in the vocabulary.
# Skipping entry ['Bangkok' 'Thailand' 'Cairo' 'Egypt'] due to missing word in the vocabulary.
# Skipping entry ['Bangkok' 'Thailand' 'Canberra' 'Australia'] due to missing word in the vocabulary.
# Skipping entry ['Bangkok' 'Thailand' 'Hanoi' 'Vietnam'] due to missing word in the vocabulary.
# Skipping entry ['Bangkok' 'Thailand' 'Havana' 'Cuba'] due to missing word in the vocabulary.
# Skipping entry ['Bangkok' 'Thailand' 'Helsinki' 'Finland'] due to missing word in the vocabulary.
# Skipping entry ['Bangkok' 'Thailand' 'Islamabad' 'Pakistan'] due to missing word in the vocabulary.
# Skipping entry ['Bangkok' 'Thailand' 'Kabul' 'Afghanistan'] due to missing word in the vocabulary.
# Skipping entry ['Bangkok' 'Thailand' 'London' 'England'] due to missing word in the vocabulary.
# Skipping entry ['Bangkok' 'Thailand' 'Madrid' 'Spain'] due to missing word in the vocabulary.
# Skipping entry ['Bangkok' 'Thailand' 'Moscow' 'Russia'] due to missing word in the vocabulary.
# Skipping entry ['Bangkok' 'Thailand' 'Oslo' 'Norway'] due to missing word in the vocabulary.
# Skipping entry ['Bangkok' 'Thailand' 'Ottawa' 'Canada'] due to missing word in the vocabulary.
# Skipping entry ['Bangkok' 'Thailand' 'Paris' 'France'] due to missing word in the vocabulary.
# Skipping entry ['Bangkok' 'Thailand' 'Rome' 'Italy'] due to missing word in the vocabulary.
# Skipping entry ['Bangkok' 'Thailand' 'Stockholm' 'Sweden'] due to missing word in the vocabulary.
# Skipping entry ['Bangkok' 'Thailand' 'Tehran' 'Iran'] due to missing word in the vocabulary.
# Skipping entry ['Bangkok' 'Thailand' 'Tokyo' 'Japan'] due to missing word in the vocabulary.
# Skipping entry ['Bangkok' 'Thailand' 'Athens' 'Greece'] due to missing word in the vocabulary.
# Skipping entry ['Bangkok' 'Thailand' 'Baghdad' 'Iraq'] due to missing word in the vocabulary.
# Skipping entry ['Beijing' 'China' 'Berlin' 'Germany'] due to missing word in the vocabulary.
# Skipping entry ['Beijing' 'China' 'Bern' 'Switzerland'] due to missing word in the vocabulary.
# Skipping entry ['Beijing' 'China' 'Cairo' 'Egypt'] due to missing word in the vocabulary.
# Skipping entry ['Beijing' 'China' 'Canberra' 'Australia'] due to missing word in the vocabulary.
# Skipping entry ['Beijing' 'China' 'Hanoi' 'Vietnam'] due to missing word in the vocabulary.
# Skipping entry ['Beijing' 'China' 'Havana' 'Cuba'] due to missing word in the vocabulary.
# Skipping entry ['Beijing' 'China' 'Helsinki' 'Finland'] due to missing word in the vocabulary.
# Skipping entry ['Beijing' 'China' 'Islamabad' 'Pakistan'] due to missing word in the vocabulary.
# Skipping entry ['Beijing' 'China' 'Kabul' 'Afghanistan'] due to missing word in the vocabulary.
# Skipping entry ['Beijing' 'China' 'London' 'England'] due to missing word in the vocabulary.
# Skipping entry ['Beijing' 'China' 'Madrid' 'Spain'] due to missing word in the vocabulary.
# Skipping entry ['Beijing' 'China' 'Moscow' 'Russia'] due to missing word in the vocabulary.
# Skipping entry ['Beijing' 'China' 'Oslo' 'Norway'] due to missing word in the vocabulary.
# Skipping entry ['Beijing' 'China' 'Ottawa' 'Canada'] due to missing word in the vocabulary.
# Skipping entry ['Beijing' 'China' 'Paris' 'France'] due to missing word in the vocabulary.
# Skipping entry ['Beijing' 'China' 'Rome' 'Italy'] due to missing word in the vocabulary.
# Skipping entry ['Beijing' 'China' 'Stockholm' 'Sweden'] due to missing word in the vocabulary.
# Skipping entry ['Beijing' 'China' 'Tehran' 'Iran'] due to missing word in the vocabulary.
# Skipping entry ['Beijing' 'China' 'Tokyo' 'Japan'] due to missing word in the vocabulary.
# Skipping entry ['Beijing' 'China' 'Athens' 'Greece'] due to missing word in the vocabulary.
# Skipping entry ['Beijing' 'China' 'Baghdad' 'Iraq'] due to missing word in the vocabulary.
# Skipping entry ['Beijing' 'China' 'Bangkok' 'Thailand'] due to missing word in the vocabulary.
# Skipping entry ['Berlin' 'Germany' 'Bern' 'Switzerland'] due to missing word in the vocabulary.
# Skipping entry ['Berlin' 'Germany' 'Cairo' 'Egypt'] due to missing word in the vocabulary.
# Skipping entry ['Berlin' 'Germany' 'Canberra' 'Australia'] due to missing word in the vocabulary.
# Skipping entry ['Berlin' 'Germany' 'Hanoi' 'Vietnam'] due to missing word in the vocabulary.
# Skipping entry ['Berlin' 'Germany' 'Havana' 'Cuba'] due to missing word in the vocabulary.
# Skipping entry ['Berlin' 'Germany' 'Helsinki' 'Finland'] due to missing word in the vocabulary.
# Skipping entry ['Berlin' 'Germany' 'Islamabad' 'Pakistan'] due to missing word in the vocabulary.
# Skipping entry ['Berlin' 'Germany' 'Kabul' 'Afghanistan'] due to missing word in the vocabulary.
# Skipping entry ['Berlin' 'Germany' 'London' 'England'] due to missing word in the vocabulary.
# Skipping entry ['Berlin' 'Germany' 'Madrid' 'Spain'] due to missing word in the vocabulary.
# Skipping entry ['Berlin' 'Germany' 'Moscow' 'Russia'] due to missing word in the vocabulary.
# Skipping entry ['Berlin' 'Germany' 'Oslo' 'Norway'] due to missing word in the vocabulary.
# Skipping entry ['Berlin' 'Germany' 'Ottawa' 'Canada'] due to missing word in the vocabulary.
# Skipping entry ['Berlin' 'Germany' 'Paris' 'France'] due to missing word in the vocabulary.
# Skipping entry ['Berlin' 'Germany' 'Rome' 'Italy'] due to missing word in the vocabulary.
# Skipping entry ['Berlin' 'Germany' 'Stockholm' 'Sweden'] due to missing word in the vocabulary.
# Skipping entry ['Berlin' 'Germany' 'Tehran' 'Iran'] due to missing word in the vocabulary.
# Skipping entry ['Berlin' 'Germany' 'Tokyo' 'Japan'] due to missing word in the vocabulary.
# Skipping entry ['Berlin' 'Germany' 'Athens' 'Greece'] due to missing word in the vocabulary.
# Skipping entry ['Berlin' 'Germany' 'Baghdad' 'Iraq'] due to missing word in the vocabulary.
# Skipping entry ['Berlin' 'Germany' 'Bangkok' 'Thailand'] due to missing word in the vocabulary.
# Skipping entry ['Berlin' 'Germany' 'Beijing' 'China'] due to missing word in the vocabulary.
# Skipping entry ['Bern' 'Switzerland' 'Cairo' 'Egypt'] due to missing word in the vocabulary.
# Skipping entry ['Bern' 'Switzerland' 'Canberra' 'Australia'] due to missing word in the vocabulary.
# Skipping entry ['Bern' 'Switzerland' 'Hanoi' 'Vietnam'] due to missing word in the vocabulary.
# Skipping entry ['Bern' 'Switzerland' 'Havana' 'Cuba'] due to missing word in the vocabulary.
# Skipping entry ['Bern' 'Switzerland' 'Helsinki' 'Finland'] due to missing word in the vocabulary.
# Skipping entry ['Bern' 'Switzerland' 'Islamabad' 'Pakistan'] due to missing word in the vocabulary.
# Skipping entry ['Bern' 'Switzerland' 'Kabul' 'Afghanistan'] due to missing word in the vocabulary.
# Skipping entry ['Bern' 'Switzerland' 'London' 'England'] due to missing word in the vocabulary.
# Skipping entry ['Bern' 'Switzerland' 'Madrid' 'Spain'] due to missing word in the vocabulary.
# Skipping entry ['Bern' 'Switzerland' 'Moscow' 'Russia'] due to missing word in the vocabulary.
# Skipping entry ['Bern' 'Switzerland' 'Oslo' 'Norway'] due to missing word in the vocabulary.
# Skipping entry ['Bern' 'Switzerland' 'Ottawa' 'Canada'] due to missing word in the vocabulary.
# Skipping entry ['Bern' 'Switzerland' 'Paris' 'France'] due to missing word in the vocabulary.
# Skipping entry ['Bern' 'Switzerland' 'Rome' 'Italy'] due to missing word in the vocabulary.
# Skipping entry ['Bern' 'Switzerland' 'Stockholm' 'Sweden'] due to missing word in the vocabulary.
# Skipping entry ['Bern' 'Switzerland' 'Tehran' 'Iran'] due to missing word in the vocabulary.
# Skipping entry ['Bern' 'Switzerland' 'Tokyo' 'Japan'] due to missing word in the vocabulary.
# Skipping entry ['Bern' 'Switzerland' 'Athens' 'Greece'] due to missing word in the vocabulary.
# Skipping entry ['Bern' 'Switzerland' 'Baghdad' 'Iraq'] due to missing word in the vocabulary.
# Skipping entry ['Bern' 'Switzerland' 'Bangkok' 'Thailand'] due to missing word in the vocabulary.
# Skipping entry ['Bern' 'Switzerland' 'Beijing' 'China'] due to missing word in the vocabulary.
# Skipping entry ['Bern' 'Switzerland' 'Berlin' 'Germany'] due to missing word in the vocabulary.
# Skipping entry ['Cairo' 'Egypt' 'Canberra' 'Australia'] due to missing word in the vocabulary.
# Skipping entry ['Cairo' 'Egypt' 'Hanoi' 'Vietnam'] due to missing word in the vocabulary.
# Skipping entry ['Cairo' 'Egypt' 'Havana' 'Cuba'] due to missing word in the vocabulary.
# Skipping entry ['Cairo' 'Egypt' 'Helsinki' 'Finland'] due to missing word in the vocabulary.
# Skipping entry ['Cairo' 'Egypt' 'Islamabad' 'Pakistan'] due to missing word in the vocabulary.
# Skipping entry ['Cairo' 'Egypt' 'Kabul' 'Afghanistan'] due to missing word in the vocabulary.
# Skipping entry ['Cairo' 'Egypt' 'London' 'England'] due to missing word in the vocabulary.
# Skipping entry ['Cairo' 'Egypt' 'Madrid' 'Spain'] due to missing word in the vocabulary.
# Skipping entry ['Cairo' 'Egypt' 'Moscow' 'Russia'] due to missing word in the vocabulary.
# Skipping entry ['Cairo' 'Egypt' 'Oslo' 'Norway'] due to missing word in the vocabulary.
# Skipping entry ['Cairo' 'Egypt' 'Ottawa' 'Canada'] due to missing word in the vocabulary.
# Skipping entry ['Cairo' 'Egypt' 'Paris' 'France'] due to missing word in the vocabulary.
# Skipping entry ['Cairo' 'Egypt' 'Rome' 'Italy'] due to missing word in the vocabulary.
# Skipping entry ['Cairo' 'Egypt' 'Stockholm' 'Sweden'] due to missing word in the vocabulary.
# Skipping entry ['Cairo' 'Egypt' 'Tehran' 'Iran'] due to missing word in the vocabulary.
# Skipping entry ['Cairo' 'Egypt' 'Tokyo' 'Japan'] due to missing word in the vocabulary.
# Skipping entry ['Cairo' 'Egypt' 'Athens' 'Greece'] due to missing word in the vocabulary.
# Skipping entry ['Cairo' 'Egypt' 'Baghdad' 'Iraq'] due to missing word in the vocabulary.
# Skipping entry ['Cairo' 'Egypt' 'Bangkok' 'Thailand'] due to missing word in the vocabulary.
# Skipping entry ['Cairo' 'Egypt' 'Beijing' 'China'] due to missing word in the vocabulary.
# Skipping entry ['Cairo' 'Egypt' 'Berlin' 'Germany'] due to missing word in the vocabulary.
# Skipping entry ['Cairo' 'Egypt' 'Bern' 'Switzerland'] due to missing word in the vocabulary.
# Skipping entry ['Canberra' 'Australia' 'Hanoi' 'Vietnam'] due to missing word in the vocabulary.
# Skipping entry ['Canberra' 'Australia' 'Havana' 'Cuba'] due to missing word in the vocabulary.
# Skipping entry ['Canberra' 'Australia' 'Helsinki' 'Finland'] due to missing word in the vocabulary.
# Skipping entry ['Canberra' 'Australia' 'Islamabad' 'Pakistan'] due to missing word in the vocabulary.
# Skipping entry ['Canberra' 'Australia' 'Kabul' 'Afghanistan'] due to missing word in the vocabulary.
# Skipping entry ['Canberra' 'Australia' 'London' 'England'] due to missing word in the vocabulary.
# Skipping entry ['Canberra' 'Australia' 'Madrid' 'Spain'] due to missing word in the vocabulary.
# Skipping entry ['Canberra' 'Australia' 'Moscow' 'Russia'] due to missing word in the vocabulary.
# Skipping entry ['Canberra' 'Australia' 'Oslo' 'Norway'] due to missing word in the vocabulary.
# Skipping entry ['Canberra' 'Australia' 'Ottawa' 'Canada'] due to missing word in the vocabulary.
# Skipping entry ['Canberra' 'Australia' 'Paris' 'France'] due to missing word in the vocabulary.
# Skipping entry ['Canberra' 'Australia' 'Rome' 'Italy'] due to missing word in the vocabulary.
# Skipping entry ['Canberra' 'Australia' 'Stockholm' 'Sweden'] due to missing word in the vocabulary.
# Skipping entry ['Canberra' 'Australia' 'Tehran' 'Iran'] due to missing word in the vocabulary.
# Skipping entry ['Canberra' 'Australia' 'Tokyo' 'Japan'] due to missing word in the vocabulary.
# Skipping entry ['Canberra' 'Australia' 'Athens' 'Greece'] due to missing word in the vocabulary.
# Skipping entry ['Canberra' 'Australia' 'Baghdad' 'Iraq'] due to missing word in the vocabulary.
# Skipping entry ['Canberra' 'Australia' 'Bangkok' 'Thailand'] due to missing word in the vocabulary.
# Skipping entry ['Canberra' 'Australia' 'Beijing' 'China'] due to missing word in the vocabulary.
# Skipping entry ['Canberra' 'Australia' 'Berlin' 'Germany'] due to missing word in the vocabulary.
# Skipping entry ['Canberra' 'Australia' 'Bern' 'Switzerland'] due to missing word in the vocabulary.
# Skipping entry ['Canberra' 'Australia' 'Cairo' 'Egypt'] due to missing word in the vocabulary.
# Skipping entry ['Hanoi' 'Vietnam' 'Havana' 'Cuba'] due to missing word in the vocabulary.
# Skipping entry ['Hanoi' 'Vietnam' 'Helsinki' 'Finland'] due to missing word in the vocabulary.
# Skipping entry ['Hanoi' 'Vietnam' 'Islamabad' 'Pakistan'] due to missing word in the vocabulary.
# Skipping entry ['Hanoi' 'Vietnam' 'Kabul' 'Afghanistan'] due to missing word in the vocabulary.
# Skipping entry ['Hanoi' 'Vietnam' 'London' 'England'] due to missing word in the vocabulary.
# Skipping entry ['Hanoi' 'Vietnam' 'Madrid' 'Spain'] due to missing word in the vocabulary.
# Skipping entry ['Hanoi' 'Vietnam' 'Moscow' 'Russia'] due to missing word in the vocabulary.
# Skipping entry ['Hanoi' 'Vietnam' 'Oslo' 'Norway'] due to missing word in the vocabulary.
# Skipping entry ['Hanoi' 'Vietnam' 'Ottawa' 'Canada'] due to missing word in the vocabulary.
# Skipping entry ['Hanoi' 'Vietnam' 'Paris' 'France'] due to missing word in the vocabulary.
# Skipping entry ['Hanoi' 'Vietnam' 'Rome' 'Italy'] due to missing word in the vocabulary.
# Skipping entry ['Hanoi' 'Vietnam' 'Stockholm' 'Sweden'] due to missing word in the vocabulary.
# Skipping entry ['Hanoi' 'Vietnam' 'Tehran' 'Iran'] due to missing word in the vocabulary.
# Skipping entry ['Hanoi' 'Vietnam' 'Tokyo' 'Japan'] due to missing word in the vocabulary.
# Skipping entry ['Hanoi' 'Vietnam' 'Athens' 'Greece'] due to missing word in the vocabulary.
# Skipping entry ['Hanoi' 'Vietnam' 'Baghdad' 'Iraq'] due to missing word in the vocabulary.
# Skipping entry ['Hanoi' 'Vietnam' 'Bangkok' 'Thailand'] due to missing word in the vocabulary.
# Skipping entry ['Hanoi' 'Vietnam' 'Beijing' 'China'] due to missing word in the vocabulary.
# Skipping entry ['Hanoi' 'Vietnam' 'Berlin' 'Germany'] due to missing word in the vocabulary.
# Skipping entry ['Hanoi' 'Vietnam' 'Bern' 'Switzerland'] due to missing word in the vocabulary.
# Skipping entry ['Hanoi' 'Vietnam' 'Cairo' 'Egypt'] due to missing word in the vocabulary.
# Skipping entry ['Hanoi' 'Vietnam' 'Canberra' 'Australia'] due to missing word in the vocabulary.
# Skipping entry ['Havana' 'Cuba' 'Helsinki' 'Finland'] due to missing word in the vocabulary.
# Skipping entry ['Havana' 'Cuba' 'Islamabad' 'Pakistan'] due to missing word in the vocabulary.
# Skipping entry ['Havana' 'Cuba' 'Kabul' 'Afghanistan'] due to missing word in the vocabulary.
# Skipping entry ['Havana' 'Cuba' 'London' 'England'] due to missing word in the vocabulary.
# Skipping entry ['Havana' 'Cuba' 'Madrid' 'Spain'] due to missing word in the vocabulary.
# Skipping entry ['Havana' 'Cuba' 'Moscow' 'Russia'] due to missing word in the vocabulary.
# Skipping entry ['Havana' 'Cuba' 'Oslo' 'Norway'] due to missing word in the vocabulary.
# Skipping entry ['Havana' 'Cuba' 'Ottawa' 'Canada'] due to missing word in the vocabulary.
# Skipping entry ['Havana' 'Cuba' 'Paris' 'France'] due to missing word in the vocabulary.
# Skipping entry ['Havana' 'Cuba' 'Rome' 'Italy'] due to missing word in the vocabulary.
# Skipping entry ['Havana' 'Cuba' 'Stockholm' 'Sweden'] due to missing word in the vocabulary.
# Skipping entry ['Havana' 'Cuba' 'Tehran' 'Iran'] due to missing word in the vocabulary.
# Skipping entry ['Havana' 'Cuba' 'Tokyo' 'Japan'] due to missing word in the vocabulary.
# Skipping entry ['Havana' 'Cuba' 'Athens' 'Greece'] due to missing word in the vocabulary.
# Skipping entry ['Havana' 'Cuba' 'Baghdad' 'Iraq'] due to missing word in the vocabulary.
# Skipping entry ['Havana' 'Cuba' 'Bangkok' 'Thailand'] due to missing word in the vocabulary.
# Skipping entry ['Havana' 'Cuba' 'Beijing' 'China'] due to missing word in the vocabulary.
# Skipping entry ['Havana' 'Cuba' 'Berlin' 'Germany'] due to missing word in the vocabulary.
# Skipping entry ['Havana' 'Cuba' 'Bern' 'Switzerland'] due to missing word in the vocabulary.
# Skipping entry ['Havana' 'Cuba' 'Cairo' 'Egypt'] due to missing word in the vocabulary.
# Skipping entry ['Havana' 'Cuba' 'Canberra' 'Australia'] due to missing word in the vocabulary.
# Skipping entry ['Havana' 'Cuba' 'Hanoi' 'Vietnam'] due to missing word in the vocabulary.
# Skipping entry ['Helsinki' 'Finland' 'Islamabad' 'Pakistan'] due to missing word in the vocabulary.
# Skipping entry ['Helsinki' 'Finland' 'Kabul' 'Afghanistan'] due to missing word in the vocabulary.
# Skipping entry ['Helsinki' 'Finland' 'London' 'England'] due to missing word in the vocabulary.
# Skipping entry ['Helsinki' 'Finland' 'Madrid' 'Spain'] due to missing word in the vocabulary.
# Skipping entry ['Helsinki' 'Finland' 'Moscow' 'Russia'] due to missing word in the vocabulary.
# Skipping entry ['Helsinki' 'Finland' 'Oslo' 'Norway'] due to missing word in the vocabulary.
# Skipping entry ['Helsinki' 'Finland' 'Ottawa' 'Canada'] due to missing word in the vocabulary.
# Skipping entry ['Helsinki' 'Finland' 'Paris' 'France'] due to missing word in the vocabulary.
# Skipping entry ['Helsinki' 'Finland' 'Rome' 'Italy'] due to missing word in the vocabulary.
# Skipping entry ['Helsinki' 'Finland' 'Stockholm' 'Sweden'] due to missing word in the vocabulary.
# Skipping entry ['Helsinki' 'Finland' 'Tehran' 'Iran'] due to missing word in the vocabulary.
# Skipping entry ['Helsinki' 'Finland' 'Tokyo' 'Japan'] due to missing word in the vocabulary.
# Skipping entry ['Helsinki' 'Finland' 'Athens' 'Greece'] due to missing word in the vocabulary.
# Skipping entry ['Helsinki' 'Finland' 'Baghdad' 'Iraq'] due to missing word in the vocabulary.
# Skipping entry ['Helsinki' 'Finland' 'Bangkok' 'Thailand'] due to missing word in the vocabulary.
# Skipping entry ['Helsinki' 'Finland' 'Beijing' 'China'] due to missing word in the vocabulary.
# Skipping entry ['Helsinki' 'Finland' 'Berlin' 'Germany'] due to missing word in the vocabulary.
# Skipping entry ['Helsinki' 'Finland' 'Bern' 'Switzerland'] due to missing word in the vocabulary.
# Skipping entry ['Helsinki' 'Finland' 'Cairo' 'Egypt'] due to missing word in the vocabulary.
# Skipping entry ['Helsinki' 'Finland' 'Canberra' 'Australia'] due to missing word in the vocabulary.
# Skipping entry ['Helsinki' 'Finland' 'Hanoi' 'Vietnam'] due to missing word in the vocabulary.
# Skipping entry ['Helsinki' 'Finland' 'Havana' 'Cuba'] due to missing word in the vocabulary.
# Skipping entry ['Islamabad' 'Pakistan' 'Kabul' 'Afghanistan'] due to missing word in the vocabulary.
# Skipping entry ['Islamabad' 'Pakistan' 'London' 'England'] due to missing word in the vocabulary.
# Skipping entry ['Islamabad' 'Pakistan' 'Madrid' 'Spain'] due to missing word in the vocabulary.
# Skipping entry ['Islamabad' 'Pakistan' 'Moscow' 'Russia'] due to missing word in the vocabulary.
# Skipping entry ['Islamabad' 'Pakistan' 'Oslo' 'Norway'] due to missing word in the vocabulary.
# Skipping entry ['Islamabad' 'Pakistan' 'Ottawa' 'Canada'] due to missing word in the vocabulary.
# Skipping entry ['Islamabad' 'Pakistan' 'Paris' 'France'] due to missing word in the vocabulary.
# Skipping entry ['Islamabad' 'Pakistan' 'Rome' 'Italy'] due to missing word in the vocabulary.
# Skipping entry ['Islamabad' 'Pakistan' 'Stockholm' 'Sweden'] due to missing word in the vocabulary.
# Skipping entry ['Islamabad' 'Pakistan' 'Tehran' 'Iran'] due to missing word in the vocabulary.
# Skipping entry ['Islamabad' 'Pakistan' 'Tokyo' 'Japan'] due to missing word in the vocabulary.
# Skipping entry ['Islamabad' 'Pakistan' 'Athens' 'Greece'] due to missing word in the vocabulary.
# Skipping entry ['Islamabad' 'Pakistan' 'Baghdad' 'Iraq'] due to missing word in the vocabulary.
# Skipping entry ['Islamabad' 'Pakistan' 'Bangkok' 'Thailand'] due to missing word in the vocabulary.
# Skipping entry ['Islamabad' 'Pakistan' 'Beijing' 'China'] due to missing word in the vocabulary.
# Skipping entry ['Islamabad' 'Pakistan' 'Berlin' 'Germany'] due to missing word in the vocabulary.
# Skipping entry ['Islamabad' 'Pakistan' 'Bern' 'Switzerland'] due to missing word in the vocabulary.
# Skipping entry ['Islamabad' 'Pakistan' 'Cairo' 'Egypt'] due to missing word in the vocabulary.
# Skipping entry ['Islamabad' 'Pakistan' 'Canberra' 'Australia'] due to missing word in the vocabulary.
# Skipping entry ['Islamabad' 'Pakistan' 'Hanoi' 'Vietnam'] due to missing word in the vocabulary.
# Skipping entry ['Islamabad' 'Pakistan' 'Havana' 'Cuba'] due to missing word in the vocabulary.
# Skipping entry ['Islamabad' 'Pakistan' 'Helsinki' 'Finland'] due to missing word in the vocabulary.
# Skipping entry ['Kabul' 'Afghanistan' 'London' 'England'] due to missing word in the vocabulary.
# Skipping entry ['Kabul' 'Afghanistan' 'Madrid' 'Spain'] due to missing word in the vocabulary.
# Skipping entry ['Kabul' 'Afghanistan' 'Moscow' 'Russia'] due to missing word in the vocabulary.
# Skipping entry ['Kabul' 'Afghanistan' 'Oslo' 'Norway'] due to missing word in the vocabulary.
# Skipping entry ['Kabul' 'Afghanistan' 'Ottawa' 'Canada'] due to missing word in the vocabulary.
# Skipping entry ['Kabul' 'Afghanistan' 'Paris' 'France'] due to missing word in the vocabulary.
# Skipping entry ['Kabul' 'Afghanistan' 'Rome' 'Italy'] due to missing word in the vocabulary.
# Skipping entry ['Kabul' 'Afghanistan' 'Stockholm' 'Sweden'] due to missing word in the vocabulary.
# Skipping entry ['Kabul' 'Afghanistan' 'Tehran' 'Iran'] due to missing word in the vocabulary.
# Skipping entry ['Kabul' 'Afghanistan' 'Tokyo' 'Japan'] due to missing word in the vocabulary.
# Skipping entry ['Kabul' 'Afghanistan' 'Athens' 'Greece'] due to missing word in the vocabulary.
# Skipping entry ['Kabul' 'Afghanistan' 'Baghdad' 'Iraq'] due to missing word in the vocabulary.
# Skipping entry ['Kabul' 'Afghanistan' 'Bangkok' 'Thailand'] due to missing word in the vocabulary.
# Skipping entry ['Kabul' 'Afghanistan' 'Beijing' 'China'] due to missing word in the vocabulary.
# Skipping entry ['Kabul' 'Afghanistan' 'Berlin' 'Germany'] due to missing word in the vocabulary.
# Skipping entry ['Kabul' 'Afghanistan' 'Bern' 'Switzerland'] due to missing word in the vocabulary.
# Skipping entry ['Kabul' 'Afghanistan' 'Cairo' 'Egypt'] due to missing word in the vocabulary.
# Skipping entry ['Kabul' 'Afghanistan' 'Canberra' 'Australia'] due to missing word in the vocabulary.
# Skipping entry ['Kabul' 'Afghanistan' 'Hanoi' 'Vietnam'] due to missing word in the vocabulary.
# Skipping entry ['Kabul' 'Afghanistan' 'Havana' 'Cuba'] due to missing word in the vocabulary.
# Skipping entry ['Kabul' 'Afghanistan' 'Helsinki' 'Finland'] due to missing word in the vocabulary.
# Skipping entry ['Kabul' 'Afghanistan' 'Islamabad' 'Pakistan'] due to missing word in the vocabulary.
# Skipping entry ['London' 'England' 'Madrid' 'Spain'] due to missing word in the vocabulary.
# Skipping entry ['London' 'England' 'Moscow' 'Russia'] due to missing word in the vocabulary.
# Skipping entry ['London' 'England' 'Oslo' 'Norway'] due to missing word in the vocabulary.
# Skipping entry ['London' 'England' 'Ottawa' 'Canada'] due to missing word in the vocabulary.
# Skipping entry ['London' 'England' 'Paris' 'France'] due to missing word in the vocabulary.
# Skipping entry ['London' 'England' 'Rome' 'Italy'] due to missing word in the vocabulary.
# Skipping entry ['London' 'England' 'Stockholm' 'Sweden'] due to missing word in the vocabulary.
# Skipping entry ['London' 'England' 'Tehran' 'Iran'] due to missing word in the vocabulary.
# Skipping entry ['London' 'England' 'Tokyo' 'Japan'] due to missing word in the vocabulary.
# Skipping entry ['London' 'England' 'Athens' 'Greece'] due to missing word in the vocabulary.
# Skipping entry ['London' 'England' 'Baghdad' 'Iraq'] due to missing word in the vocabulary.
# Skipping entry ['London' 'England' 'Bangkok' 'Thailand'] due to missing word in the vocabulary.
# Skipping entry ['London' 'England' 'Beijing' 'China'] due to missing word in the vocabulary.
# Skipping entry ['London' 'England' 'Berlin' 'Germany'] due to missing word in the vocabulary.
# Skipping entry ['London' 'England' 'Bern' 'Switzerland'] due to missing word in the vocabulary.
# Skipping entry ['London' 'England' 'Cairo' 'Egypt'] due to missing word in the vocabulary.
# Skipping entry ['London' 'England' 'Canberra' 'Australia'] due to missing word in the vocabulary.
# Skipping entry ['London' 'England' 'Hanoi' 'Vietnam'] due to missing word in the vocabulary.
# Skipping entry ['London' 'England' 'Havana' 'Cuba'] due to missing word in the vocabulary.
# Skipping entry ['London' 'England' 'Helsinki' 'Finland'] due to missing word in the vocabulary.
# Skipping entry ['London' 'England' 'Islamabad' 'Pakistan'] due to missing word in the vocabulary.
# Skipping entry ['London' 'England' 'Kabul' 'Afghanistan'] due to missing word in the vocabulary.
# Skipping entry ['Madrid' 'Spain' 'Moscow' 'Russia'] due to missing word in the vocabulary.
# Skipping entry ['Madrid' 'Spain' 'Oslo' 'Norway'] due to missing word in the vocabulary.
# Skipping entry ['Madrid' 'Spain' 'Ottawa' 'Canada'] due to missing word in the vocabulary.
# Skipping entry ['Madrid' 'Spain' 'Paris' 'France'] due to missing word in the vocabulary.
# Skipping entry ['Madrid' 'Spain' 'Rome' 'Italy'] due to missing word in the vocabulary.
# Skipping entry ['Madrid' 'Spain' 'Stockholm' 'Sweden'] due to missing word in the vocabulary.
# Skipping entry ['Madrid' 'Spain' 'Tehran' 'Iran'] due to missing word in the vocabulary.
# Skipping entry ['Madrid' 'Spain' 'Tokyo' 'Japan'] due to missing word in the vocabulary.
# Skipping entry ['Madrid' 'Spain' 'Athens' 'Greece'] due to missing word in the vocabulary.
# Skipping entry ['Madrid' 'Spain' 'Baghdad' 'Iraq'] due to missing word in the vocabulary.
# Skipping entry ['Madrid' 'Spain' 'Bangkok' 'Thailand'] due to missing word in the vocabulary.
# Skipping entry ['Madrid' 'Spain' 'Beijing' 'China'] due to missing word in the vocabulary.
# Skipping entry ['Madrid' 'Spain' 'Berlin' 'Germany'] due to missing word in the vocabulary.
# Skipping entry ['Madrid' 'Spain' 'Bern' 'Switzerland'] due to missing word in the vocabulary.
# Skipping entry ['Madrid' 'Spain' 'Cairo' 'Egypt'] due to missing word in the vocabulary.
# Skipping entry ['Madrid' 'Spain' 'Canberra' 'Australia'] due to missing word in the vocabulary.
# Skipping entry ['Madrid' 'Spain' 'Hanoi' 'Vietnam'] due to missing word in the vocabulary.
# Skipping entry ['Madrid' 'Spain' 'Havana' 'Cuba'] due to missing word in the vocabulary.
# Skipping entry ['Madrid' 'Spain' 'Helsinki' 'Finland'] due to missing word in the vocabulary.
# Skipping entry ['Madrid' 'Spain' 'Islamabad' 'Pakistan'] due to missing word in the vocabulary.
# Skipping entry ['Madrid' 'Spain' 'Kabul' 'Afghanistan'] due to missing word in the vocabulary.
# Skipping entry ['Madrid' 'Spain' 'London' 'England'] due to missing word in the vocabulary.
# Skipping entry ['Moscow' 'Russia' 'Oslo' 'Norway'] due to missing word in the vocabulary.
# Skipping entry ['Moscow' 'Russia' 'Ottawa' 'Canada'] due to missing word in the vocabulary.
# Skipping entry ['Moscow' 'Russia' 'Paris' 'France'] due to missing word in the vocabulary.
# Skipping entry ['Moscow' 'Russia' 'Rome' 'Italy'] due to missing word in the vocabulary.
# Skipping entry ['Moscow' 'Russia' 'Stockholm' 'Sweden'] due to missing word in the vocabulary.
# Skipping entry ['Moscow' 'Russia' 'Tehran' 'Iran'] due to missing word in the vocabulary.
# Skipping entry ['Moscow' 'Russia' 'Tokyo' 'Japan'] due to missing word in the vocabulary.
# Skipping entry ['Moscow' 'Russia' 'Athens' 'Greece'] due to missing word in the vocabulary.
# Skipping entry ['Moscow' 'Russia' 'Baghdad' 'Iraq'] due to missing word in the vocabulary.
# Skipping entry ['Moscow' 'Russia' 'Bangkok' 'Thailand'] due to missing word in the vocabulary.
# Skipping entry ['Moscow' 'Russia' 'Beijing' 'China'] due to missing word in the vocabulary.
# Skipping entry ['Moscow' 'Russia' 'Berlin' 'Germany'] due to missing word in the vocabulary.
# Skipping entry ['Moscow' 'Russia' 'Bern' 'Switzerland'] due to missing word in the vocabulary.
# Skipping entry ['Moscow' 'Russia' 'Cairo' 'Egypt'] due to missing word in the vocabulary.
# Skipping entry ['Moscow' 'Russia' 'Canberra' 'Australia'] due to missing word in the vocabulary.
# Skipping entry ['Moscow' 'Russia' 'Hanoi' 'Vietnam'] due to missing word in the vocabulary.
# Skipping entry ['Moscow' 'Russia' 'Havana' 'Cuba'] due to missing word in the vocabulary.
# Skipping entry ['Moscow' 'Russia' 'Helsinki' 'Finland'] due to missing word in the vocabulary.
# Skipping entry ['Moscow' 'Russia' 'Islamabad' 'Pakistan'] due to missing word in the vocabulary.
# Skipping entry ['Moscow' 'Russia' 'Kabul' 'Afghanistan'] due to missing word in the vocabulary.
# Skipping entry ['Moscow' 'Russia' 'London' 'England'] due to missing word in the vocabulary.
# Skipping entry ['Moscow' 'Russia' 'Madrid' 'Spain'] due to missing word in the vocabulary.
# Skipping entry ['Oslo' 'Norway' 'Ottawa' 'Canada'] due to missing word in the vocabulary.
# Skipping entry ['Oslo' 'Norway' 'Paris' 'France'] due to missing word in the vocabulary.
# Skipping entry ['Oslo' 'Norway' 'Rome' 'Italy'] due to missing word in the vocabulary.
# Skipping entry ['Oslo' 'Norway' 'Stockholm' 'Sweden'] due to missing word in the vocabulary.
# Skipping entry ['Oslo' 'Norway' 'Tehran' 'Iran'] due to missing word in the vocabulary.
# Skipping entry ['Oslo' 'Norway' 'Tokyo' 'Japan'] due to missing word in the vocabulary.
# Skipping entry ['Oslo' 'Norway' 'Athens' 'Greece'] due to missing word in the vocabulary.
# Skipping entry ['Oslo' 'Norway' 'Baghdad' 'Iraq'] due to missing word in the vocabulary.
# Skipping entry ['Oslo' 'Norway' 'Bangkok' 'Thailand'] due to missing word in the vocabulary.
# Skipping entry ['Oslo' 'Norway' 'Beijing' 'China'] due to missing word in the vocabulary.
# Skipping entry ['Oslo' 'Norway' 'Berlin' 'Germany'] due to missing word in the vocabulary.
# Skipping entry ['Oslo' 'Norway' 'Bern' 'Switzerland'] due to missing word in the vocabulary.
# Skipping entry ['Oslo' 'Norway' 'Cairo' 'Egypt'] due to missing word in the vocabulary.
# Skipping entry ['Oslo' 'Norway' 'Canberra' 'Australia'] due to missing word in the vocabulary.
# Skipping entry ['Oslo' 'Norway' 'Hanoi' 'Vietnam'] due to missing word in the vocabulary.
# Skipping entry ['Oslo' 'Norway' 'Havana' 'Cuba'] due to missing word in the vocabulary.
# Skipping entry ['Oslo' 'Norway' 'Helsinki' 'Finland'] due to missing word in the vocabulary.
# Skipping entry ['Oslo' 'Norway' 'Islamabad' 'Pakistan'] due to missing word in the vocabulary.
# Skipping entry ['Oslo' 'Norway' 'Kabul' 'Afghanistan'] due to missing word in the vocabulary.
# Skipping entry ['Oslo' 'Norway' 'London' 'England'] due to missing word in the vocabulary.
# Skipping entry ['Oslo' 'Norway' 'Madrid' 'Spain'] due to missing word in the vocabulary.
# Skipping entry ['Oslo' 'Norway' 'Moscow' 'Russia'] due to missing word in the vocabulary.
# Skipping entry ['Ottawa' 'Canada' 'Paris' 'France'] due to missing word in the vocabulary.
# Skipping entry ['Ottawa' 'Canada' 'Rome' 'Italy'] due to missing word in the vocabulary.
# Skipping entry ['Ottawa' 'Canada' 'Stockholm' 'Sweden'] due to missing word in the vocabulary.
# Skipping entry ['Ottawa' 'Canada' 'Tehran' 'Iran'] due to missing word in the vocabulary.
# Skipping entry ['Ottawa' 'Canada' 'Tokyo' 'Japan'] due to missing word in the vocabulary.
# Skipping entry ['Ottawa' 'Canada' 'Athens' 'Greece'] due to missing word in the vocabulary.
# Skipping entry ['Ottawa' 'Canada' 'Baghdad' 'Iraq'] due to missing word in the vocabulary.
# Skipping entry ['Ottawa' 'Canada' 'Bangkok' 'Thailand'] due to missing word in the vocabulary.
# Skipping entry ['Ottawa' 'Canada' 'Beijing' 'China'] due to missing word in the vocabulary.
# Skipping entry ['Ottawa' 'Canada' 'Berlin' 'Germany'] due to missing word in the vocabulary.
# Skipping entry ['Ottawa' 'Canada' 'Bern' 'Switzerland'] due to missing word in the vocabulary.
# Skipping entry ['Ottawa' 'Canada' 'Cairo' 'Egypt'] due to missing word in the vocabulary.
# Skipping entry ['Ottawa' 'Canada' 'Canberra' 'Australia'] due to missing word in the vocabulary.
# Skipping entry ['Ottawa' 'Canada' 'Hanoi' 'Vietnam'] due to missing word in the vocabulary.
# Skipping entry ['Ottawa' 'Canada' 'Havana' 'Cuba'] due to missing word in the vocabulary.
# Skipping entry ['Ottawa' 'Canada' 'Helsinki' 'Finland'] due to missing word in the vocabulary.
# Skipping entry ['Ottawa' 'Canada' 'Islamabad' 'Pakistan'] due to missing word in the vocabulary.
# Skipping entry ['Ottawa' 'Canada' 'Kabul' 'Afghanistan'] due to missing word in the vocabulary.
# Skipping entry ['Ottawa' 'Canada' 'London' 'England'] due to missing word in the vocabulary.
# Skipping entry ['Ottawa' 'Canada' 'Madrid' 'Spain'] due to missing word in the vocabulary.
# Skipping entry ['Ottawa' 'Canada' 'Moscow' 'Russia'] due to missing word in the vocabulary.
# Skipping entry ['Ottawa' 'Canada' 'Oslo' 'Norway'] due to missing word in the vocabulary.
# Skipping entry ['Paris' 'France' 'Rome' 'Italy'] due to missing word in the vocabulary.
# Skipping entry ['Paris' 'France' 'Stockholm' 'Sweden'] due to missing word in the vocabulary.
# Skipping entry ['Paris' 'France' 'Tehran' 'Iran'] due to missing word in the vocabulary.
# Skipping entry ['Paris' 'France' 'Tokyo' 'Japan'] due to missing word in the vocabulary.
# Skipping entry ['Paris' 'France' 'Athens' 'Greece'] due to missing word in the vocabulary.
# Skipping entry ['Paris' 'France' 'Baghdad' 'Iraq'] due to missing word in the vocabulary.
# Skipping entry ['Paris' 'France' 'Bangkok' 'Thailand'] due to missing word in the vocabulary.
# Skipping entry ['Paris' 'France' 'Beijing' 'China'] due to missing word in the vocabulary.
# Skipping entry ['Paris' 'France' 'Berlin' 'Germany'] due to missing word in the vocabulary.
# Skipping entry ['Paris' 'France' 'Bern' 'Switzerland'] due to missing word in the vocabulary.
# Skipping entry ['Paris' 'France' 'Cairo' 'Egypt'] due to missing word in the vocabulary.
# Skipping entry ['Paris' 'France' 'Canberra' 'Australia'] due to missing word in the vocabulary.
# Skipping entry ['Paris' 'France' 'Hanoi' 'Vietnam'] due to missing word in the vocabulary.
# Skipping entry ['Paris' 'France' 'Havana' 'Cuba'] due to missing word in the vocabulary.
# Skipping entry ['Paris' 'France' 'Helsinki' 'Finland'] due to missing word in the vocabulary.
# Skipping entry ['Paris' 'France' 'Islamabad' 'Pakistan'] due to missing word in the vocabulary.
# Skipping entry ['Paris' 'France' 'Kabul' 'Afghanistan'] due to missing word in the vocabulary.
# Skipping entry ['Paris' 'France' 'London' 'England'] due to missing word in the vocabulary.
# Skipping entry ['Paris' 'France' 'Madrid' 'Spain'] due to missing word in the vocabulary.
# Skipping entry ['Paris' 'France' 'Moscow' 'Russia'] due to missing word in the vocabulary.
# Skipping entry ['Paris' 'France' 'Oslo' 'Norway'] due to missing word in the vocabulary.
# Skipping entry ['Paris' 'France' 'Ottawa' 'Canada'] due to missing word in the vocabulary.
# Skipping entry ['Rome' 'Italy' 'Stockholm' 'Sweden'] due to missing word in the vocabulary.
# Skipping entry ['Rome' 'Italy' 'Tehran' 'Iran'] due to missing word in the vocabulary.
# Skipping entry ['Rome' 'Italy' 'Tokyo' 'Japan'] due to missing word in the vocabulary.
# Skipping entry ['Rome' 'Italy' 'Athens' 'Greece'] due to missing word in the vocabulary.
# Skipping entry ['Rome' 'Italy' 'Baghdad' 'Iraq'] due to missing word in the vocabulary.
# Skipping entry ['Rome' 'Italy' 'Bangkok' 'Thailand'] due to missing word in the vocabulary.
# Skipping entry ['Rome' 'Italy' 'Beijing' 'China'] due to missing word in the vocabulary.
# Skipping entry ['Rome' 'Italy' 'Berlin' 'Germany'] due to missing word in the vocabulary.
# Skipping entry ['Rome' 'Italy' 'Bern' 'Switzerland'] due to missing word in the vocabulary.
# Skipping entry ['Rome' 'Italy' 'Cairo' 'Egypt'] due to missing word in the vocabulary.
# Skipping entry ['Rome' 'Italy' 'Canberra' 'Australia'] due to missing word in the vocabulary.
# Skipping entry ['Rome' 'Italy' 'Hanoi' 'Vietnam'] due to missing word in the vocabulary.
# Skipping entry ['Rome' 'Italy' 'Havana' 'Cuba'] due to missing word in the vocabulary.
# Skipping entry ['Rome' 'Italy' 'Helsinki' 'Finland'] due to missing word in the vocabulary.
# Skipping entry ['Rome' 'Italy' 'Islamabad' 'Pakistan'] due to missing word in the vocabulary.
# Skipping entry ['Rome' 'Italy' 'Kabul' 'Afghanistan'] due to missing word in the vocabulary.
# Skipping entry ['Rome' 'Italy' 'London' 'England'] due to missing word in the vocabulary.
# Skipping entry ['Rome' 'Italy' 'Madrid' 'Spain'] due to missing word in the vocabulary.
# Skipping entry ['Rome' 'Italy' 'Moscow' 'Russia'] due to missing word in the vocabulary.
# Skipping entry ['Rome' 'Italy' 'Oslo' 'Norway'] due to missing word in the vocabulary.
# Skipping entry ['Rome' 'Italy' 'Ottawa' 'Canada'] due to missing word in the vocabulary.
# Skipping entry ['Rome' 'Italy' 'Paris' 'France'] due to missing word in the vocabulary.
# Skipping entry ['Stockholm' 'Sweden' 'Tehran' 'Iran'] due to missing word in the vocabulary.
# Skipping entry ['Stockholm' 'Sweden' 'Tokyo' 'Japan'] due to missing word in the vocabulary.
# Skipping entry ['Stockholm' 'Sweden' 'Athens' 'Greece'] due to missing word in the vocabulary.
# Skipping entry ['Stockholm' 'Sweden' 'Baghdad' 'Iraq'] due to missing word in the vocabulary.
# Skipping entry ['Stockholm' 'Sweden' 'Bangkok' 'Thailand'] due to missing word in the vocabulary.
# Skipping entry ['Stockholm' 'Sweden' 'Beijing' 'China'] due to missing word in the vocabulary.
# Skipping entry ['Stockholm' 'Sweden' 'Berlin' 'Germany'] due to missing word in the vocabulary.
# Skipping entry ['Stockholm' 'Sweden' 'Bern' 'Switzerland'] due to missing word in the vocabulary.
# Skipping entry ['Stockholm' 'Sweden' 'Cairo' 'Egypt'] due to missing word in the vocabulary.
# Skipping entry ['Stockholm' 'Sweden' 'Canberra' 'Australia'] due to missing word in the vocabulary.
# Skipping entry ['Stockholm' 'Sweden' 'Hanoi' 'Vietnam'] due to missing word in the vocabulary.
# Skipping entry ['Stockholm' 'Sweden' 'Havana' 'Cuba'] due to missing word in the vocabulary.
# Skipping entry ['Stockholm' 'Sweden' 'Helsinki' 'Finland'] due to missing word in the vocabulary.
# Skipping entry ['Stockholm' 'Sweden' 'Islamabad' 'Pakistan'] due to missing word in the vocabulary.
# Skipping entry ['Stockholm' 'Sweden' 'Kabul' 'Afghanistan'] due to missing word in the vocabulary.
# Skipping entry ['Stockholm' 'Sweden' 'London' 'England'] due to missing word in the vocabulary.
# Skipping entry ['Stockholm' 'Sweden' 'Madrid' 'Spain'] due to missing word in the vocabulary.
# Skipping entry ['Stockholm' 'Sweden' 'Moscow' 'Russia'] due to missing word in the vocabulary.
# Skipping entry ['Stockholm' 'Sweden' 'Oslo' 'Norway'] due to missing word in the vocabulary.
# Skipping entry ['Stockholm' 'Sweden' 'Ottawa' 'Canada'] due to missing word in the vocabulary.
# Skipping entry ['Stockholm' 'Sweden' 'Paris' 'France'] due to missing word in the vocabulary.
# Skipping entry ['Stockholm' 'Sweden' 'Rome' 'Italy'] due to missing word in the vocabulary.
# Skipping entry ['Tehran' 'Iran' 'Tokyo' 'Japan'] due to missing word in the vocabulary.
# Skipping entry ['Tehran' 'Iran' 'Athens' 'Greece'] due to missing word in the vocabulary.
# Skipping entry ['Tehran' 'Iran' 'Baghdad' 'Iraq'] due to missing word in the vocabulary.
# Skipping entry ['Tehran' 'Iran' 'Bangkok' 'Thailand'] due to missing word in the vocabulary.
# Skipping entry ['Tehran' 'Iran' 'Beijing' 'China'] due to missing word in the vocabulary.
# Skipping entry ['Tehran' 'Iran' 'Berlin' 'Germany'] due to missing word in the vocabulary.
# Skipping entry ['Tehran' 'Iran' 'Bern' 'Switzerland'] due to missing word in the vocabulary.
# Skipping entry ['Tehran' 'Iran' 'Cairo' 'Egypt'] due to missing word in the vocabulary.
# Skipping entry ['Tehran' 'Iran' 'Canberra' 'Australia'] due to missing word in the vocabulary.
# Skipping entry ['Tehran' 'Iran' 'Hanoi' 'Vietnam'] due to missing word in the vocabulary.
# Skipping entry ['Tehran' 'Iran' 'Havana' 'Cuba'] due to missing word in the vocabulary.
# Skipping entry ['Tehran' 'Iran' 'Helsinki' 'Finland'] due to missing word in the vocabulary.
# Skipping entry ['Tehran' 'Iran' 'Islamabad' 'Pakistan'] due to missing word in the vocabulary.
# Skipping entry ['Tehran' 'Iran' 'Kabul' 'Afghanistan'] due to missing word in the vocabulary.
# Skipping entry ['Tehran' 'Iran' 'London' 'England'] due to missing word in the vocabulary.
# Skipping entry ['Tehran' 'Iran' 'Madrid' 'Spain'] due to missing word in the vocabulary.
# Skipping entry ['Tehran' 'Iran' 'Moscow' 'Russia'] due to missing word in the vocabulary.
# Skipping entry ['Tehran' 'Iran' 'Oslo' 'Norway'] due to missing word in the vocabulary.
# Skipping entry ['Tehran' 'Iran' 'Ottawa' 'Canada'] due to missing word in the vocabulary.
# Skipping entry ['Tehran' 'Iran' 'Paris' 'France'] due to missing word in the vocabulary.
# Skipping entry ['Tehran' 'Iran' 'Rome' 'Italy'] due to missing word in the vocabulary.
# Skipping entry ['Tehran' 'Iran' 'Stockholm' 'Sweden'] due to missing word in the vocabulary.
# Skipping entry ['Tokyo' 'Japan' 'Athens' 'Greece'] due to missing word in the vocabulary.
# Skipping entry ['Tokyo' 'Japan' 'Baghdad' 'Iraq'] due to missing word in the vocabulary.
# Skipping entry ['Tokyo' 'Japan' 'Bangkok' 'Thailand'] due to missing word in the vocabulary.
# Skipping entry ['Tokyo' 'Japan' 'Beijing' 'China'] due to missing word in the vocabulary.
# Skipping entry ['Tokyo' 'Japan' 'Berlin' 'Germany'] due to missing word in the vocabulary.
# Skipping entry ['Tokyo' 'Japan' 'Bern' 'Switzerland'] due to missing word in the vocabulary.
# Skipping entry ['Tokyo' 'Japan' 'Cairo' 'Egypt'] due to missing word in the vocabulary.
# Skipping entry ['Tokyo' 'Japan' 'Canberra' 'Australia'] due to missing word in the vocabulary.
# Skipping entry ['Tokyo' 'Japan' 'Hanoi' 'Vietnam'] due to missing word in the vocabulary.
# Skipping entry ['Tokyo' 'Japan' 'Havana' 'Cuba'] due to missing word in the vocabulary.
# Skipping entry ['Tokyo' 'Japan' 'Helsinki' 'Finland'] due to missing word in the vocabulary.
# Skipping entry ['Tokyo' 'Japan' 'Islamabad' 'Pakistan'] due to missing word in the vocabulary.
# Skipping entry ['Tokyo' 'Japan' 'Kabul' 'Afghanistan'] due to missing word in the vocabulary.
# Skipping entry ['Tokyo' 'Japan' 'London' 'England'] due to missing word in the vocabulary.
# Skipping entry ['Tokyo' 'Japan' 'Madrid' 'Spain'] due to missing word in the vocabulary.
# Skipping entry ['Tokyo' 'Japan' 'Moscow' 'Russia'] due to missing word in the vocabulary.
# Skipping entry ['Tokyo' 'Japan' 'Oslo' 'Norway'] due to missing word in the vocabulary.
# Skipping entry ['Tokyo' 'Japan' 'Ottawa' 'Canada'] due to missing word in the vocabulary.
# Skipping entry ['Tokyo' 'Japan' 'Paris' 'France'] due to missing word in the vocabulary.
# Skipping entry ['Tokyo' 'Japan' 'Rome' 'Italy'] due to missing word in the vocabulary.
# Skipping entry ['Tokyo' 'Japan' 'Stockholm' 'Sweden'] due to missing word in the vocabulary.
# Skipping entry ['Tokyo' 'Japan' 'Tehran' 'Iran'] due to missing word in the vocabulary.
# Skipping entry ['Abuja' 'Nigeria' 'Accra' 'Ghana'] due to missing word in the vocabulary.
# Skipping entry ['Abuja' 'Nigeria' 'Algiers' 'Algeria'] due to missing word in the vocabulary.
# Skipping entry ['Abuja' 'Nigeria' 'Amman' 'Jordan'] due to missing word in the vocabulary.
# Skipping entry ['Abuja' 'Nigeria' 'Ankara' 'Turkey'] due to missing word in the vocabulary.
# Skipping entry ['Abuja' 'Nigeria' 'Antananarivo' 'Madagascar'] due to missing word in the vocabulary.
# Skipping entry ['Abuja' 'Nigeria' 'Apia' 'Samoa'] due to missing word in the vocabulary.
# Skipping entry ['Abuja' 'Nigeria' 'Ashgabat' 'Turkmenistan'] due to missing word in the vocabulary.
# Skipping entry ['Abuja' 'Nigeria' 'Asmara' 'Eritrea'] due to missing word in the vocabulary.
# Skipping entry ['Abuja' 'Nigeria' 'Astana' 'Kazakhstan'] due to missing word in the vocabulary.
# ...
# Skipping entry ['Sweden' 'Swedish' 'Thailand' 'Thai'] due to missing word in the vocabulary.
# Skipping entry ['Sweden' 'Swedish' 'Ukraine' 'Ukrainian'] due to missing word in the vocabulary.
# Skipping entry ['Sweden' 'Swedish' 'Albania' 'Albanian'] due to missing word in the vocabulary.
# Skipping entry ['Sweden' 'Swedish' 'Argentina' 'Argentinean'] due to missing word in the vocabulary.
# Skipping entry ['Sweden' 'Swedish' 'Australia' 'Australian'] due to missing word in the vocabulary.
# Skipping entry ['Sweden' 'Swedish' 'Austria' 'Austrian'] due to missing word in the vocabulary.
# Skipping entry ['Sweden' 'Swedish' 'Belarus' 'Belorussian'] due to missing word in the vocabulary.
# Skipping entry ['Sweden' 'Swedish' 'Brazil' 'Brazilian'] due to missing word in the vocabulary.
# Skipping entry ['Sweden' 'Swedish' 'Bulgaria' 'Bulgarian'] due to missing word in the vocabulary.
# Skipping entry ['Sweden' 'Swedish' 'Cambodia' 'Cambodian'] due to missing word in the vocabulary.
# Skipping entry ['Sweden' 'Swedish' 'Chile' 'Chilean'] due to missing word in the vocabulary.
# Skipping entry ['Sweden' 'Swedish' 'China' 'Chinese'] due to missing word in the vocabulary.
# Skipping entry ['Sweden' 'Swedish' 'Colombia' 'Colombian'] due to missing word in the vocabulary.
# Skipping entry ['Sweden' 'Swedish' 'Croatia' 'Croatian'] due to missing word in the vocabulary.
# Skipping entry ['Sweden' 'Swedish' 'Denmark' 'Danish'] due to missing word in the vocabulary.
# Skipping entry ['Sweden' 'Swedish' 'Egypt' 'Egyptian'] due to missing word in the vocabulary.
# Skipping entry ['Sweden' 'Swedish' 'England' 'English'] due to missing word in the vocabulary.
# Skipping entry ['Sweden' 'Swedish' 'France' 'French'] due to missing word in the vocabulary.
# Skipping entry ['Sweden' 'Swedish' 'Germany' 'German'] due to missing word in the vocabulary.
# Skipping entry ['Sweden' 'Swedish' 'Greece' 'Greek'] due to missing word in the vocabulary.
# Skipping entry ['Sweden' 'Swedish' 'Iceland' 'Icelandic'] due to missing word in the vocabulary.
# Skipping entry ['Sweden' 'Swedish' 'India' 'Indian'] due to missing word in the vocabulary.
# Skipping entry ['Sweden' 'Swedish' 'Ireland' 'Irish'] due to missing word in the vocabulary.
# Skipping entry ['Sweden' 'Swedish' 'Israel' 'Israeli'] due to missing word in the vocabulary.
# Skipping entry ['Sweden' 'Swedish' 'Italy' 'Italian'] due to missing word in the vocabulary.
# Skipping entry ['Sweden' 'Swedish' 'Japan' 'Japanese'] due to missing word in the vocabulary.
# Skipping entry ['Sweden' 'Swedish' 'Korea' 'Korean'] due to missing word in the vocabulary.
# Skipping entry ['Sweden' 'Swedish' 'Macedonia' 'Macedonian'] due to missing word in the vocabulary.
# Skipping entry ['Sweden' 'Swedish' 'Malta' 'Maltese'] due to missing word in the vocabulary.
# Skipping entry ['Sweden' 'Swedish' 'Mexico' 'Mexican'] due to missing word in the vocabulary.
# Skipping entry ['Sweden' 'Swedish' 'Moldova' 'Moldovan'] due to missing word in the vocabulary.
# Skipping entry ['Sweden' 'Swedish' 'Netherlands' 'Dutch'] due to missing word in the vocabulary.
# Skipping entry ['Sweden' 'Swedish' 'Norway' 'Norwegian'] due to missing word in the vocabulary.
# Skipping entry ['Sweden' 'Swedish' 'Peru' 'Peruvian'] due to missing word in the vocabulary.
# Skipping entry ['Sweden' 'Swedish' 'Poland' 'Polish'] due to missing word in the vocabulary.
# Skipping entry ['Sweden' 'Swedish' 'Portugal' 'Portuguese'] due to missing word in the vocabulary.
# Skipping entry ['Sweden' 'Swedish' 'Russia' 'Russian'] due to missing word in the vocabulary.
# Skipping entry ['Sweden' 'Swedish' 'Slovakia' 'Slovakian'] due to missing word in the vocabulary.
# Skipping entry ['Switzerland' 'Swiss' 'Thailand' 'Thai'] due to missing word in the vocabulary.
# Skipping entry ['Switzerland' 'Swiss' 'Ukraine' 'Ukrainian'] due to missing word in the vocabulary.
# Skipping entry ['Switzerland' 'Swiss' 'Albania' 'Albanian'] due to missing word in the vocabulary.
# Skipping entry ['Switzerland' 'Swiss' 'Argentina' 'Argentinean'] due to missing word in the vocabulary.
# Skipping entry ['Switzerland' 'Swiss' 'Australia' 'Australian'] due to missing word in the vocabulary.
# Skipping entry ['Switzerland' 'Swiss' 'Austria' 'Austrian'] due to missing word in the vocabulary.
# Skipping entry ['Switzerland' 'Swiss' 'Belarus' 'Belorussian'] due to missing word in the vocabulary.
# Skipping entry ['Switzerland' 'Swiss' 'Brazil' 'Brazilian'] due to missing word in the vocabulary.
# Skipping entry ['Switzerland' 'Swiss' 'Bulgaria' 'Bulgarian'] due to missing word in the vocabulary.
# Skipping entry ['Switzerland' 'Swiss' 'Cambodia' 'Cambodian'] due to missing word in the vocabulary.
# Skipping entry ['Switzerland' 'Swiss' 'Chile' 'Chilean'] due to missing word in the vocabulary.
# Skipping entry ['Switzerland' 'Swiss' 'China' 'Chinese'] due to missing word in the vocabulary.
# Skipping entry ['Switzerland' 'Swiss' 'Colombia' 'Colombian'] due to missing word in the vocabulary.
# Skipping entry ['Switzerland' 'Swiss' 'Croatia' 'Croatian'] due to missing word in the vocabulary.
# Skipping entry ['Switzerland' 'Swiss' 'Denmark' 'Danish'] due to missing word in the vocabulary.
# Skipping entry ['Switzerland' 'Swiss' 'Egypt' 'Egyptian'] due to missing word in the vocabulary.
# Skipping entry ['Switzerland' 'Swiss' 'England' 'English'] due to missing word in the vocabulary.
# Skipping entry ['Switzerland' 'Swiss' 'France' 'French'] due to missing word in the vocabulary.
# Skipping entry ['Switzerland' 'Swiss' 'Germany' 'German'] due to missing word in the vocabulary.
# Skipping entry ['Switzerland' 'Swiss' 'Greece' 'Greek'] due to missing word in the vocabulary.
# Skipping entry ['Switzerland' 'Swiss' 'Iceland' 'Icelandic'] due to missing word in the vocabulary.
# Skipping entry ['Switzerland' 'Swiss' 'India' 'Indian'] due to missing word in the vocabulary.
# Skipping entry ['Switzerland' 'Swiss' 'Ireland' 'Irish'] due to missing word in the vocabulary.
# Skipping entry ['Switzerland' 'Swiss' 'Israel' 'Israeli'] due to missing word in the vocabulary.
# Skipping entry ['Switzerland' 'Swiss' 'Italy' 'Italian'] due to missing word in the vocabulary.
# Skipping entry ['Switzerland' 'Swiss' 'Japan' 'Japanese'] due to missing word in the vocabulary.
# Skipping entry ['Switzerland' 'Swiss' 'Korea' 'Korean'] due to missing word in the vocabulary.
# Skipping entry ['Switzerland' 'Swiss' 'Macedonia' 'Macedonian'] due to missing word in the vocabulary.
# Skipping entry ['Switzerland' 'Swiss' 'Malta' 'Maltese'] due to missing word in the vocabulary.
# Skipping entry ['Switzerland' 'Swiss' 'Mexico' 'Mexican'] due to missing word in the vocabulary.
# Skipping entry ['Switzerland' 'Swiss' 'Moldova' 'Moldovan'] due to missing word in the vocabulary.
# Skipping entry ['Switzerland' 'Swiss' 'Netherlands' 'Dutch'] due to missing word in the vocabulary.
# Skipping entry ['Switzerland' 'Swiss' 'Norway' 'Norwegian'] due to missing word in the vocabulary.
# Skipping entry ['Switzerland' 'Swiss' 'Peru' 'Peruvian'] due to missing word in the vocabulary.
# Skipping entry ['Switzerland' 'Swiss' 'Poland' 'Polish'] due to missing word in the vocabulary.
# Skipping entry ['Switzerland' 'Swiss' 'Portugal' 'Portuguese'] due to missing word in the vocabulary.
# Skipping entry ['Switzerland' 'Swiss' 'Russia' 'Russian'] due to missing word in the vocabulary.
# Skipping entry ['Switzerland' 'Swiss' 'Slovakia' 'Slovakian'] due to missing word in the vocabulary.
# Skipping entry ['Switzerland' 'Swiss' 'Spain' 'Spanish'] due to missing word in the vocabulary.
# Skipping entry ['Thailand' 'Thai' 'Ukraine' 'Ukrainian'] due to missing word in the vocabulary.
# Skipping entry ['Thailand' 'Thai' 'Albania' 'Albanian'] due to missing word in the vocabulary.
# Skipping entry ['Thailand' 'Thai' 'Argentina' 'Argentinean'] due to missing word in the vocabulary.
# Skipping entry ['Thailand' 'Thai' 'Australia' 'Australian'] due to missing word in the vocabulary.
# Skipping entry ['Thailand' 'Thai' 'Austria' 'Austrian'] due to missing word in the vocabulary.
# Skipping entry ['Thailand' 'Thai' 'Belarus' 'Belorussian'] due to missing word in the vocabulary.
# Skipping entry ['Thailand' 'Thai' 'Brazil' 'Brazilian'] due to missing word in the vocabulary.
# Skipping entry ['Thailand' 'Thai' 'Bulgaria' 'Bulgarian'] due to missing word in the vocabulary.
# Skipping entry ['Thailand' 'Thai' 'Cambodia' 'Cambodian'] due to missing word in the vocabulary.
# Skipping entry ['Thailand' 'Thai' 'Chile' 'Chilean'] due to missing word in the vocabulary.
# Skipping entry ['Thailand' 'Thai' 'China' 'Chinese'] due to missing word in the vocabulary.
# Skipping entry ['Thailand' 'Thai' 'Colombia' 'Colombian'] due to missing word in the vocabulary.
# Skipping entry ['Thailand' 'Thai' 'Croatia' 'Croatian'] due to missing word in the vocabulary.
# Skipping entry ['Thailand' 'Thai' 'Denmark' 'Danish'] due to missing word in the vocabulary.
# Skipping entry ['Thailand' 'Thai' 'Egypt' 'Egyptian'] due to missing word in the vocabulary.
# Skipping entry ['Thailand' 'Thai' 'England' 'English'] due to missing word in the vocabulary.
# Skipping entry ['Thailand' 'Thai' 'France' 'French'] due to missing word in the vocabulary.
# Skipping entry ['Thailand' 'Thai' 'Germany' 'German'] due to missing word in the vocabulary.
# Skipping entry ['Thailand' 'Thai' 'Greece' 'Greek'] due to missing word in the vocabulary.
# Skipping entry ['Thailand' 'Thai' 'Iceland' 'Icelandic'] due to missing word in the vocabulary.
# Skipping entry ['Thailand' 'Thai' 'India' 'Indian'] due to missing word in the vocabulary.
# Skipping entry ['Thailand' 'Thai' 'Ireland' 'Irish'] due to missing word in the vocabulary.
# Skipping entry ['Thailand' 'Thai' 'Israel' 'Israeli'] due to missing word in the vocabulary.
# Skipping entry ['Thailand' 'Thai' 'Italy' 'Italian'] due to missing word in the vocabulary.
# Skipping entry ['Thailand' 'Thai' 'Japan' 'Japanese'] due to missing word in the vocabulary.
# Skipping entry ['Thailand' 'Thai' 'Korea' 'Korean'] due to missing word in the vocabulary.
# Skipping entry ['Thailand' 'Thai' 'Macedonia' 'Macedonian'] due to missing word in the vocabulary.
# Skipping entry ['Thailand' 'Thai' 'Malta' 'Maltese'] due to missing word in the vocabulary.
# Skipping entry ['Thailand' 'Thai' 'Mexico' 'Mexican'] due to missing word in the vocabulary.
# Skipping entry ['Thailand' 'Thai' 'Moldova' 'Moldovan'] due to missing word in the vocabulary.
# Skipping entry ['Thailand' 'Thai' 'Netherlands' 'Dutch'] due to missing word in the vocabulary.
# Skipping entry ['Thailand' 'Thai' 'Norway' 'Norwegian'] due to missing word in the vocabulary.
# Skipping entry ['Thailand' 'Thai' 'Peru' 'Peruvian'] due to missing word in the vocabulary.
# Skipping entry ['Thailand' 'Thai' 'Poland' 'Polish'] due to missing word in the vocabulary.
# Skipping entry ['Thailand' 'Thai' 'Portugal' 'Portuguese'] due to missing word in the vocabulary.
# Skipping entry ['Thailand' 'Thai' 'Russia' 'Russian'] due to missing word in the vocabulary.
# Skipping entry ['Thailand' 'Thai' 'Slovakia' 'Slovakian'] due to missing word in the vocabulary.
# Skipping entry ['Thailand' 'Thai' 'Spain' 'Spanish'] due to missing word in the vocabulary.
# Skipping entry ['Thailand' 'Thai' 'Sweden' 'Swedish'] due to missing word in the vocabulary.
# Skipping entry ['Ukraine' 'Ukrainian' 'Albania' 'Albanian'] due to missing word in the vocabulary.
# Skipping entry ['Ukraine' 'Ukrainian' 'Argentina' 'Argentinean'] due to missing word in the vocabulary.
# Skipping entry ['Ukraine' 'Ukrainian' 'Australia' 'Australian'] due to missing word in the vocabulary.
# Skipping entry ['Ukraine' 'Ukrainian' 'Austria' 'Austrian'] due to missing word in the vocabulary.
# Skipping entry ['Ukraine' 'Ukrainian' 'Belarus' 'Belorussian'] due to missing word in the vocabulary.
# Skipping entry ['Ukraine' 'Ukrainian' 'Brazil' 'Brazilian'] due to missing word in the vocabulary.
# Skipping entry ['Ukraine' 'Ukrainian' 'Bulgaria' 'Bulgarian'] due to missing word in the vocabulary.
# Skipping entry ['Ukraine' 'Ukrainian' 'Cambodia' 'Cambodian'] due to missing word in the vocabulary.
# Skipping entry ['Ukraine' 'Ukrainian' 'Chile' 'Chilean'] due to missing word in the vocabulary.
# Skipping entry ['Ukraine' 'Ukrainian' 'China' 'Chinese'] due to missing word in the vocabulary.
# Skipping entry ['Ukraine' 'Ukrainian' 'Colombia' 'Colombian'] due to missing word in the vocabulary.
# Skipping entry ['Ukraine' 'Ukrainian' 'Croatia' 'Croatian'] due to missing word in the vocabulary.
# Skipping entry ['Ukraine' 'Ukrainian' 'Denmark' 'Danish'] due to missing word in the vocabulary.
# Skipping entry ['Ukraine' 'Ukrainian' 'Egypt' 'Egyptian'] due to missing word in the vocabulary.
# Skipping entry ['Ukraine' 'Ukrainian' 'England' 'English'] due to missing word in the vocabulary.
# Skipping entry ['Ukraine' 'Ukrainian' 'France' 'French'] due to missing word in the vocabulary.
# Skipping entry ['Ukraine' 'Ukrainian' 'Germany' 'German'] due to missing word in the vocabulary.
# Skipping entry ['Ukraine' 'Ukrainian' 'Greece' 'Greek'] due to missing word in the vocabulary.
# Skipping entry ['Ukraine' 'Ukrainian' 'Iceland' 'Icelandic'] due to missing word in the vocabulary.
# Skipping entry ['Ukraine' 'Ukrainian' 'India' 'Indian'] due to missing word in the vocabulary.
# Skipping entry ['Ukraine' 'Ukrainian' 'Ireland' 'Irish'] due to missing word in the vocabulary.
# Skipping entry ['Ukraine' 'Ukrainian' 'Israel' 'Israeli'] due to missing word in the vocabulary.
# Skipping entry ['Ukraine' 'Ukrainian' 'Italy' 'Italian'] due to missing word in the vocabulary.
# Skipping entry ['Ukraine' 'Ukrainian' 'Japan' 'Japanese'] due to missing word in the vocabulary.
# Skipping entry ['Ukraine' 'Ukrainian' 'Korea' 'Korean'] due to missing word in the vocabulary.
# Skipping entry ['Ukraine' 'Ukrainian' 'Macedonia' 'Macedonian'] due to missing word in the vocabulary.
# Skipping entry ['Ukraine' 'Ukrainian' 'Malta' 'Maltese'] due to missing word in the vocabulary.
# Skipping entry ['Ukraine' 'Ukrainian' 'Mexico' 'Mexican'] due to missing word in the vocabulary.
# Skipping entry ['Ukraine' 'Ukrainian' 'Moldova' 'Moldovan'] due to missing word in the vocabulary.
# Skipping entry ['Ukraine' 'Ukrainian' 'Netherlands' 'Dutch'] due to missing word in the vocabulary.
# Skipping entry ['Ukraine' 'Ukrainian' 'Norway' 'Norwegian'] due to missing word in the vocabulary.
# Skipping entry ['Ukraine' 'Ukrainian' 'Peru' 'Peruvian'] due to missing word in the vocabulary.
# Skipping entry ['Ukraine' 'Ukrainian' 'Poland' 'Polish'] due to missing word in the vocabulary.
# Skipping entry ['Ukraine' 'Ukrainian' 'Portugal' 'Portuguese'] due to missing word in the vocabulary.
# Skipping entry ['Ukraine' 'Ukrainian' 'Russia' 'Russian'] due to missing word in the vocabulary.
# Skipping entry ['Ukraine' 'Ukrainian' 'Slovakia' 'Slovakian'] due to missing word in the vocabulary.
# Skipping entry ['Ukraine' 'Ukrainian' 'Spain' 'Spanish'] due to missing word in the vocabulary.
# Skipping entry ['Ukraine' 'Ukrainian' 'Sweden' 'Swedish'] due to missing word in the vocabulary.
# Skipping entry ['Ukraine' 'Ukrainian' 'Switzerland' 'Swiss'] due to missing word in the vocabulary.
# Accuracy for k = 1 and W2V trained on text8: 2.61%
# Accuracy for k = 3 and W2V trained on text8: 13.86%
# Accuracy for k = 5 and W2V trained on text8: 17.03%
# Accuracy for k = 10 and W2V trained on text8: 19.92%
# Accuracy for k = 1 and W2V trained on google news: 20.19%
# Accuracy for k = 3 and W2V trained on google news: 78.35%
# Accuracy for k = 5 and W2V trained on google news: 84.72%
# Accuracy for k = 10 and W2V trained on google news: 89.35%
# Accuracy for k = 1 and FastText trained on text8: 12.41%
# Accuracy for k = 3 and FastText trained on text8: 27.89%
# Accuracy for k = 5 and FastText trained on text8: 31.16%
# Accuracy for k = 10 and FastText trained on text8: 34.43%
# Accuracy for k = 1 and W2V pretrainde on wikipedia and news: 33.62%
# Accuracy for k = 3 and W2V pretrainde on wikipedia and news: 88.96%
# Accuracy for k = 5 and W2V pretrainde on wikipedia and news: 92.14%
# Accuracy for k = 10 and W2V pretrainde on wikipedia and news: 94.65%

# %% [markdown]
# Accuracy for k = 1 and W2V trained on text8: 2.61%
# Accuracy for k = 3 and W2V trained on text8: 13.86%
# Accuracy for k = 5 and W2V trained on text8: 17.03%
# Accuracy for k = 10 and W2V trained on text8: 19.92%
# Accuracy for k = 1 and W2V trained on google news: 20.19%
# Accuracy for k = 3 and W2V trained on google news: 78.35%
# Accuracy for k = 5 and W2V trained on google news: 84.72%
# Accuracy for k = 10 and W2V trained on google news: 89.35%
# Accuracy for k = 1 and FastText trained on text8: 12.41%
# Accuracy for k = 3 and FastText trained on text8: 27.89%
# Accuracy for k = 5 and FastText trained on text8: 31.16%
# Accuracy for k = 10 and FastText trained on text8: 34.43%
# Accuracy for k = 1 and W2V pretrainde on wikipedia and news: 33.62%
# Accuracy for k = 3 and W2V pretrainde on wikipedia and news: 88.96%
# Accuracy for k = 5 and W2V pretrainde on wikipedia and news: 92.14%
# Accuracy for k = 10 and W2V pretrainde on wikipedia and news: 94.65%

# %% [markdown]
# ## Sentence Embeddings
#
# Sentence embeddings are a way to represent a sentence in a vector space. The vector space is usually learned from a large corpus of text. They are used in many NLP tasks, such as text classification, text similarity, and question answering. In this practice, we will use and interact both with Doc2Vec and InferSent models.
#
# Key takeaways from lessons and in-class practices:
# - Doc2Vec is an extension of the Word2Vec framework.
# - It incorporates Document ID to obtain a more accurate representation of a document/paragraph.
# - Training document vectors are pre-computed, however you can infer vectors for new documents.
# - InferSent exploit a deep learning architecture to supervisedly learn sentence representations.
# - InferSent vectors could exploit both Word2Vec or FastText as word embedding models.

# %% [markdown]
# ### **Question 6**
#
# Train a novel Doc2Vec model using the [APIs provided by gensim](https://radimrehurek.com/gensim/models/doc2vec.html) with text8 corpus.
#
# - Which is the training time for the model? Is it comparable with Word2Vec and FastText training time?
#
# NB. **Store** the model to a file for subsequent steps.

# %%
# your code here
from gensim.models import Doc2Vec
from gensim.models.doc2vec import TaggedDocument


tagged_data = [TaggedDocument(words=doc, tags=[str(i)]) for i, doc in enumerate(dataset)]
start_time = time.time()
doc2vec_model = Doc2Vec(vector_size=100, window=5, min_count=5, workers=4, epochs=10)
doc2vec_model.build_vocab(tagged_data)
doc2vec_model.train(tagged_data, total_examples=doc2vec_model.corpus_count, epochs=doc2vec_model.epochs)
end_time = time.time()
print(f"Doc2Vec model trained in {end_time - start_time} seconds.")

doc2vec_model.save("doc2vec_model.bin")
# Out:
# Doc2Vec model trained in 47.36729025840759 seconds.

# %% [markdown]
# The time for training is around 47 seconds wich is ....

# %% [markdown]
# ### **Question 7 (Doc2Vec qualitative evaluation)**
# Perform some **qualitative** experiments by computing the cosine similarities between sentences composed by yourself.
# For example, you can use the following sentences:
#
# ```python
# s1 = "The president of the United States is Donald Trump"
# s2 = "The president of the United States is Joe Biden"
# s3 = "United States is a country"
# s4 = "The cell phone is a device"
# ```
#
# Please try to interact with the model by providing different sentences and check the results. Is the model able to capture the semantic meaning of the sentences? Are you satisfied with the results?

# %%
# your code here

from sklearn.metrics.pairwise import cosine_similarity
import numpy as np


s1 = "The president of the United States is Donald Trump"
s2 = "The president of the United States is Joe Biden"
s3 = "United States is a country"
s4 = "The cell phone is a device"

tokenized_s1 = s1.split()
tokenized_s2 = s2.split()
tokenized_s3 = s3.split()
tokenized_s4 = s4.split()

tagged_s1 = TaggedDocument(words=tokenized_s1, tags=['s1'])
tagged_s2 = TaggedDocument(words=tokenized_s2, tags=['s2'])
tagged_s3 = TaggedDocument(words=tokenized_s3, tags=['s3'])
tagged_s4 = TaggedDocument(words=tokenized_s4, tags=['s4'])


tagged_data = [tagged_s1, tagged_s2, tagged_s3, tagged_s4]


def calculate_cosine_similarity(sentence1, sentence2, model):
    vector1 = model.infer_vector(sentence1)
    vector2 = model.infer_vector(sentence2)
    similarity = cosine_similarity([vector1], [vector2])[0][0]
    return similarity


#doc2vec_model = Doc2Vec(tagged_data, vector_size=100, window=5, min_count=1, workers=4)

# Calculate and print cosine similarities
print(f"Similarity between s1 and s2: {calculate_cosine_similarity(tokenized_s1, tokenized_s2, doc2vec_model)}")
print(f"Similarity between s1 and s3: {calculate_cosine_similarity(tokenized_s1, tokenized_s3, doc2vec_model)}")
print(f"Similarity between s1 and s4: {calculate_cosine_similarity(tokenized_s1, tokenized_s4, doc2vec_model)}")
print(f"Similarity between s2 and s3: {calculate_cosine_similarity(tokenized_s2, tokenized_s3, doc2vec_model)}")
print(f"Similarity between s2 and s4: {calculate_cosine_similarity(tokenized_s2, tokenized_s4, doc2vec_model)}")
print(f"Similarity between s3 and s4: {calculate_cosine_similarity(tokenized_s3, tokenized_s4, doc2vec_model)}")
# Out:
# Similarity between s1 and s2: 0.8405611515045166
# Similarity between s1 and s3: 0.6792886257171631
# Similarity between s1 and s4: 0.6500366926193237
# Similarity between s2 and s3: 0.7398487329483032
# Similarity between s2 and s4: 0.6416105031967163
# Similarity between s3 and s4: 0.7838231325149536

# %% [markdown]
# ### **Question 8**
#
# Load the InferSent model provided by Facebook Research ([reference](https://github.com/facebookresearch/InferSent)) and perform the same qualitative evaluation done in Question 7. In this case, you can use the InferSent pretrained model (v2) - [reference](https://github.com/facebookresearch/InferSent).
#
# Try to find some sentences for which InferSent is able to capture the semantic meaning of the sentences as opposed to Doc2Vec. Are you satisfied with the results? Which model is able to better capture the semantic meaning of the sentences? What can be the reason for this?
#
# **Notes:**
# Please find below the code to download the InferSent model.

# %%
# %%capture
# InferSent download required files

! mkdir fastText
! curl -Lo fastText/crawl-300d-2M.vec.zip https://dl.fbaipublicfiles.com/fasttext/vectors-english/crawl-300d-2M.vec.zip
! unzip fastText/crawl-300d-2M.vec.zip -d fastText/
! mkdir encoder
! curl -Lo encoder/infersent2.pkl https://dl.fbaipublicfiles.com/infersent/infersent2.pkl
! git clone https://github.com/facebookresearch/InferSent.git

# %%
from InferSent.models import InferSent
import torch
V = 2
MODEL_PATH = 'encoder/infersent%s.pkl' % V
params_model = {'bsize': 64, 'word_emb_dim': 300, 'enc_lstm_dim': 2048,
                'pool_type': 'max', 'dpout_model': 0.0, 'version': V}
infersent = InferSent(params_model)
infersent.load_state_dict(torch.load(MODEL_PATH))

W2V_PATH = 'fastText/crawl-300d-2M.vec'
infersent.set_w2v_path(W2V_PATH)

# %%
# your code here

# %% [markdown]
# ### **Question 9** (Extrinsic Evaluation)
#
# **Extrinsic** evaluation aims at measuring the performance of the word/sentence/paragraph embedding model when used in a downstream task. In this case, we will use the model to perform a text classification task.
# We can use different configuration, training corpora or even different models to build a complete architecture for the task at hand.
#
# For this practice we use the text classification dataset available [here](https://github.com/MorenoLaQuatra/DeepNLP/blob/main/practices/P2/news_headline_classification.csv) - [source: Kaggle](https://www.kaggle.com/rmisra/news-category-dataset). It contains news headlines and the corresponding category. The dataset is composed by 200846 divided into multiple categories (e.g. politics, business, sports, etc.).
#
# **Note:** consider using just the first 10.000 headlines to reduce runtime during the lab. You can use the complete data collection at home to achieve better results.
#
# Compute the accuracy of 3 classification models each one built with one of the models introduced in this practice:
# - Word2Vec model pretrained on Google News corpus
# - FastText model pretrained on Wikipedia+News corpus
# - **[Optional]** Doc2Vec model pretrained on Text8 corpus
# - **[Optional]** InferSent pretrained model (v2) - [reference](https://github.com/facebookresearch/InferSent)
#
# The procedure to create a classification system is sketched below:
# 1. Choose a machine learning (multi-class) classifier (e.g., MLP)
# 2. Split the data collection in train/test (80%/20%)
# 3. Use text vectors obtained by pretrained model as input of the classifier
# 4. Measure the accuracy of the classification system
# 5. Repeat step 3-4 using different embedding models
#
#
# **Note:** For word embedding models you must use an aggregation strategy to obtain a single vector for each sentence. You can use the average of the word vectors or the sum of the word vectors. In both cases, the output vector can be used as input of the classifier.
#
# Report the performance of each classification pipeline. Which model has better performance? Why? Try to elaborate on the results.

# %%
# !wget https://raw.githubusercontent.com/MorenoLaQuatra/DeepNLP/main/practices/P2/news_headline_classification.csv

# %%
# your code here

# %% [markdown]
# **Word2Vec + Average aggregation function**

# %%
# your code here

# %% [markdown]
# **FastText + Average aggregation function**

# %%
# your code here

# %% [markdown]
# **Doc2Vec (Text8)**

# %%
# your code here

# %% [markdown]
# **InferSent**

# %%
# your code here
